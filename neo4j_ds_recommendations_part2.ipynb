# %% [markdown]
# https://neo4j.com/graphacademy/online-training/data-science/part-3/
#
# https://www.cs.princeton.edu/~chazelle/courses/BIB/pagerank.htm

# %%
import pandas as pd
from py2neo import Graph
graph = Graph("bolt://localhost:7687", user='neo4j', password='newPassword')
# graph = Graph()

# %%
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 2, Recommendations

# %% [markdown]
# ### Page Ranking

# %% [markdown]
# In the 2nd part of this quest for a recommendations engine, we use the PageRank algorithm to make client/customer  recommendations to an merchant or merchant reccommendations to a client.
#
# PageRank is an algorithm that measures the so-called transitive influence or connectivity of nodes. It can be computed by either iteratively distributing one node’s rank (originally based on degree) over its neighbors or by randomly traversing the graph and counting the frequency of hitting each node during these walks.

# %% [markdown]
# Check that our database is running:

# %%
graph.run("CALL db.schema.visualization()").data()
# Out:
# [{'nodes': [(_-14:Merchant {constraints: ['CONSTRAINT ON ( merchant:Merchant ) ASSERT (merchant.franchisename) IS UNIQUE'], indexes: ['franchisename'], name: 'Merchant'}),
#    (_-13:Client {constraints: ['CONSTRAINT ON ( client:Client ) ASSERT (client.dedupestatic) IS UNIQUE'], indexes: [], name: 'Client'})],
#   'relationships': [(Client)-[:TRANSACTED_AT {}]->(Merchant)]}]

# %% [markdown]
# https://www.cs.princeton.edu/~chazelle/courses/BIB/pagerank.htm

# %% [markdown]
# The following PageRank code is run over the whole graph to find out the most influential Merchant in terms of transactions:

# %% [markdown]
# #### Find popular merchants:

# %%
popular_merchants_query = """
MATCH (merchant:Merchant)
RETURN merchant.franchisename, size((merchant)<-[:TRANSACTED_AT]-()) AS transactions
ORDER BY transactions DESC
LIMIT 10
"""

graph.run(popular_merchants_query).to_data_frame()
# Out:
#   merchant.franchisename  transactions
# 0         BOXER SUPERSTO         93970
# 1            NETFLIX.COM         84771
# 2          CheckersHyper         70692
# 3         APPLE.COM/BILL         64212
# 4         payD Vodacom E         63589
# 5              Truworths         61202
# 6         CHICKEN LICKEN         56052
# 7         UBER SA HELP.U         44448
# 8           MTN Eazi Rec         41583
# 9               PEP CELL         38983

# %% [markdown]
# #### Pick one merchant, 'franchisename:'DIS-CHEM DAINFERN'

# %%
franchisename='DIS-CHEM DAINFERN'

# %%
query = """
MATCH (m:Merchant {franchisename:$franchisename})
RETURN m.companyname
"""
graph.run(query, {"franchisename": franchisename}).to_data_frame()
# Out:
#   m.companyname
# 0       DISCHEM

# %%
# query = """
#     CALL db.index.fulltext.createNodeIndex('merchants', ['Merchant'], ['franchisename'])
# """
# graph.run(query).data()

# %% [markdown]
# #### Retrieve FULLTEXT indices:

# %%
query = """
CALL db.indexes()
YIELD name, uniqueness, type
WHERE type = "FULLTEXT"
RETURN *
"""
graph.run(query).to_data_frame()
# Out:
#         name      type uniqueness
# 0  merchants  FULLTEXT  NONUNIQUE

# %% [markdown]
# #### Conduct a full text search on franchisename over the entire graph:

# %%
query = """
CALL db.index.fulltext.queryNodes("merchants", "columbine")
YIELD node, score
RETURN node.franchisename, score, [(client)-[:TRANSACTED_AT]-(node) | client.dedupestatic] AS clients
LIMIT 10
"""
graph.run(query).to_data_frame()
# Out:
#      node.franchisename     score  \
# 0  WOOLWORTHS COLUMBINE  4.751985
# 1    CHECKERS COLUMBINE  4.751985
# 2      Clicks Columbine  4.751985
# 3   MCDONALDS COLUMBINE  4.751985
# 4    Checkers Columbine  4.751985
# 5       ENGEN COLUMBINE  4.751985
# 6         MTN COLUMBINE  4.751985
# 7     COLUMBINE SERVICE  4.751985
# 8        COLUMBINE SERV  4.751985
# 9     Columbine Co -  -  4.751985
#
#                                              clients
# 0  [2.113942945e+11, 2.114112577e+11, 1.912449891...
# 1  [1.91210293005e+11, 1.10028582802e+11, 1.10103...
# 2  [2.11242239909e+11, 2.11482389736e+11, 1.91871...
# 3  [1.10021078408e+11, 1.91136412536e+11, 2.11587...
# 4  [2.113942945e+11, 1.10262820501e+11, 1.1022603...
# 5  [1.91336439034e+11, 2.11084497304e+11, 2.11321...
# 6  [1.91136694905e+11, 1.91220942836e+11, 2.11255...
# 7  [1.91054314407e+11, 1.91442782905e+11, 1.91227...
# 8  [2.11649785003e+11, 2.11686938808e+11, 1.91178...
# 9  [1.91522046201e+11, 1.10105532002e+11, 1.10001...

# %%
my_node = graph.run("""MATCH (merchant:Merchant {companyname:'DISCHEM'})
RETURN merchant """).data()

# %%
my_node
# Out:
# [{'merchant': (_59:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CANAL WALK'})},
#  {'merchant': (_78:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KILLARNEY PHAMAC'})},
#  {'merchant': (_108:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM DAINFERN'})},
#  {'merchant': (_141:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SANDTON CITY PHA'})},
#  {'merchant': (_442:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ATHOL OAKLANDS I'})},
#  {'merchant': (_497:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ATHOL OAKLAND'})},
#  {'merchant': (_551:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GLEN LUCIA PHN L'})},
#  {'merchant': (_630:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Ballito Lifesty'})},
#  {'merchant': (_681:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SUNNINGHILL PARM'})},
#  {'merchant': (_696:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Benmore'})},
#  {'merchant': (_714:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NICOLWAY PHAR'})},
#  {'merchant': (_728:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GATEWAY PHARM'})},
#  {'merchant': (_730:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SANDTON CITY'})},
#  {'merchant': (_810:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LANGENHOVEN PRK'})},
#  {'merchant': (_877:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BEDFORD SQUAR'})},
#  {'merchant': (_915:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Norwood'})},
#  {'merchant': (_940:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODLANDS'})},
#  {'merchant': (_1159:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HILLCREST PHA'})},
#  {'merchant': (_1220:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Woodlands Boule'})},
#  {'merchant': (_1322:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NOORDHOEK P'})},
#  {'merchant': (_1348:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Paarl Mall'})},
#  {'merchant': (_1425:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CLAREMONT'})},
#  {'merchant': (_1449:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BROOKLYN PHAR'})},
#  {'merchant': (_1452:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Nicolway'})},
#  {'merchant': (_1551:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RAND RIDGE ME'})},
#  {'merchant': (_1559:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BENMORE GARDENS'})},
#  {'merchant': (_1586:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM YORK STREET'})},
#  {'merchant': (_1601:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ROSEBANK'})},
#  {'merchant': (_1655:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOMERSET WEST'})},
#  {'merchant': (_1811:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM DAINFERN PHARMCY'})},
#  {'merchant': (_1844:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Liberty Mall'})},
#  {'merchant': (_1957:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  STRUBEN VALLY'})},
#  {'merchant': (_1968:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOMER MALL (S'})},
#  {'merchant': (_1970:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Glen Marais'})},
#  {'merchant': (_2011:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORTHGATE'})},
#  {'merchant': (_2075:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Brooklyn Mall'})},
#  {'merchant': (_2102:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE CLUB SURGCAL'})},
#  {'merchant': (_2129:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemWatercres'})},
#  {'merchant': (_2209:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PEARLS PHARMACY'})},
#  {'merchant': (_2210:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CLEAR WATER ML'})},
#  {'merchant': (_2234:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Fourways Mall'})},
#  {'merchant': (_2331:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ALBERMARLE GA'})},
#  {'merchant': (_2389:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  GLENFAIR PHA'})},
#  {'merchant': (_2497:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LA LUCIA'})},
#  {'merchant': (_2508:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLOEMFONTEIN'})},
#  {'merchant': (_2566:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WALMER PARK P'})},
#  {'merchant': (_2601:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM OLYMPUS PHARM'})},
#  {'merchant': (_2779:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE (CLAREMO'})},
#  {'merchant': (_2796:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Victory Park'})},
#  {'merchant': (_2800:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VICTORY PARK'})},
#  {'merchant': (_2880:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL OF AFR'})},
#  {'merchant': (_2966:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NICOLWAY'})},
#  {'merchant': (_2990:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SEA POINT PHARMA'})},
#  {'merchant': (_3148:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem La Lucia'})},
#  {'merchant': (_3201:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODLANDS PHA'})},
#  {'merchant': (_3226:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BALLITO LIFES'})},
#  {'merchant': (_3315:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BALLITO LIF'})},
#  {'merchant': (_3324:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CORNUBIA'})},
#  {'merchant': (_3460:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM EAST RAND PHA'})},
#  {'merchant': (_3471:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CORNUBIA PHARACY'})},
#  {'merchant': (_3502:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM EASTGATE'})},
#  {'merchant': (_3511:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAZELDEEN PHA'})},
#  {'merchant': (_3584:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Zapper*Dis-Chem Benmor'})},
#  {'merchant': (_3585:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORWOOD'})},
#  {'merchant': (_3598:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WATERCREST'})},
#  {'merchant': (_3644:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MORNINGSIDE PARM'})},
#  {'merchant': (_3696:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Watercrest'})},
#  {'merchant': (_3725:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Jean Avenue'})},
#  {'merchant': (_3727:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cresta'})},
#  {'merchant': (_3739:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sandton City'})},
#  {'merchant': (_3848:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CENTURY CITY'})},
#  {'merchant': (_3966:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYSIDE MALL'})},
#  {'merchant': (_3971:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Rosebank'})},
#  {'merchant': (_4013:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Amanzimtoti'})},
#  {'merchant': (_4024:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LYNWOOD LANE PHA'})},
#  {'merchant': (_4025:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Lynwood Lane'})},
#  {'merchant': (_4027:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Potchefstroom'})},
#  {'merchant': (_4032:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL OF THE SUTH'})},
#  {'merchant': (_4172:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Canal Walk'})},
#  {'merchant': (_4269:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Menlyn Park Mal'})},
#  {'merchant': (_4327:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Overport'})},
#  {'merchant': (_4331:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Verdi'})},
#  {'merchant': (_4361:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Rynfield Terrac'})},
#  {'merchant': (_4371:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CLEAR WATER'})},
#  {'merchant': (_4455:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Vaal Mall'})},
#  {'merchant': (_4462:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESTVILLE PHA'})},
#  {'merchant': (_4515:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Boksburg North'})},
#  {'merchant': (_4611:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TOTI PHARMACYARM'})},
#  {'merchant': (_4658:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ROSEBANK PHAR'})},
#  {'merchant': (_4728:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cradlestone'})},
#  {'merchant': (_4772:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  CENTURION PH'})},
#  {'merchant': (_4785:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WATERCREST PHL'})},
#  {'merchant': (_4834:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM AMANZIMTOTI -T'})},
#  {'merchant': (_4842:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SITARI FIELDS'})},
#  {'merchant': (_4935:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cape Gate'})},
#  {'merchant': (_5028:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VALLEY VIEW'})},
#  {'merchant': (_5089:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FERNDALE MALL'})},
#  {'merchant': (_5122:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CLEARWATER MA'})},
#  {'merchant': (_5144:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BOKSBURG'})},
#  {'merchant': (_5220:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sunninghill'})},
#  {'merchant': (_5227:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WONDERPARK PH'})},
#  {'merchant': (_5378:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bloemfontein'})},
#  {'merchant': (_5438:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Eastgate'})},
#  {'merchant': (_5461:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREENSTONE PH'})},
#  {'merchant': (_5479:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem New Market Mall'})},
#  {'merchant': (_5511:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Killarney'})},
#  {'merchant': (_5512:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MENLYN PHARMAARM'})},
#  {'merchant': (_5618:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Centurion'})},
#  {'merchant': (_5755:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Roodepoort'})},
#  {'merchant': (_5759:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Greenstone'})},
#  {'merchant': (_5835:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VAAL MALL'})},
#  {'merchant': (_5863:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CRESTA PHARMA'})},
#  {'merchant': (_5959:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CARNIVAL MALL'})},
#  {'merchant': (_6062:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Secunda'})},
#  {'merchant': (_6191:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORTHGATE PHA'})},
#  {'merchant': (_6219:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM STRUBENSVALLE'})},
#  {'merchant': (_6261:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bedford Square'})},
#  {'merchant': (_6334:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sea Point'})},
#  {'merchant': (_6424:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MEADOWDALE PH'})},
#  {'merchant': (_6430:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SEA POINT'})},
#  {'merchant': (_6500:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NOORDHOEK PHAMAC'})},
#  {'merchant': (_6522:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HARTBEESPOORT IN'})},
#  {'merchant': (_6541:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM EASTGATE PHARACY'})},
#  {'merchant': (_6562:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE PAVILLION'})},
#  {'merchant': (_6641:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KNYSNA MALL PHAR'})},
#  {'merchant': (_6650:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BOKSBURG NORT'})},
#  {'merchant': (_6692:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GLEN ACRES PHT'})},
#  {'merchant': (_6722:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FOURWAYS MALL'})},
#  {'merchant': (_6785:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREENSTONE'})},
#  {'merchant': (_6846:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Athol Oaklands'})},
#  {'merchant': (_7000:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Valley View'})},
#  {'merchant': (_7047:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Modderfontein'})},
#  {'merchant': (_7081:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MODDERFONTEIN'})},
#  {'merchant': (_7097:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Parkmeadows'})},
#  {'merchant': (_7185:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PAVILION DURB'})},
#  {'merchant': (_7219:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TLC DE WIEKUS'})},
#  {'merchant': (_7223:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem The Pavillion'})},
#  {'merchant': (_7246:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL OF AFRIC'})},
#  {'merchant': (_7282:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM JEAN AVENUE'})},
#  {'merchant': (_7289:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  SUNWARD PARK'})},
#  {'merchant': (_7310:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bracken Gardens'})},
#  {'merchant': (_7361:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MENLYN PARK'})},
#  {'merchant': (_7539:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HERMANUS PHART'})},
#  {'merchant': (_7547:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREENVALLEY'})},
#  {'merchant': (_7548:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MONTANA PHARM'})},
#  {'merchant': (_7561:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Hartebeespoort'})},
#  {'merchant': (_7846:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLUE ROUTE MA'})},
#  {'merchant': (_7892:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Randridge'})},
#  {'merchant': (_7921:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BALLITO'})},
#  {'merchant': (_7925:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESTGATE PHAR'})},
#  {'merchant': (_7975:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MONDEOR PHARM'})},
#  {'merchant': (_7984:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODMEAD PHAR'})},
#  {'merchant': (_7988:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WINDHOEK'})},
#  {'merchant': (_8017:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VAAL PHARMACY'})},
#  {'merchant': (_8051:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem South Coast Mal'})},
#  {'merchant': (_8118:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Morningside'})},
#  {'merchant': (_8139:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SPRINGS PHARM'})},
#  {'merchant': (_8196:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VERDI PHARMAC'})},
#  {'merchant': (_8212:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WALMER PARK'})},
#  {'merchant': (_8303:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYWEST PHARMHAR'})},
#  {'merchant': (_8365:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Farramere'})},
#  {'merchant': (_8498:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Olympus'})},
#  {'merchant': (_8504:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM OVERPORT PHAR'})},
#  {'merchant': (_8672:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Woodmead'})},
#  {'merchant': (_8704:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PINECREST PHA'})},
#  {'merchant': (_8750:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Clearwater Mall'})},
#  {'merchant': (_8796:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Hillcrest'})},
#  {'merchant': (_8801:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SUNWARD PARK'})},
#  {'merchant': (_8901:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Pinecrest'})},
#  {'merchant': (_8940:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FARRAMERE'})},
#  {'merchant': (_9061:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem East Rand'})},
#  {'merchant': (_9110:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Mall of the Sou'})},
#  {'merchant': (_9114:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TABLE BAY PHA PH'})},
#  {'merchant': (_9129:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem George'})},
#  {'merchant': (_9237:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FARRAMERE PHALL'})},
#  {'merchant': (_9424:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Pearls Pharmacy'})},
#  {'merchant': (_9433:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Northgate'})},
#  {'merchant': (_9539:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PARKMEADOWS P'})},
#  {'merchant': (_9558:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Claremont'})},
#  {'merchant': (_9607:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MIDLANDS MALLINT'})},
#  {'merchant': (_9623:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RASLOUW PHARM'})},
#  {'merchant': (_9773:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bayside Mall'})},
#  {'merchant': (_9801:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM JEFFREYS BAY'})},
#  {'merchant': (_9824:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CARLSWALD PHARMA'})},
#  {'merchant': (_9890:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PAARL MALL PH'})},
#  {'merchant': (_9923:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KILLARNEY M'})},
#  {'merchant': (_9970:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORWOOD PHARM'})},
#  {'merchant': (_10093:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Ferndale'})},
#  {'merchant': (_10102:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Knysna Mall'})},
#  {'merchant': (_10139:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LYNNWOOD RD'})},
#  {'merchant': (_10243:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TYGERVALLEY P'})},
#  {'merchant': (_10248:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Green Valley'})},
#  {'merchant': (_10302:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODBURN SQUAE P'})},
#  {'merchant': (_10303:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MIDLANDS MALL'})},
#  {'merchant': (_10462:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYSIDE'})},
#  {'merchant': (_10592:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM JEAN AVENUE PARM'})},
#  {'merchant': (_10619:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE GLEN PHAR'})},
#  {'merchant': (_10732:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CRADLE STONE'})},
#  {'merchant': (_10790:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESKUS MALL P'})},
#  {'merchant': (_10912:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ATHOL OAKLANDS'})},
#  {'merchant': (_11068:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE GATE PHAMAC'})},
#  {'merchant': (_11073:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CARLSWALD'})},
#  {'merchant': (_11181:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LYNNWOOD PHARINT'})},
#  {'merchant': (_11212:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GLEN ACRES'})},
#  {'merchant': (_11383:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MEGA CITY PHA'})},
#  {'merchant': (_11402:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RUSTENBURG PH'})},
#  {'merchant': (_11472:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ROODEPOORT PHIN'})},
#  {'merchant': (_11495:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Strubens Valley'})},
#  {'merchant': (_11595:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HILLCREST DUR'})},
#  {'merchant': (_11606:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL@ PHARM'})},
#  {'merchant': (_11609:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MEADOWDALE'})},
#  {'merchant': (_11757:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Walmer Park'})},
#  {'merchant': (_11829:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Hermanus'})},
#  {'merchant': (_11853:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KENILWORTH PHNTR'})},
#  {'merchant': (_12010:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RYNFIELD TERRCE'})},
#  {'merchant': (_12017:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE RD PHARM'})},
#  {'merchant': (_12188:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Montana'})},
#  {'merchant': (_12306:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREENVALLEY PHAR'})},
#  {'merchant': (_12312:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SITARI FIELDSPHA'})},
#  {'merchant': (_12358:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KALAHARI MALLACY'})},
#  {'merchant': (_12427:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Somerset Mall'})},
#  {'merchant': (_12447:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Rustenburg'})},
#  {'merchant': (_12563:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORTH CAPE'})},
#  {'merchant': (_12610:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BROOKLYN'})},
#  {'merchant': (_12830:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GOODWOOD N CACY'})},
#  {'merchant': (_12992:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WORCESTER PHASTE'})},
#  {'merchant': (_13179:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HIGHVELD MALL'})},
#  {'merchant': (_13334:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Albermarle Gard'})},
#  {'merchant': (_13542:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TABLE BAY MAL'})},
#  {'merchant': (_13679:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM POTCHEFSTROOM'})},
#  {'merchant': (_13795:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GEORGE'})},
#  {'merchant': (_13944:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  MOSSELBAAI ML P'})},
#  {'merchant': (_14011:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Pres Hyper V/D'})},
#  {'merchant': (_14400:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NEWCASTLE'})},
#  {'merchant': (_14537:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PRELLER SQUAR'})},
#  {'merchant': (_14549:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BALLITO JUNCT'})},
#  {'merchant': (_14579:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM WERNHILL'})},
#  {'merchant': (_14604:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SPRINGS MALL'})},
#  {'merchant': (_14734:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WONDERPARK'})},
#  {'merchant': (_14740:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GOLDFIELDS'})},
#  {'merchant': (_14791:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RANDRIDGE'})},
#  {'merchant': (_14837:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RYNFIELD TERR'})},
#  {'merchant': (_14911:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE GATE -'})},
#  {'merchant': (_15060:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SUNNINGHILL'})},
#  {'merchant': (_15207:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MONDEOR'})},
#  {'merchant': (_15236:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ZEVENWACHT'})},
#  {'merchant': (_15283:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PRELLER SQUARRE'})},
#  {'merchant': (_15377:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cornubia Mall'})},
#  {'merchant': (_15625:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE MALL OF C'})},
#  {'merchant': (_15661:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RICHARDS BAY'})},
#  {'merchant': (_15783:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WONDERBOOM PH'})},
#  {'merchant': (_15842:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  JEAN AVENUE ARM'})},
#  {'merchant': (_15898:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAASENDAL PHAPIN'})},
#  {'merchant': (_15939:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM DURBANVILLE P'})},
#  {'merchant': (_15958:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BRACKEN GARDE'})},
#  {'merchant': (_15979:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VALLEY VIEW PT'})},
#  {'merchant': (_16062:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VERDI CENTRE'})},
#  {'merchant': (_16324:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TYGERVALLEY'})},
#  {'merchant': (_16325:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  MASINGITA PH'})},
#  {'merchant': (_16384:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NEW MARKET PHL P'})},
#  {'merchant': (_16454:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RANDFONTEIN PARM'})},
#  {'merchant': (_16512:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PARK MEADOWS'})},
#  {'merchant': (_16531:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOUTH COAST ML'})},
#  {'merchant': (_16643:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'PAYPAL *DISCHEMPHAR'})},
#  {'merchant': (_16666:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KRUGERSDORP S'})},
#  {'merchant': (_16684:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GARDEN ROUTE'})},
#  {'merchant': (_16699:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MAPONYA MALL'})},
#  {'merchant': (_16734:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HEMMINGWAY'})},
#  {'merchant': (_16835:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WONDERBOOM'})},
#  {'merchant': (_16951:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FESTIVAL MALL'})},
#  {'merchant': (_16977:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ROODEPOORT'})},
#  {'merchant': (_17006:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Gateway Mall'})},
#  {'merchant': (_17081:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Dainfern Square'})},
#  {'merchant': (_17090:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE ATRIUM OV'})},
#  {'merchant': (_17119:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SAVANNAH MALL'})},
#  {'merchant': (_17127:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODMEAD'})},
#  {'merchant': (_17177:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Meadowdale'})},
#  {'merchant': (_17273:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MIDDELBURG'})},
#  {'merchant': (_17374:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MORNINGSIDE'})},
#  {'merchant': (_17442:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Strubens Valle'})},
#  {'merchant': (_17470:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Goodwood N Cit'})},
#  {'merchant': (_17512:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CHARTSWORTH PARM'})},
#  {'merchant': (_17541:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WHITE RIVER C'})},
#  {'merchant': (_17543:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESKUS MALL'})},
#  {'merchant': (_17620:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ALBEMARLE SQUEN'})},
#  {'merchant': (_17704:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GOODWOOD PHAR'})},
#  {'merchant': (_17895:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LOCH LOGAN BL'})},
#  {'merchant': (_17911:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL OF THE'})},
#  {'merchant': (_17993:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KENILWORTH CE'})},
#  {'merchant': (_18097:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CRADLESTONE'})},
#  {'merchant': (_18220:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MONTANA NORTH'})},
#  {'merchant': (_18240:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NEW MARKET'})},
#  {'merchant': (_18406:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sunward Park'})},
#  {'merchant': (_18520:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BENMORE'})},
#  {'merchant': (_18549:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SECUNDA'})},
#  {'merchant': (_18559:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CHATSWORTH CE'})},
#  {'merchant': (_18589:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ZEVENWACHT PHT'})},
#  {'merchant': (_18627:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM DUNES MALL'})},
#  {'merchant': (_18631:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE MALL FOUR'})},
#  {'merchant': (_18632:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PAARL'})},
#  {'merchant': (_18837:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WITBANK - HIG'})},
#  {'merchant': (_18847:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NEWCASTLE PHAARM'})},
#  {'merchant': (_18901:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HERMANUS'})},
#  {'merchant': (_18920:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CRESTA'})},
#  {'merchant': (_18990:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOUTH COAST M'})},
#  {'merchant': (_19026:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TOTI CENTRE'})},
#  {'merchant': (_19054:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLUE ROUTE PH'})},
#  {'merchant': (_19252:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SECUNDA PHARM'})},
#  {'merchant': (_19309:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Hemmingways'})},
#  {'merchant': (_19784:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOSHANGUVE PH'})},
#  {'merchant': (_19829:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Fountains Jeffr'})},
#  {'merchant': (_19867:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HARTBEESPOORT'})},
#  {'merchant': (_19958:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VANDERBIJLPAR'})},
#  {'merchant': (_20060:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CENTURION'})},
#  {'merchant': (_20069:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bluff Towers'})},
#  {'merchant': (_20081:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE CLUB PHAR'})},
#  {'merchant': (_20728:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESTGATE'})},
#  {'merchant': (_20817:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MAPONYA MAL'})},
#  {'merchant': (_21043:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL OF THE N'})},
#  {'merchant': (_21056:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THREE RIVERS'})},
#  {'merchant': (_21057:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM OLYMPUS'})},
#  {'merchant': (_21130:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREYSTONE CRO'})},
#  {'merchant': (_21325:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'http://www.dischemonli'})},
#  {'merchant': (_21346:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HEIDELBERG'})},
#  {'merchant': (_21438:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MELLVILLE PHAACY'})},
#  {'merchant': (_21513:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PINECREST -'})},
#  {'merchant': (_21623:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODBURN SQUA'})},
#  {'merchant': (_21651:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LANGENHOVEN'})},
#  {'merchant': (_21655:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LYNNWOOD LANE'})},
#  {'merchant': (_21769:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAZELDENE'})},
#  {'merchant': (_21818:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  HEMMINGWAYS'})},
#  {'merchant': (_21923:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM EAST RAND MAL'})},
#  {'merchant': (_21993:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Richards Bay'})},
#  {'merchant': (_22067:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WHITE RIVER C IN'})},
#  {'merchant': (_22235:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Witbank'})},
#  {'merchant': (_22906:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE GLEN'})},
#  {'merchant': (_22935:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RANDFONTEIN'})},
#  {'merchant': (_22939:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Kalahari Villag'})},
#  {'merchant': (_23008:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Mall@'})},
#  {'merchant': (_23017:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESTWOOD'})},
#  {'merchant': (_23086:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Melville'})},
#  {'merchant': (_23106:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE BLUFF -'})},
#  {'merchant': (_23120:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RASLOUW'})},
#  {'merchant': (_23275:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MELVILLE'})},
#  {'merchant': (_23403:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Raslouw'})},
#  {'merchant': (_23614:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GLENFAIR'})},
#  {'merchant': (_23841:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Haasendal'})},
#  {'merchant': (_24069:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MOSSELBAAI'})},
#  {'merchant': (_24431:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sun Valley'})},
#  {'merchant': (_24701:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Middelburg'})},
#  {'merchant': (_24718:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MOOIRIVIER MA'})},
#  {'merchant': (_24750:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem TLC De Wiekus R'})},
#  {'merchant': (_24788:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Langehoven'})},
#  {'merchant': (_25334:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FLEURDAL PHARACY'})},
#  {'merchant': (_25482:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLUFF TOWER PRMA'})},
#  {'merchant': (_25517:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WORCESTER'})},
#  {'merchant': (_25781:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RUSTENBURG'})},
#  {'merchant': (_26104:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Worcester'})},
#  {'merchant': (_26110:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Wonderpark'})},
#  {'merchant': (_26544:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Westgate'})},
#  {'merchant': (_26932:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOSHANGUVE'})},
#  {'merchant': (_27167:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Greenvalley'})},
#  {'merchant': (_27333:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREYSTONE PHASIN'})},
#  {'merchant': (_27421:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MIDDELBURG PHLBU'})},
#  {'merchant': (_27539:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KALAHARI MALL'})},
#  {'merchant': (_27561:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM POLOKWANE NORRTH'})},
#  {'merchant': (_27738:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Soshanguwe Cros'})},
#  {'merchant': (_27812:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MEGA CITY PHAMAC'})},
#  {'merchant': (_27994:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM AMANZIMTOTI'})},
#  {'merchant': (_28171:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM DURBANVILLE'})},
#  {'merchant': (_28347:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM YORK STREET PAR'})},
#  {'merchant': (_28354:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Southgate'})},
#  {'merchant': (_28387:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYWEST MAL'})},
#  {'merchant': (_28536:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM EXPRESS HEI'})},
#  {'merchant': (_28575:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Table Bay Mall'})},
#  {'merchant': (_28708:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Tygervalley'})},
#  {'merchant': (_29220:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NELSPRUIT'})},
#  {'merchant': (_29268:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FLEURDAL'})},
#  {'merchant': (_29686:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LIBERTY PRO'})},
#  {'merchant': (_29814:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE ROAD'})},
#  {'merchant': (_29833:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cape Road'})},
#  {'merchant': (_30183:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM JUBILEE MALL'})},
#  {'merchant': (_30520:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LOFTUS PARK P'})},
#  {'merchant': (_30554:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Lynwood'})},
#  {'merchant': (_30747:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PLATINUM PA'})},
#  {'merchant': (_30794:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Festival Mall'})},
#  {'merchant': (_31054:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOUTHGATE PHAGAT'})},
#  {'merchant': (_31193:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Blue Route'})},
#  {'merchant': (_31415:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOUTHGATE'})},
#  {'merchant': (_31554:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Carnival Mall'})},
#  {'merchant': (_31876:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL@ - C'})},
#  {'merchant': (_32015:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KIMBERLEY NORL'})},
#  {'merchant': (_32874:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Durbanville'})},
#  {'merchant': (_32903:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAASENDAL'})},
#  {'merchant': (_34416:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Savannah Mall'})},
#  {'merchant': (_36083:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Club Surgical'})},
#  {'merchant': (_36227:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KLERKSDORP-FL'})},
#  {'merchant': (_36268:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Ballito'})},
#  {'merchant': (_36551:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Krugersdorp'})},
#  {'merchant': (_36570:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Dainfern Squar'})},
#  {'merchant': (_36867:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemBenmor'})},
#  {'merchant': (_36936:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemCornub'})},
#  {'merchant': (_37080:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem The Glen'})},
#  {'merchant': (_37296:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KRUGERSDORP'})},
#  {'merchant': (_37853:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GROBLERSDAL'})},
#  {'merchant': (_38329:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Weskus Mall'})},
# ...
#  {'merchant': (_256736:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CRESTA PHAR'})},
#  {'merchant': (_256770:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ALBEMARLE S'})},
#  {'merchant': (_256803:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODLANDS P'})},
#  {'merchant': (_256855:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ONCOLOGY-ONOCA'})},
#  {'merchant': (_257847:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'payD Zapper*Dis-Chem C'})},
#  {'merchant': (_257872:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  MOSSELBAAI'})},
#  {'merchant': (_258003:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPPER*Dis-ChemCornu'})},
#  {'merchant': (_258384:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Liberty Promin'})},
#  {'merchant': (_259829:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM PAARL MALL P *'})},
#  {'merchant': (_260651:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM MOOIRIVER'})},
#  {'merchant': (_260732:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FOURWAYS MA'})},
#  {'merchant': (_262311:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE CLUB'})},
#  {'merchant': (_263113:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WHITE'})},
#  {'merchant': (_263701:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BRAAMFONTEI'})},
#  {'merchant': (_264892:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'payD Zapper*Dis-Chem B'})},
#  {'merchant': (_265451:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WHITE RIVER C PO'})},
#  {'merchant': (_265731:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BRAAMFONTEIN'})},
#  {'merchant': (_266371:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM WOODBURN SQUARE'})},
#  {'merchant': (_266385:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM WONDERPARK MALL'})},
#  {'merchant': (_266436:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemMorningsi'})},
#  {'merchant': (_266460:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemLibert'})},
#  {'merchant': (_266537:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  AIRPORT JUNCTI'})},
#  {'merchant': (_266539:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Zapper*Dis-Chem Pharma'})},
#  {'merchant': (_267135:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ONCOLOGY PAN'})},
#  {'merchant': (_267364:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  CULEMBORG PHA'})},
#  {'merchant': (_267934:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SPRINGS PHA'})},
#  {'merchant': (_267972:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemCentur'})},
#  {'merchant': (_268373:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GARDEN ROUT'})},
#  {'merchant': (_268442:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SUNWARD PARK INT'})},
#  {'merchant': (_270691:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemJeanAvenu'})},
#  {'merchant': (_270803:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM OVERPORT PH'})},
#  {'merchant': (_271426:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RUSTENBURG PHA'})},
#  {'merchant': (_271991:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemMenlynPar'})},
#  {'merchant': (_272171:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ONCOLOGY SAND'})},
#  {'merchant': (_272329:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemBrookl'})},
#  {'merchant': (_272939:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemOlympus'})},
#  {'merchant': (_273013:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Zapper*Dis-Chem Randri'})},
#  {'merchant': (_273026:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CENTURY CITY ('})},
#  {'merchant': (_273029:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Zapper*Dis-Chem Victor'})},
#  {'merchant': (_274720:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM - THE LOCAL'})},
#  {'merchant': (_275220:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemBallitoJunction'})},
#  {'merchant': (_276360:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Fountains Jeff'})},
#  {'merchant': (_276655:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemGreens'})},
#  {'merchant': (_277293:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemPaarlMall'})},
#  {'merchant': (_277866:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPPER*Dis-ChemWater'})},
#  {'merchant': (_278174:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Masingita Mall'})},
#  {'merchant': (_278463:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOUTHVIEW PHA'})},
#  {'merchant': (_279470:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM CHATSWORTH'})},
#  {'merchant': (_279750:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemroodepoor'})},
#  {'merchant': (_279813:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MENLYN PHAR'})},
#  {'merchant': (_280293:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemGarden'})},
#  {'merchant': (_281348:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPPER*Dis-ChemNoordho'})},
#  {'merchant': (_281372:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FARRAMERE PHA'})},
#  {'merchant': (_282477:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLUE ROUTE PHA'})},
#  {'merchant': (_282532:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemCradle'})},
#  {'merchant': (_282631:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemLynnwo'})},
#  {'merchant': (_283671:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ONCOLOGY ROND'})},
#  {'merchant': (_284055:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE MALL OF CA'})},
#  {'merchant': (_284522:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ROODEPOORT PHA'})},
#  {'merchant': (_284623:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemLocalChoi'})},
#  {'merchant': (_284836:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Braamfontein RH'})},
#  {'merchant': (_285022:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYSIDE MALL P'})},
#  {'merchant': (_286943:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemHartebees'})},
#  {'merchant': (_287406:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CAPE GATE P'})},
#  {'merchant': (_287785:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SITARI FIEL'})},
#  {'merchant': (_289437:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM RANDRIDGE'})},
#  {'merchant': (_289438:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM BRAAMFONTEIN'})},
#  {'merchant': (_289440:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM MALL@'})},
#  {'merchant': (_289978:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GROBLERSDAL MALL'})},
#  {'merchant': (_292971:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemSomersetM'})},
#  {'merchant': (_293486:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPPER*Dis-ChemBoksb'})},
#  {'merchant': (_294191:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE PAVILLI'})},
#  {'merchant': (_295108:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GLEN ACRES PHA'})},
#  {'merchant': (_295218:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WESKUS MALL PH'})},
#  {'merchant': (_295466:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VICTORY PARK P'})},
#  {'merchant': (_296066:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM RYNFIELD TERRA'})},
#  {'merchant': (_296848:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM ONCOLOGY PRE'})},
#  {'merchant': (_297567:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DisChemNewcastle'})},
#  {'merchant': (_297900:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WONDERBOOM   S'})},
#  {'merchant': (_299458:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'payD Zapper*Dis-Chem V'})},
#  {'merchant': (_299747:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VANDERBIJLPARK'})},
#  {'merchant': (_299764:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HEMMINGWAYS EA'})},
#  {'merchant': (_300428:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM YORK STREET PH'})},
#  {'merchant': (_301087:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM NEW MARKET'})},
#  {'merchant': (_301142:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemFarram'})},
#  {'merchant': (_301365:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DISCHEM WILLOWBRIDGE'})},
#  {'merchant': (_304276:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'payD Zapper*Dis-Chem S'})},
#  {'merchant': (_304985:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPPER*Dis-ChemGlenf'})},
#  {'merchant': (_305682:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS CHEM CONSTANTIA PA'})},
#  {'merchant': (_306205:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM  MONTANA PHARM'})},
#  {'merchant': (_306268:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TLC DE WIEK'})},
#  {'merchant': (_306545:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM FARRAMERE PHAR'})},
#  {'merchant': (_308882:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAZEL'})},
#  {'merchant': (_308901:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BENMO'})},
#  {'merchant': (_308902:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sunn'})},
#  {'merchant': (_308910:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Dain'})},
#  {'merchant': (_308965:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WOODL'})},
#  {'merchant': (_309009:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Atho'})},
#  {'merchant': (_309048:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MORNI'})},
#  {'merchant': (_309072:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HILLC'})},
#  {'merchant': (_309099:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM LOCH'})},
#  {'merchant': (_309138:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM HAASE'})},
#  {'merchant': (_309144:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NICOL'})},
#  {'merchant': (_309185:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SANDT'})},
#  {'merchant': (_309278:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BAYWE'})},
#  {'merchant': (_309357:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM YORK'})},
#  {'merchant': (_309359:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TYGER'})},
#  {'merchant': (_309402:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cres'})},
#  {'merchant': (_309435:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MOSSE'})},
#  {'merchant': (_309504:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM KNYSN'})},
#  {'merchant': (_309517:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BROOK'})},
#  {'merchant': (_309522:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SEA P'})},
#  {'merchant': (_309552:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BALLI'})},
#  {'merchant': (_309562:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM BLUE'})},
#  {'merchant': (_309621:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Sand'})},
#  {'merchant': (_309643:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM VICTO'})},
#  {'merchant': (_309665:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'ZAPDisChemBenm'})},
#  {'merchant': (_309774:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Wood'})},
#  {'merchant': (_309795:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Morn'})},
#  {'merchant': (_309832:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Rose'})},
#  {'merchant': (_309880:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Benm'})},
#  {'merchant': (_309886:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM TABLE'})},
#  {'merchant': (_309904:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Nico'})},
#  {'merchant': (_309944:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM THE M'})},
#  {'merchant': (_309958:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Bedf'})},
#  {'merchant': (_310077:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CREST'})},
#  {'merchant': (_310093:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM SOMER'})},
#  {'merchant': (_310094:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'Dischem Cape'})},
#  {'merchant': (_310221:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MENLY'})},
#  {'merchant': (_310245:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM WALME'})},
#  {'merchant': (_310261:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CLARE'})},
#  {'merchant': (_310297:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CENT'})},
#  {'merchant': (_310337:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM NORWO'})},
#  {'merchant': (_310347:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM CULEM'})},
#  {'merchant': (_310463:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM MALL'})},
#  {'merchant': (_310464:Merchant {companyindex: '49', companyname: 'DISCHEM', franchisename: 'DIS-CHEM GREEN'})},
#  ...]

# %%
my_node = graph.run("""MATCH (merchant:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c:Client) 
RETURN merchant.franchisename, c.dedupestatic """).data()

# %%
len(my_node)
# Out:
# 252

# %% [markdown]
# Retrieve the customers this merchant had and how many transactions they had:

# %%
author_articles_query = """
MATCH (:Merchant {franchisename: $franchisename})<-[:TRANSACTED_AT]-(client)
RETURN client.dedupestatic AS client, size((client)-[:TRANSACTED_AT]->()) AS other_transactions
ORDER BY other_transactions DESC
LIMIT 20
"""
graph.run(author_articles_query,  {"franchisename": franchisename}).to_data_frame()
# Out:
#                client  other_transactions
# 0   1.91030354806e+11                  91
# 1     1.100845365e+11                  79
# 2   1.10037086901e+11                  79
# 3   1.10021154503e+11                  70
# 4   1.91091606207e+11                  68
# 5     1.918431743e+11                  68
# 6   1.91061835402e+11                  66
# 7   1.91831161106e+11                  66
# 8   1.10021255709e+11                  64
# 9   1.46353058376e+11                  61
# 10  1.46347603142e+11                  61
# 11    2.110886841e+11                  61
# 12  1.10107654318e+11                  59
# 13  1.11100124209e+11                  59
# 14  1.91151455127e+11                  55
# 15  1.10251581209e+11                  54
# 16  1.91125901907e+11                  54
# 17  1.91103744734e+11                  52
# 18    1.930201939e+11                  52
# 19  1.10112132308e+11                  52

# %% [markdown]
# Retrieve the customers this merchant had and how many other transactions they had EXCLUDING franchisename:

# %%
author_articles_query = """
MATCH (merchant1:Merchant {franchisename: $franchisename})<-[:TRANSACTED_AT]-(client)-[:TRANSACTED_AT]->(merchant2)
WHERE merchant1<>merchant2
RETURN client.dedupestatic AS client, count((client)-[:TRANSACTED_AT]->(merchant2)) AS other_transactions
ORDER BY other_transactions DESC
LIMIT 20
"""
graph.run(author_articles_query,  {"franchisename": franchisename}).to_data_frame()
# Out:
#                client  other_transactions
# 0   1.91030354806e+11                  90
# 1   1.10037086901e+11                  78
# 2     1.100845365e+11                  78
# 3   1.10021154503e+11                  69
# 4   1.91091606207e+11                  67
# 5     1.918431743e+11                  67
# 6   1.91831161106e+11                  65
# 7   1.91061835402e+11                  65
# 8   1.10021255709e+11                  63
# 9   1.46353058376e+11                  60
# 10  1.46347603142e+11                  60
# 11    2.110886841e+11                  60
# 12  1.10107654318e+11                  58
# 13  1.11100124209e+11                  58
# 14  1.91151455127e+11                  54
# 15  1.91125901907e+11                  53
# 16  1.10251581209e+11                  53
# 17  1.91103744734e+11                  51
# 18    1.930201939e+11                  51
# 19  1.10112132308e+11                  51

# %%
collaborations_query = """
MATCH (:Merchant {franchisename: $franchisename})<-[:TRANSACTED_AT]-(client)-[:TRANSACTED_AT]->(comerchant)
RETURN comerchant.franchisename AS franchisename, count(*) AS cotransactions
ORDER BY cotransactions DESC
LIMIT 10
"""

graph.run(collaborations_query,  {"franchisename": franchisename}).to_data_frame()
# Out:
#               franchisename  cotransactions
# 0    PNP CRP DEINFERN SQUAR             116
# 1      WOOLWORTHS MAROUN SQ             111
# 2            APPLE.COM/BILL              72
# 3      Spar Broadacres Spar              72
# 4          Clicks Dairnfern              62
# 5               NETFLIX.COM              50
# 6      WOOLWORTHS- BROADACR              42
# 7      UBER SA HELP.UBER.CO              39
# 8  WOOLWORTHS MAROUN SQUARE              34
# 9      BUILDERS WH FOURWAYS              34

# %%
my_node = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c:Client)-
[:TRANSACTED_AT]-(other:Merchant)
WHERE other.franchisename<>dischem.franchisename 
RETURN dischem.franchisename, c.dedupestatic, other.franchisename, other.companyname""").data()

# %%
my_node
# Out:
# [{'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Spar Broad A',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'FOURWAYS GAR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'WOOLWORTHS- BR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Clicks Fourway',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'BUILDERS EXP C',
#   'other.companyname': 'BWH'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Spar Broadacre',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'FOURNOS FOURWA',
#   'other.companyname': 'FOURNOS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'HERBERT EVAN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'PNA DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Dainfern squar',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'THE PANTRY C',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Microsoft*Offi',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'PALM GARDENS V',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'WOOLWORTHS CED',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Hair@Kim -',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'DR KRIEL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'FOURWAYS GARDE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'SHOWMAX',
#   'other.companyname': 'SHOWMAX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'THE COMPOUND',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'NETFLIX.COM',
#   'other.companyname': 'NETFLIX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Spar Fourways',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'WOOLWORTHS MAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'GOOGLE *Google',
#   'other.companyname': 'GOOGLE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'DIS-CHEM DAINF',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'WOOLWORTHS FOU',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'FEDERAL PARKIN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'TAKEALOT ONLINE',
#   'other.companyname': 'TAKEALOT'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'WOOLWORTHS ONLINE',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10231270801e+11',
#   'other.franchisename': 'Takealot',
#   'other.companyname': 'TAKEALOT'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'DEBONAIRS DAINFERN',
#   'other.companyname': 'DEBONAIRS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'FACE LOGIC SKIN SPA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'APPLE.COM/BILL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'OCEAN BASKET',
#   'other.companyname': 'OCEAN BASKET'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'VovoTeloLonehill',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': "CARMELLA'S ON THE SQ",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQUARE',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': "HUMBLE HARRY'S THE BUZ",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'LUSH SOUTH AFRICA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'PnP Crp Deinfern SquarRE',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'CRUISEABOUT DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000229728e+11',
#   'other.franchisename': 'THE SHAVE UNION',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'FLM FOURWAYS',
#   'other.companyname': 'FLM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'DIS-CHEM THE M',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'WOOLWORTHS FOU',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'RED SQUARE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'ROMANS PIZZA',
#   'other.companyname': 'ROMANS PIZZA'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'Viva gym',
#   'other.companyname': 'VIVA GYM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'APPLE.COM/BILL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'STEERS DAINF',
#   'other.companyname': 'STEERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'WOOLWORTHS PAU',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'Checkers Leapi',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'Cltx Witkoppen',
#   'other.companyname': 'CALTEX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'Fournos Roseba',
#   'other.companyname': 'FOURNOS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'JACKSONS REA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'WELLNESS WAR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'TBS Dainfern',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'WOOLWORTHS KYA',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'LOTUS POOJA SH',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'MRP HOME-NICOL',
#   'other.companyname': 'MR PRICE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'UBER EATS',
#   'other.companyname': 'UBER EATS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'ENGEN MAIN ROA',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'Clicks Dairnfe',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'UBER TRIP',
#   'other.companyname': 'UBER'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'CALTEX WITKO',
#   'other.companyname': 'CALTEX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'FLM WILLIAM NI',
#   'other.companyname': 'FLM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'CALTEX WITKOPP',
#   'other.companyname': 'CALTEX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'WOOLWORTHS MAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'PNP CRP DEINFE',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'DIS-CHEM DAINF',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': "JACKSON'S REAL",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'PnP Crp Deinfe',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'DIS-CHEM NICOL',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'OPTIMUM HEAL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'UBER SA HELP.UBER.CO',
#   'other.companyname': 'UBER'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'AMZN DIGITAVIFTZ',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'STEERS DAINFERN',
#   'other.companyname': 'STEERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'NETFLIX.COM',
#   'other.companyname': 'NETFLIX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'AMZN DIGITAPPHT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'AMZN DIGITAMX',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'AMZN DIGITAJ',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91188171709e+11',
#   'other.franchisename': 'LOTUS POOJA SHOP CC',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SAFARI AND OUTDOOR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SPORTSMANS WAREHOUSE FS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'WELLNESS WAREHOUSE D',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'TECHEXPRESS (PTY)LTD',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'PNA DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'AZAURA JEWELLERY NIC',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQUARE',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'ALFIES PIZZERIA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'CheckersHyper Fourways',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SIX RESTAURANT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'I PAYU: Van Schaik Boo',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'ISTORE FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SPAR PINESLOPES SPAR',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'Pizza Perfect Lonehill',
#   'other.companyname': 'PIZZA PERFECT'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'WEST PACK LIFESTYLE FORWA',
#   'other.companyname': 'WEST PACK LIFE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'DR R M WEISS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'POSTNET BROADACRES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'I DHL INTERNATIONAL PT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'Spar Broadacres Spar',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'TOTAL RA LANSERIA',
#   'other.companyname': 'TOTAL'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SHAW ACADEMY SUBSCRIPT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'Clicks Fourways',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'STARBUCKS FOURWAYS M',
#   'other.companyname': 'STARBUCKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'YOYOSO FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'DIS-CHEM THE MALL FOUR',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'PNP CLT FOURWAYS',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'THE VENUE MELROSE AR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'ADOBE CREATIVE CLOUD',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQ',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'MCD Fourways ()',
#   'other.companyname': 'MCD'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SHUTTERSTOCK*--',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'WOOLWORTHS- BROADACR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'ENGEN LONEHILL BOULE',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'LA LAMPARA RESTAURANT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'SPAR MENLYNMAINE SPA',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91152212801e+11',
#   'other.franchisename': 'DIS-CHEM DAINFERN PHARMCY',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQ',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'LASERDERM DUNKELD PT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'SKIN RENEWAL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'LuluCOM',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'Checkers Pineslopes',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'NETFLIX.COM',
#   'other.companyname': 'NETFLIX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.28010539734e+11',
#   'other.franchisename': 'PAYPAL *JOSHUABRAND',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'FLM WILLIAM NICOL',
#   'other.companyname': 'FLM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'WOOLWORTHS CEDAR SQU',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'DIS-CHEM THE MALL FOUR',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'WEST PACK LIFESTYLE FO',
#   'other.companyname': 'WEST PACK LIFE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'PNA DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'LA CREMOSA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10190737808e+11',
#   'other.franchisename': 'PNP CRP FOURWAYS',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Clicks Broad Acres',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Dischem Strubens Valley',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'DRS VAN RENSBURG AND  ART',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'MOGALE CITY LOCAL MUNIC',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': "DULCE'S WILGEHEUWEL",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WILGEHEUWEL HOSPITAL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'MATRIX WAREHOUSE FOU  AYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'THE MARKET',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'ENGEN MAIN ROAD',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'FOURWAYS DRY CLEANERS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WOOLWORTHS DESIGN QUART',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'CHOP IT BROADACRES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'GARDENSHOP BROADACRES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'NORTHWORLD PHARMACY    S',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WOOLWORTHS- BROADACRES',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WOOLWORTHS FOURWAYS JHB',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'GAME FOURWAYS',
#   'other.companyname': 'GAME'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'BP BROADACRES',
#   'other.companyname': 'BP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQUAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'WOOLWORTHS OLIVEDALE JH',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Dischem Dainfern Square',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'FLM FOURWAYS',
#   'other.companyname': 'FLM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'BP FOURWAYS',
#   'other.companyname': 'BP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'NANDOS BROADACRES',
#   'other.companyname': 'NANDOS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'DR PA BETTS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Makro Riversands',
#   'other.companyname': 'MAKRO'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'MUGG & BEAN RIVERSANDS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'PNP CRP FOURWAYS',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'MUGG AND BEAN CREST',
#   'other.companyname': 'MUGG AND BEAN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'CRAZY STORE OV FOURWAY',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'SHEET STREET- FOURWAYS',
#   'other.companyname': 'SHEET STREET'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Dischem Fourways Mall',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'MUG & BEAN FOURWAYS MALL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'SLOANE STAR MEA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'The valley grill',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'SPAR NORTHWOLD SPAR',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Spar Olivedale Spar   TOR',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'GERALD FRANCIS JEWELLE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Dischem Morningside',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000107549e+11',
#   'other.franchisename': 'Spar Broadacres Spar',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'WALMART.COM',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'WOOLWORTHS- CRADLEST',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'DEALZ  KRUGERSDORP',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'NUTRI GEN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'Nail society  -',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'ROYAL JOHANNESBURG G',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': "READER'S WAREHOUSE N",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'HOTELSCOM',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91045038036e+11',
#   'other.franchisename': 'MR PRICE- CRADLE STONE',
#   'other.companyname': 'MR PRICE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'DUNKELD FRUIT WHOLESAL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'Fresh Earth Food Store',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': "FISHERMAN'S DELI DUN",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'FRUITS AND ROOTS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'BP LINDEN PARK',
#   'other.companyname': 'BP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'BUILDERS WH FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'PNP CRP LONEHILL',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'Clicks Lonehill',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'Treasure',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'VET TO PET LONEHILL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'DR D L LILLEY',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'LIFESTYLE GARDEN CENTR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': "READER'S WAREHOUSE R",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'COTTON ON MEGA FOURWAY',
#   'other.companyname': 'COTTON ON'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'takealot.com',
#   'other.companyname': 'TAKEALOT'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'RANDBURG WHOLESALE M',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'APEX DISTRIBUTORS SA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'JACKSONS REAL FOOD M',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'WOOLWORTHS LONEHILL',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'IMPALA FRUITERS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'WOOLWORTHS FOURWAYS',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10026067218e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQ',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'WOOLWORTHS FOU',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'TAKEALOT ONLINE',
#   'other.companyname': 'TAKEALOT'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'DIS-CHEM DAINFERN PHARMCY',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'SUPERBALIST',
#   'other.companyname': 'SUPERBALIST'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'ENGEN LONEHILL BOULE',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'TASHAS NICOLWAY BRYA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'TYPO NICOLWAY   _RE',
#   'other.companyname': 'TYPO'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'WOOLWORTHS NICHOL WA',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'SEATTLE ERNEST & YOUNG',
#   'other.companyname': 'SEATTLE COFFEE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'CUTE DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'EASY ON WEST',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'Fedics Ernst & Young',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'DIS-CHEM FOURWAYS MALL',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'FOREVER NEW FOURWAYS',
#   'other.companyname': 'FOREVER NEW'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': '@HOME FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91085617034e+11',
#   'other.franchisename': 'WOOLWORTHS FOURWAYS JH',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'WOOLWORTHS PAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'SuperSpar Mall',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'MAGNOLIA KWEKERY',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'VODASHOP-THE GROVE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'PNP CRP LYNNWOOD',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'MONTEXO SPUR',
#   'other.companyname': 'SPUR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'HONDA EAST RAND MALL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'ENGEN HIGHVELD  STO',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'BP NORTHRAND',
#   'other.companyname': 'BP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'GEORGES SUPERMARKET',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'Checkers Bonaero Park',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'TILETORIA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'DIS-CHEM MALL@ - C',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'TOTAL SUMMIT',
#   'other.companyname': 'TOTAL'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.20000085189e+11',
#   'other.franchisename': 'PNP CRP BLUE HILLS',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'SLOANE STAR ME',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'WOOLWORTHS MAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'WOOLWORTHS NOR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'APPLE.COM/BILL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'PnP Crp Fourwa',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'ADOBE PHOTOGPH',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'JOUBERT EN SEU',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'Spar Riverside',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'DIS-CHEM DAINF',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'PAYFAST*RapidI',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'Short Cuts Cra',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'PnP Crp Lonehi',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'LONEHILL PLAST',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'WELEDA PHARMAC',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'ARTHUR BALES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10063411407e+11',
#   'other.franchisename': 'EQUIFOX VET SUPPLIES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'CALTEX WITKOPP',
#   'other.companyname': 'CALTEX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'PnP Crp Lonehi',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'LIQUOR CITY LE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'PnP MM Fourway',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'ALCON CELLARS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'CAT BOX FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91070107508e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'WELEDA PHARMACY PINESL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'SPAR PINESLOPES SPAR',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'WOOLWORTHS LONEHILL',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'DIS-CHEM DAINFERN PHARMCY',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PnP Crp Deinfern SquarRE',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'Dainfern square',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': "ANNICA'S DESIGNER PA",
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'Clicks Dairnfern',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'Checkers Pineslopes',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PNP CLOTHING LONEHILL',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PnP Crp Lonehill',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PnP Clt Lonehill',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'Clicks Lonehill',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'OLD FASHION FISH & CHI',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'PNP CRP LONEHILL',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10020319002e+11',
#   'other.franchisename': 'MATRIX WAREHOUSE FOU',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10021255709e+11',
#   'other.franchisename': 'NETFLIX.COM',
#   'other.companyname': 'NETFLIX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10021255709e+11',
#   'other.franchisename': 'PLAYSTATIONNETWORK',
#   'other.companyname': 'PLAYSTATIONNET'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10021255709e+11',
#   'other.franchisename': 'LIQUOR CITY BROADACR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10021255709e+11',
#   'other.franchisename': 'Clicks Fourways',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10021255709e+11',
#   'other.franchisename': 'FACEBK *XMMCNRC',
#   'other.companyname': 'Unknown'},
# ...
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'PNA DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SEATTLE GROSVENOR CROS',
#   'other.companyname': 'SEATTLE COFFEE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'ENGEN BRYANSTON CONV',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SLOANE MEAT MARKET',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'WESTERN SHOPPE (PTY)',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'DRIFTERS ADVENTURE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SPAR EXPRESS GOLDEN',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SHELL GOLDEN MEADOWS F',
#   'other.companyname': 'SHELL'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'LONEHILL BOULEVARD C',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'ARAMEX INTERNATIONAL Z',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'LAURENTINA HARTEES',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'ENGEN MAIN ROAD CONV',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'FLM WILLIAM NICOL',
#   'other.companyname': 'FLM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'HI FI FOURWAYS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'ENGEN MAIN ROAD',
#   'other.companyname': 'ENGEN'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'PIZZA NOW*',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SUPER AUTOWASH',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'CALTEX WITKOPPEN CON',
#   'other.companyname': 'CALTEX'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'PIZZA AND MEZZA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'WOOLWORTHS LONEHILL',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'DINOS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'LONGMEADOW ONE STOP RE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'BRYANSTON PHARMACY.',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'BUILDERS WH NORTHGAT',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'ADENDORFF MACHINERY',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'FINE FRAGRANCE OLIVEDA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'PETS EATS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'DAINFERN BLUE BOTTLE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'OutdoorWarehouse',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'STORE & MORE FOURWAY',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SAFARI AND OUTDOOR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'RIVONIA MIDAS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQ',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'Checkers Nicolway',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SPAR BROMHOF',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'SPAR PINESLO',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'DIS-CHEM DAINF',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'BUILDERS EXP B',
#   'other.companyname': 'BWH'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'NORTHWORLD PHA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'CLEAOPATRA S',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'Clicks Fourway',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'BUILDERS WH FO',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'VISION WORKS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.91831161106e+11',
#   'other.franchisename': 'BP BROMHOF',
#   'other.companyname': 'BP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS WOO',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'GAME GREENSTON',
#   'other.companyname': 'GAME'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'GLOBAL COMPO',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'INDUSTRIAL E',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS MAR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS LON',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'APPLE.COM/BILL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'Spar Sandringham Spar',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'PnP Crp Lonehill',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'MORNINGSIDE DISPENSA',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'THE PANTRY COLLECTION',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'ABSOLUTE PETS DAINFERN',
#   'other.companyname': 'ABSOLUTE PETS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'DIS-CHEM GREENSTONE PH',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'PNP CLOTHING LONEHILL',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'Clicks Lonehill',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS SUMMIT RO',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'LITTLE RIVERSIDE CAF',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'BHARATIYAM RESTAURAN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS BENMORE G',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'FEIGELS KOSHER DELIC',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'PLUSH CARWASH',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'THE ROCK DINER KYALAMI',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS LONEHILL',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'LONEHILL ANIMAL HOSP',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'DR R.ISRAELITE VET    AL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'Clicks Dairnfern',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS MAROUN SQ',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'UNDER THE TREES TEA GR',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'SCHAFFLERS GARDEN NU',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'FROZEN FOR YOU',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'DINOS',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'TURN N TENDER DAINFERN',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'WOOLWORTHS MELROSE A',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'THE PANTRY COLLECTIO',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.910801383e+11',
#   'other.franchisename': 'PnP Crp Deinfern SquarRE',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '2.11087941934e+11',
#   'other.franchisename': 'Clicks Dairnfern',
#   'other.companyname': 'CLICKS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '2.11087941934e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'WOOLWORTHS- BROADACR',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'Spar Broadacres Spar',
#   'other.companyname': 'SPAR'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'WOOLWORTHS FOURWAYS',
#   'other.companyname': 'WOOLWORTHS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'DIS-CHEM THE MALL FOUR',
#   'other.companyname': 'DISCHEM'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'CheckersHyper Fourways',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'MILLYS TROUT STALL',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'VIVA SCHOEMANSKLOOF',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.100192803e+11',
#   'other.franchisename': 'Shoprite Komatipoort',
#   'other.companyname': 'SHOPRITE'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10198064004e+11',
#   'other.franchisename': 'BEAUTYLINE NO',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10198064004e+11',
#   'other.franchisename': 'Checkers Bryan Park',
#   'other.companyname': 'CHECKERS'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10198064004e+11',
#   'other.franchisename': 'DRIFTERS ADVENTURE',
#   'other.companyname': 'Unknown'},
#  {'dischem.franchisename': 'DIS-CHEM DAINFERN',
#   'c.dedupestatic': '1.10198064004e+11',
#   'other.franchisename': 'PNP CRP DEINFERN SQUAR',
#   'other.companyname': 'PNP'},
#  ...]

# %%
my_node = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c:Client)-
[:TRANSACTED_AT]-(other:Merchant)
WHERE other.franchisename<>dischem.franchisename 
RETURN DISTINCT(c.dedupestatic), count(DISTINCT other)""").data()
my_node
# Out:
# [{'(c.dedupestatic)': '1.10231270801e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.20000229728e+11', 'count(DISTINCT other)': 13},
#  {'(c.dedupestatic)': '1.91188171709e+11', 'count(DISTINCT other)': 40},
#  {'(c.dedupestatic)': '1.91152212801e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '1.28010539734e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10190737808e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.20000107549e+11', 'count(DISTINCT other)': 41},
#  {'(c.dedupestatic)': '1.91045038036e+11', 'count(DISTINCT other)': 9},
#  {'(c.dedupestatic)': '1.10026067218e+11', 'count(DISTINCT other)': 22},
#  {'(c.dedupestatic)': '1.91085617034e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.20000085189e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.10063411407e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.91070107508e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10020319002e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.10021255709e+11', 'count(DISTINCT other)': 63},
#  {'(c.dedupestatic)': '1.91003930508e+11', 'count(DISTINCT other)': 2},
#  {'(c.dedupestatic)': '1.91872597606e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.54000415121e+11', 'count(DISTINCT other)': 22},
#  {'(c.dedupestatic)': '1.10162135408e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.10021689806e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10170871606e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '1.91497512636e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '1.91786398406e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.30000231241e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10198812108e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.91678162104e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '1.10076955508e+11', 'count(DISTINCT other)': 9},
#  {'(c.dedupestatic)': '1.91600217208e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '2.11279273006e+11', 'count(DISTINCT other)': 43},
#  {'(c.dedupestatic)': '1.91002251601e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '1.10023145404e+11', 'count(DISTINCT other)': 22},
#  {'(c.dedupestatic)': '1.10133627403e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.10164527907e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '2.11563842534e+11', 'count(DISTINCT other)': 1},
#  {'(c.dedupestatic)': '1.10106901702e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '2.11321764607e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.10523741804e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '1.10183522702e+11', 'count(DISTINCT other)': 42},
#  {'(c.dedupestatic)': '1.10102547602e+11', 'count(DISTINCT other)': 46},
#  {'(c.dedupestatic)': '1.10164964304e+11', 'count(DISTINCT other)': 34},
#  {'(c.dedupestatic)': '1.91112607005e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.91043181204e+11', 'count(DISTINCT other)': 22},
#  {'(c.dedupestatic)': '1.91831161106e+11', 'count(DISTINCT other)': 65},
#  {'(c.dedupestatic)': '1.910801383e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '2.11087941934e+11', 'count(DISTINCT other)': 2},
#  {'(c.dedupestatic)': '1.100192803e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.10198064004e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '1.100245639e+11', 'count(DISTINCT other)': 31},
#  {'(c.dedupestatic)': '1.91086747105e+11', 'count(DISTINCT other)': 49},
#  {'(c.dedupestatic)': '1.10039125718e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '2.11038300527e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.91120351403e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.91509766207e+11', 'count(DISTINCT other)': 32},
#  {'(c.dedupestatic)': '1.10032400705e+11', 'count(DISTINCT other)': 30},
#  {'(c.dedupestatic)': '1.46319333589e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.10000514403e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '2.11232366827e+11', 'count(DISTINCT other)': 50},
#  {'(c.dedupestatic)': '1.91030354806e+11', 'count(DISTINCT other)': 90},
#  {'(c.dedupestatic)': '1.30000322651e+11', 'count(DISTINCT other)': 27},
#  {'(c.dedupestatic)': '1.10206451601e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.10152180508e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91032174406e+11', 'count(DISTINCT other)': 31},
#  {'(c.dedupestatic)': '1.10005126509e+11', 'count(DISTINCT other)': 50},
#  {'(c.dedupestatic)': '1.91064231103e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91331014907e+11', 'count(DISTINCT other)': 11},
#  {'(c.dedupestatic)': '1.10133831809e+11', 'count(DISTINCT other)': 48},
#  {'(c.dedupestatic)': '1.10112132308e+11', 'count(DISTINCT other)': 51},
#  {'(c.dedupestatic)': '1.91177447734e+11', 'count(DISTINCT other)': 13},
#  {'(c.dedupestatic)': '1.91222544704e+11', 'count(DISTINCT other)': 30},
#  {'(c.dedupestatic)': '1.91125901907e+11', 'count(DISTINCT other)': 53},
#  {'(c.dedupestatic)': '1.20000484226e+11', 'count(DISTINCT other)': 45},
#  {'(c.dedupestatic)': '1.10128643501e+11', 'count(DISTINCT other)': 9},
#  {'(c.dedupestatic)': '1.10078422701e+11', 'count(DISTINCT other)': 24},
#  {'(c.dedupestatic)': '1.46304135566e+11', 'count(DISTINCT other)': 2},
#  {'(c.dedupestatic)': '1.10074695002e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.10071529705e+11', 'count(DISTINCT other)': 10},
#  {'(c.dedupestatic)': '1.91084371003e+11', 'count(DISTINCT other)': 46},
#  {'(c.dedupestatic)': '6.00000196586e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '1.10024976407e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '1.71000034915e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.10263463605e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.91538473603e+11', 'count(DISTINCT other)': 42},
#  {'(c.dedupestatic)': '1.10379052709e+11', 'count(DISTINCT other)': 32},
#  {'(c.dedupestatic)': '1.20000424228e+11', 'count(DISTINCT other)': 3},
#  {'(c.dedupestatic)': '1.20000561919e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.46347603142e+11', 'count(DISTINCT other)': 60},
#  {'(c.dedupestatic)': '1.10136135803e+11', 'count(DISTINCT other)': 33},
#  {'(c.dedupestatic)': '1.10082156506e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.10184621518e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '1.91082712407e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.10027712818e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '1.10092186904e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10023183918e+11', 'count(DISTINCT other)': 2},
#  {'(c.dedupestatic)': '1.100845365e+11', 'count(DISTINCT other)': 78},
#  {'(c.dedupestatic)': '1.914887537e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.101262651e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '2.11063388903e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.91065807103e+11', 'count(DISTINCT other)': 30},
#  {'(c.dedupestatic)': '1.10158187504e+11', 'count(DISTINCT other)': 28},
#  {'(c.dedupestatic)': '1.10065990307e+11', 'count(DISTINCT other)': 6},
#  {'(c.dedupestatic)': '1.91007885834e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.2000013148e+11', 'count(DISTINCT other)': 13},
#  {'(c.dedupestatic)': '1.20000323379e+11', 'count(DISTINCT other)': 1},
#  {'(c.dedupestatic)': '1.20000061525e+11', 'count(DISTINCT other)': 44},
#  {'(c.dedupestatic)': '1.10197498604e+11', 'count(DISTINCT other)': 34},
#  {'(c.dedupestatic)': '1.10095094601e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10059967803e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.101767448e+11', 'count(DISTINCT other)': 38},
#  {'(c.dedupestatic)': '1.10210395702e+11', 'count(DISTINCT other)': 33},
#  {'(c.dedupestatic)': '1.100777816e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.91049475405e+11', 'count(DISTINCT other)': 41},
#  {'(c.dedupestatic)': '1.91671393036e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.91331850202e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '2.11191889003e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.30000191456e+11', 'count(DISTINCT other)': 9},
#  {'(c.dedupestatic)': '1.100953944e+11', 'count(DISTINCT other)': 45},
#  {'(c.dedupestatic)': '1.91342194036e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '1.91020216101e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.10159232104e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.100519421e+11', 'count(DISTINCT other)': 34},
#  {'(c.dedupestatic)': '1.10071005005e+11', 'count(DISTINCT other)': 32},
#  {'(c.dedupestatic)': '1.91686100607e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.10186158009e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.91108742502e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '1.911399887e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.91079034209e+11', 'count(DISTINCT other)': 41},
#  {'(c.dedupestatic)': '1.91095142606e+11', 'count(DISTINCT other)': 25},
#  {'(c.dedupestatic)': '1.10027771407e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.46353058376e+11', 'count(DISTINCT other)': 60},
#  {'(c.dedupestatic)': '1.10207538301e+11', 'count(DISTINCT other)': 36},
#  {'(c.dedupestatic)': '1.10107654318e+11', 'count(DISTINCT other)': 58},
#  {'(c.dedupestatic)': '1.91647502904e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '1.10151103704e+11', 'count(DISTINCT other)': 46},
#  {'(c.dedupestatic)': '1.10157092208e+11', 'count(DISTINCT other)': 28},
#  {'(c.dedupestatic)': '1.10109795709e+11', 'count(DISTINCT other)': 39},
#  {'(c.dedupestatic)': '1.91643032604e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91109053101e+11', 'count(DISTINCT other)': 49},
#  {'(c.dedupestatic)': '1.91613934107e+11', 'count(DISTINCT other)': 31},
#  {'(c.dedupestatic)': '1.91101148802e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.91278053205e+11', 'count(DISTINCT other)': 30},
#  {'(c.dedupestatic)': '1.91095778609e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.10455148201e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.91462784202e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.10022132902e+11', 'count(DISTINCT other)': 24},
#  {'(c.dedupestatic)': '1.10179865005e+11', 'count(DISTINCT other)': 23},
#  {'(c.dedupestatic)': '1.91003580434e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.91091606207e+11', 'count(DISTINCT other)': 67},
#  {'(c.dedupestatic)': '1.11100124209e+11', 'count(DISTINCT other)': 58},
#  {'(c.dedupestatic)': '1.91066886901e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '2.11497704705e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.20000291055e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.91741357309e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91620902201e+11', 'count(DISTINCT other)': 11},
#  {'(c.dedupestatic)': '1.91215176e+11', 'count(DISTINCT other)': 27},
#  {'(c.dedupestatic)': '1.10250540401e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.10173740405e+11', 'count(DISTINCT other)': 31},
#  {'(c.dedupestatic)': '1.91107159402e+11', 'count(DISTINCT other)': 3},
#  {'(c.dedupestatic)': '1.10127422102e+11', 'count(DISTINCT other)': 23},
#  {'(c.dedupestatic)': '1.91073165601e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.10028678109e+11', 'count(DISTINCT other)': 25},
#  {'(c.dedupestatic)': '1.10251581209e+11', 'count(DISTINCT other)': 53},
#  {'(c.dedupestatic)': '1.93002780605e+11', 'count(DISTINCT other)': 44},
#  {'(c.dedupestatic)': '1.94058486805e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.91316741507e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '1.91067210303e+11', 'count(DISTINCT other)': 4},
#  {'(c.dedupestatic)': '1.20000122779e+11', 'count(DISTINCT other)': 29},
#  {'(c.dedupestatic)': '1.2000030484e+11', 'count(DISTINCT other)': 14},
#  {'(c.dedupestatic)': '1.91375434102e+11', 'count(DISTINCT other)': 37},
#  {'(c.dedupestatic)': '2.110886841e+11', 'count(DISTINCT other)': 60},
#  {'(c.dedupestatic)': '1.91355522634e+11', 'count(DISTINCT other)': 6},
#  {'(c.dedupestatic)': '1.93007582734e+11', 'count(DISTINCT other)': 9},
#  {'(c.dedupestatic)': '1.20000179835e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10004198603e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10138642818e+11', 'count(DISTINCT other)': 32},
#  {'(c.dedupestatic)': '6.00000265206e+11', 'count(DISTINCT other)': 2},
#  {'(c.dedupestatic)': '1.10184818702e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.54000342545e+11', 'count(DISTINCT other)': 45},
#  {'(c.dedupestatic)': '1.5100011539e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.10265834708e+11', 'count(DISTINCT other)': 49},
#  {'(c.dedupestatic)': '1.91082969103e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.100705055e+11', 'count(DISTINCT other)': 24},
#  {'(c.dedupestatic)': '1.10136220304e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '1.91225440705e+11', 'count(DISTINCT other)': 42},
#  {'(c.dedupestatic)': '1.10020789807e+11', 'count(DISTINCT other)': 13},
#  {'(c.dedupestatic)': '2.11384999134e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.10114570604e+11', 'count(DISTINCT other)': 46},
#  {'(c.dedupestatic)': '2.11452850304e+11', 'count(DISTINCT other)': 37},
#  {'(c.dedupestatic)': '1.91061835402e+11', 'count(DISTINCT other)': 65},
#  {'(c.dedupestatic)': '1.93007807505e+11', 'count(DISTINCT other)': 31},
#  {'(c.dedupestatic)': '1.10027003302e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10028177606e+11', 'count(DISTINCT other)': 20},
#  {'(c.dedupestatic)': '6.00000357947e+11', 'count(DISTINCT other)': 1},
#  {'(c.dedupestatic)': '1.91017143309e+11', 'count(DISTINCT other)': 33},
#  {'(c.dedupestatic)': '1.10122748808e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.91850061006e+11', 'count(DISTINCT other)': 8},
#  {'(c.dedupestatic)': '1.5100011616e+11', 'count(DISTINCT other)': 39},
#  {'(c.dedupestatic)': '1.10119797801e+11', 'count(DISTINCT other)': 6},
#  {'(c.dedupestatic)': '1.91124022307e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.91082672409e+11', 'count(DISTINCT other)': 28},
#  {'(c.dedupestatic)': '1.91357920205e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.91357542806e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.91979173902e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.91111449203e+11', 'count(DISTINCT other)': 15},
#  {'(c.dedupestatic)': '1.91087949007e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91102690604e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.91041937501e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.30000323957e+11', 'count(DISTINCT other)': 46},
#  {'(c.dedupestatic)': '1.930201939e+11', 'count(DISTINCT other)': 51},
#  {'(c.dedupestatic)': '1.91042878308e+11', 'count(DISTINCT other)': 5},
#  {'(c.dedupestatic)': '1.91479217405e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.91103744734e+11', 'count(DISTINCT other)': 51},
#  {'(c.dedupestatic)': '1.102309435e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.91149041436e+11', 'count(DISTINCT other)': 33},
#  {'(c.dedupestatic)': '1.10021154503e+11', 'count(DISTINCT other)': 69},
#  {'(c.dedupestatic)': '1.91133005304e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.10017838908e+11', 'count(DISTINCT other)': 28},
#  {'(c.dedupestatic)': '1.91046194509e+11', 'count(DISTINCT other)': 19},
#  {'(c.dedupestatic)': '1.91058925027e+11', 'count(DISTINCT other)': 27},
#  {'(c.dedupestatic)': '1.91121173634e+11', 'count(DISTINCT other)': 22},
#  {'(c.dedupestatic)': '1.93008845208e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.91053673603e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.91090050307e+11', 'count(DISTINCT other)': 41},
#  {'(c.dedupestatic)': '2.11199384301e+11', 'count(DISTINCT other)': 17},
#  {'(c.dedupestatic)': '1.10065641205e+11', 'count(DISTINCT other)': 26},
#  {'(c.dedupestatic)': '1.10037086901e+11', 'count(DISTINCT other)': 78},
#  {'(c.dedupestatic)': '1.91151455127e+11', 'count(DISTINCT other)': 54},
#  {'(c.dedupestatic)': '1.10090793803e+11', 'count(DISTINCT other)': 25},
#  {'(c.dedupestatic)': '1.102608471e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.91001657227e+11', 'count(DISTINCT other)': 4},
#  {'(c.dedupestatic)': '1.10027883507e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.918431743e+11', 'count(DISTINCT other)': 67},
#  {'(c.dedupestatic)': '1.10078235707e+11', 'count(DISTINCT other)': 38},
#  {'(c.dedupestatic)': '1.101198444e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.10065692306e+11', 'count(DISTINCT other)': 5},
#  {'(c.dedupestatic)': '2.11587576602e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10009938303e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.10029036305e+11', 'count(DISTINCT other)': 5},
#  {'(c.dedupestatic)': '1.91100151227e+11', 'count(DISTINCT other)': 11},
#  {'(c.dedupestatic)': '1.10096863404e+11', 'count(DISTINCT other)': 18},
#  {'(c.dedupestatic)': '1.10121447502e+11', 'count(DISTINCT other)': 32},
#  {'(c.dedupestatic)': '1.101280939e+11', 'count(DISTINCT other)': 16},
#  {'(c.dedupestatic)': '1.91180577036e+11', 'count(DISTINCT other)': 50},
#  {'(c.dedupestatic)': '1.91003979407e+11', 'count(DISTINCT other)': 28},
#  {'(c.dedupestatic)': '1.30000300538e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91238162702e+11', 'count(DISTINCT other)': 35},
#  {'(c.dedupestatic)': '1.10059264802e+11', 'count(DISTINCT other)': 10},
#  {'(c.dedupestatic)': '1.510001274e+11', 'count(DISTINCT other)': 24},
#  {'(c.dedupestatic)': '1.280146713e+11', 'count(DISTINCT other)': 7},
#  {'(c.dedupestatic)': '1.10093956509e+11', 'count(DISTINCT other)': 12},
#  {'(c.dedupestatic)': '1.10087801809e+11', 'count(DISTINCT other)': 21},
#  {'(c.dedupestatic)': '1.91988706136e+11', 'count(DISTINCT other)': 15}]

# %%
my_node = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c:Client)-
[othertransaction:TRANSACTED_AT]-(other:Merchant)
WHERE other.franchisename<>dischem.franchisename 
RETURN DISTINCT(other.franchisename) AS other_franchisename, count(othertransaction) AS number_transactions""").data()
my_node
# Out:
# [{'other_franchisename': 'Spar Broad A', 'number_transactions': 2},
#  {'other_franchisename': 'FOURWAYS GAR', 'number_transactions': 9},
#  {'other_franchisename': 'WOOLWORTHS- BR', 'number_transactions': 13},
#  {'other_franchisename': 'Clicks Fourway', 'number_transactions': 4},
#  {'other_franchisename': 'BUILDERS EXP C', 'number_transactions': 5},
#  {'other_franchisename': 'Spar Broadacre', 'number_transactions': 19},
#  {'other_franchisename': 'FOURNOS FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'HERBERT EVAN', 'number_transactions': 4},
#  {'other_franchisename': 'PNA DAINFERN', 'number_transactions': 34},
#  {'other_franchisename': 'Dainfern squar', 'number_transactions': 5},
#  {'other_franchisename': 'THE PANTRY C', 'number_transactions': 1},
#  {'other_franchisename': 'Microsoft*Offi', 'number_transactions': 2},
#  {'other_franchisename': 'PALM GARDENS V', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS CED', 'number_transactions': 3},
#  {'other_franchisename': 'Hair@Kim -', 'number_transactions': 1},
#  {'other_franchisename': 'DR KRIEL', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS GARDE', 'number_transactions': 1},
#  {'other_franchisename': 'SHOWMAX', 'number_transactions': 3},
#  {'other_franchisename': 'THE COMPOUND', 'number_transactions': 1},
#  {'other_franchisename': 'NETFLIX.COM', 'number_transactions': 50},
#  {'other_franchisename': 'Spar Fourways', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS MAR', 'number_transactions': 33},
#  {'other_franchisename': 'GOOGLE *Google', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM DAINF', 'number_transactions': 22},
#  {'other_franchisename': 'WOOLWORTHS FOU', 'number_transactions': 7},
#  {'other_franchisename': 'FEDERAL PARKIN', 'number_transactions': 8},
#  {'other_franchisename': 'TAKEALOT ONLINE', 'number_transactions': 22},
#  {'other_franchisename': 'WOOLWORTHS ONLINE', 'number_transactions': 4},
#  {'other_franchisename': 'Takealot', 'number_transactions': 2},
#  {'other_franchisename': 'PNP CRP DEINFERN SQUAR', 'number_transactions': 116},
#  {'other_franchisename': 'DEBONAIRS DAINFERN', 'number_transactions': 8},
#  {'other_franchisename': 'FACE LOGIC SKIN SPA', 'number_transactions': 6},
#  {'other_franchisename': 'APPLE.COM/BILL', 'number_transactions': 72},
#  {'other_franchisename': 'OCEAN BASKET', 'number_transactions': 4},
#  {'other_franchisename': 'VovoTeloLonehill', 'number_transactions': 1},
#  {'other_franchisename': "CARMELLA'S ON THE SQ", 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQUARE',
#   'number_transactions': 34},
#  {'other_franchisename': "HUMBLE HARRY'S THE BUZ", 'number_transactions': 2},
#  {'other_franchisename': 'LUSH SOUTH AFRICA', 'number_transactions': 2},
#  {'other_franchisename': 'PnP Crp Deinfern SquarRE',
#   'number_transactions': 26},
#  {'other_franchisename': 'CRUISEABOUT DAINFERN', 'number_transactions': 1},
#  {'other_franchisename': 'THE SHAVE UNION', 'number_transactions': 1},
#  {'other_franchisename': 'FLM FOURWAYS', 'number_transactions': 19},
#  {'other_franchisename': 'DIS-CHEM THE M', 'number_transactions': 4},
#  {'other_franchisename': 'RED SQUARE', 'number_transactions': 1},
#  {'other_franchisename': 'ROMANS PIZZA', 'number_transactions': 1},
#  {'other_franchisename': 'Viva gym', 'number_transactions': 1},
#  {'other_franchisename': 'STEERS DAINF', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PAU', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Leapi', 'number_transactions': 6},
#  {'other_franchisename': 'Cltx Witkoppen', 'number_transactions': 11},
#  {'other_franchisename': 'Fournos Roseba', 'number_transactions': 1},
#  {'other_franchisename': 'JACKSONS REA', 'number_transactions': 1},
#  {'other_franchisename': 'WELLNESS WAR', 'number_transactions': 2},
#  {'other_franchisename': 'TBS Dainfern', 'number_transactions': 6},
#  {'other_franchisename': 'WOOLWORTHS KYA', 'number_transactions': 3},
#  {'other_franchisename': 'LOTUS POOJA SH', 'number_transactions': 1},
#  {'other_franchisename': 'MRP HOME-NICOL', 'number_transactions': 1},
#  {'other_franchisename': 'UBER EATS', 'number_transactions': 8},
#  {'other_franchisename': 'ENGEN MAIN ROA', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dairnfe', 'number_transactions': 14},
#  {'other_franchisename': 'UBER TRIP', 'number_transactions': 8},
#  {'other_franchisename': 'CALTEX WITKO', 'number_transactions': 7},
#  {'other_franchisename': 'FLM WILLIAM NI', 'number_transactions': 3},
#  {'other_franchisename': 'CALTEX WITKOPP', 'number_transactions': 7},
#  {'other_franchisename': 'PNP CRP DEINFE', 'number_transactions': 27},
#  {'other_franchisename': "JACKSON'S REAL", 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Deinfe', 'number_transactions': 6},
#  {'other_franchisename': 'DIS-CHEM NICOL', 'number_transactions': 3},
#  {'other_franchisename': 'OPTIMUM HEAL', 'number_transactions': 1},
#  {'other_franchisename': 'UBER SA HELP.UBER.CO', 'number_transactions': 39},
#  {'other_franchisename': 'AMZN DIGITAVIFTZ', 'number_transactions': 1},
#  {'other_franchisename': 'STEERS DAINFERN', 'number_transactions': 8},
#  {'other_franchisename': 'AMZN DIGITAPPHT', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAMX', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAJ', 'number_transactions': 1},
#  {'other_franchisename': 'LOTUS POOJA SHOP CC', 'number_transactions': 1},
#  {'other_franchisename': 'SAFARI AND OUTDOOR', 'number_transactions': 2},
#  {'other_franchisename': 'SPORTSMANS WAREHOUSE FS', 'number_transactions': 4},
#  {'other_franchisename': 'WELLNESS WAREHOUSE D', 'number_transactions': 4},
#  {'other_franchisename': 'TECHEXPRESS (PTY)LTD', 'number_transactions': 1},
#  {'other_franchisename': 'AZAURA JEWELLERY NIC', 'number_transactions': 1},
#  {'other_franchisename': 'ALFIES PIZZERIA', 'number_transactions': 1},
#  {'other_franchisename': 'CheckersHyper Fourways', 'number_transactions': 16},
#  {'other_franchisename': 'SIX RESTAURANT', 'number_transactions': 13},
#  {'other_franchisename': 'I PAYU: Van Schaik Boo', 'number_transactions': 1},
#  {'other_franchisename': 'ISTORE FOURWAYS', 'number_transactions': 5},
#  {'other_franchisename': 'SPAR PINESLOPES SPAR', 'number_transactions': 21},
#  {'other_franchisename': 'Pizza Perfect Lonehill', 'number_transactions': 2},
#  {'other_franchisename': 'WEST PACK LIFESTYLE FORWA',
#   'number_transactions': 2},
#  {'other_franchisename': 'DR R M WEISS', 'number_transactions': 1},
#  {'other_franchisename': 'POSTNET BROADACRES', 'number_transactions': 5},
#  {'other_franchisename': 'I DHL INTERNATIONAL PT', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Broadacres Spar', 'number_transactions': 72},
#  {'other_franchisename': 'TOTAL RA LANSERIA', 'number_transactions': 2},
#  {'other_franchisename': 'SHAW ACADEMY SUBSCRIPT', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Fourways', 'number_transactions': 13},
#  {'other_franchisename': 'STARBUCKS FOURWAYS M', 'number_transactions': 7},
#  {'other_franchisename': 'YOYOSO FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM THE MALL FOUR', 'number_transactions': 21},
#  {'other_franchisename': 'PNP CLT FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'THE VENUE MELROSE AR', 'number_transactions': 1},
#  {'other_franchisename': 'ADOBE CREATIVE CLOUD', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQ', 'number_transactions': 111},
#  {'other_franchisename': 'MCD Fourways ()', 'number_transactions': 7},
#  {'other_franchisename': 'SHUTTERSTOCK*--', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BROADACR', 'number_transactions': 42},
#  {'other_franchisename': 'ENGEN LONEHILL BOULE', 'number_transactions': 20},
#  {'other_franchisename': 'LA LAMPARA RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MENLYNMAINE SPA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM DAINFERN PHARMCY',
#   'number_transactions': 29},
#  {'other_franchisename': 'LASERDERM DUNKELD PT', 'number_transactions': 1},
#  {'other_franchisename': 'SKIN RENEWAL', 'number_transactions': 1},
#  {'other_franchisename': 'LuluCOM', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Pineslopes', 'number_transactions': 16},
#  {'other_franchisename': 'PAYPAL *JOSHUABRAND', 'number_transactions': 1},
#  {'other_franchisename': 'FLM WILLIAM NICOL', 'number_transactions': 8},
#  {'other_franchisename': 'WOOLWORTHS CEDAR SQU', 'number_transactions': 14},
#  {'other_franchisename': 'WEST PACK LIFESTYLE FO', 'number_transactions': 19},
#  {'other_franchisename': 'LA CREMOSA', 'number_transactions': 9},
#  {'other_franchisename': 'PNP CRP FOURWAYS', 'number_transactions': 31},
#  {'other_franchisename': 'Clicks Broad Acres', 'number_transactions': 32},
#  {'other_franchisename': 'Dischem Strubens Valley', 'number_transactions': 1},
#  {'other_franchisename': 'DRS VAN RENSBURG AND  ART',
#   'number_transactions': 1},
#  {'other_franchisename': 'MOGALE CITY LOCAL MUNIC', 'number_transactions': 1},
#  {'other_franchisename': "DULCE'S WILGEHEUWEL", 'number_transactions': 1},
#  {'other_franchisename': 'WILGEHEUWEL HOSPITAL', 'number_transactions': 1},
#  {'other_franchisename': 'MATRIX WAREHOUSE FOU  AYS',
#   'number_transactions': 2},
#  {'other_franchisename': 'THE MARKET', 'number_transactions': 15},
#  {'other_franchisename': 'ENGEN MAIN ROAD', 'number_transactions': 3},
#  {'other_franchisename': 'FOURWAYS DRY CLEANERS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS DESIGN QUART', 'number_transactions': 1},
#  {'other_franchisename': 'CHOP IT BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'GARDENSHOP BROADACRES', 'number_transactions': 1},
#  {'other_franchisename': 'NORTHWORLD PHARMACY    S', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BROADACRES', 'number_transactions': 18},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS JHB', 'number_transactions': 2},
#  {'other_franchisename': 'GAME FOURWAYS', 'number_transactions': 8},
#  {'other_franchisename': 'BP BROADACRES', 'number_transactions': 14},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQUAR', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS OLIVEDALE JH', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Dainfern Square', 'number_transactions': 3},
#  {'other_franchisename': 'BP FOURWAYS', 'number_transactions': 11},
#  {'other_franchisename': 'NANDOS BROADACRES', 'number_transactions': 2},
#  {'other_franchisename': 'DR PA BETTS', 'number_transactions': 1},
#  {'other_franchisename': 'Makro Riversands', 'number_transactions': 25},
#  {'other_franchisename': 'MUGG & BEAN RIVERSANDS', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN CREST', 'number_transactions': 1},
#  {'other_franchisename': 'CRAZY STORE OV FOURWAY', 'number_transactions': 4},
#  {'other_franchisename': 'SHEET STREET- FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Fourways Mall', 'number_transactions': 1},
#  {'other_franchisename': 'MUG & BEAN FOURWAYS MALL', 'number_transactions': 1},
#  {'other_franchisename': 'SLOANE STAR MEA', 'number_transactions': 1},
#  {'other_franchisename': 'The valley grill', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR NORTHWOLD SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Olivedale Spar   TOR',
#   'number_transactions': 1},
#  {'other_franchisename': 'GERALD FRANCIS JEWELLE', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Morningside', 'number_transactions': 1},
#  {'other_franchisename': 'WALMART.COM', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- CRADLEST', 'number_transactions': 1},
#  {'other_franchisename': 'DEALZ  KRUGERSDORP', 'number_transactions': 1},
#  {'other_franchisename': 'NUTRI GEN', 'number_transactions': 1},
#  {'other_franchisename': 'Nail society  -', 'number_transactions': 1},
#  {'other_franchisename': 'ROYAL JOHANNESBURG G', 'number_transactions': 2},
#  {'other_franchisename': "READER'S WAREHOUSE N", 'number_transactions': 2},
#  {'other_franchisename': 'HOTELSCOM', 'number_transactions': 1},
#  {'other_franchisename': 'MR PRICE- CRADLE STONE', 'number_transactions': 1},
#  {'other_franchisename': 'DUNKELD FRUIT WHOLESAL', 'number_transactions': 2},
#  {'other_franchisename': 'Fresh Earth Food Store', 'number_transactions': 1},
#  {'other_franchisename': "FISHERMAN'S DELI DUN", 'number_transactions': 1},
#  {'other_franchisename': 'FRUITS AND ROOTS', 'number_transactions': 4},
#  {'other_franchisename': 'BP LINDEN PARK', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH FOURWAYS', 'number_transactions': 34},
#  {'other_franchisename': 'PNP CRP LONEHILL', 'number_transactions': 33},
#  {'other_franchisename': 'Clicks Lonehill', 'number_transactions': 19},
#  {'other_franchisename': 'Treasure', 'number_transactions': 4},
#  {'other_franchisename': 'VET TO PET LONEHILL', 'number_transactions': 4},
#  {'other_franchisename': 'DR D L LILLEY', 'number_transactions': 1},
#  {'other_franchisename': 'LIFESTYLE GARDEN CENTR', 'number_transactions': 2},
#  {'other_franchisename': "READER'S WAREHOUSE R", 'number_transactions': 2},
#  {'other_franchisename': 'COTTON ON MEGA FOURWAY', 'number_transactions': 7},
#  {'other_franchisename': 'takealot.com', 'number_transactions': 2},
#  {'other_franchisename': 'RANDBURG WHOLESALE M', 'number_transactions': 5},
#  {'other_franchisename': 'APEX DISTRIBUTORS SA', 'number_transactions': 1},
#  {'other_franchisename': 'JACKSONS REAL FOOD M', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS LONEHILL', 'number_transactions': 34},
#  {'other_franchisename': 'IMPALA FRUITERS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS', 'number_transactions': 26},
#  {'other_franchisename': 'SUPERBALIST', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS NICOLWAY BRYA', 'number_transactions': 4},
#  {'other_franchisename': 'TYPO NICOLWAY   _RE', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS NICHOL WA', 'number_transactions': 13},
#  {'other_franchisename': 'SEATTLE ERNEST & YOUNG', 'number_transactions': 1},
#  {'other_franchisename': 'CUTE DAINFERN', 'number_transactions': 7},
#  {'other_franchisename': 'EASY ON WEST', 'number_transactions': 1},
#  {'other_franchisename': 'Fedics Ernst & Young', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM FOURWAYS MALL', 'number_transactions': 8},
#  {'other_franchisename': 'FOREVER NEW FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': '@HOME FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS JH', 'number_transactions': 8},
#  {'other_franchisename': 'WOOLWORTHS PAR', 'number_transactions': 1},
#  {'other_franchisename': 'SuperSpar Mall', 'number_transactions': 1},
#  {'other_franchisename': 'MAGNOLIA KWEKERY', 'number_transactions': 1},
#  {'other_franchisename': 'VODASHOP-THE GROVE', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP LYNNWOOD', 'number_transactions': 1},
#  {'other_franchisename': 'MONTEXO SPUR', 'number_transactions': 3},
#  {'other_franchisename': 'HONDA EAST RAND MALL', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN HIGHVELD  STO', 'number_transactions': 1},
#  {'other_franchisename': 'BP NORTHRAND', 'number_transactions': 1},
#  {'other_franchisename': 'GEORGES SUPERMARKET', 'number_transactions': 3},
#  {'other_franchisename': 'Checkers Bonaero Park', 'number_transactions': 1},
#  {'other_franchisename': 'TILETORIA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MALL@ - C', 'number_transactions': 3},
#  {'other_franchisename': 'TOTAL SUMMIT', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP BLUE HILLS', 'number_transactions': 5},
#  {'other_franchisename': 'SLOANE STAR ME', 'number_transactions': 3},
#  {'other_franchisename': 'WOOLWORTHS NOR', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Fourwa', 'number_transactions': 2},
#  {'other_franchisename': 'ADOBE PHOTOGPH', 'number_transactions': 1},
#  {'other_franchisename': 'JOUBERT EN SEU', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Riverside', 'number_transactions': 1},
#  {'other_franchisename': 'PAYFAST*RapidI', 'number_transactions': 1},
#  {'other_franchisename': 'Short Cuts Cra', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Lonehi', 'number_transactions': 5},
#  {'other_franchisename': 'LONEHILL PLAST', 'number_transactions': 4},
#  {'other_franchisename': 'WELEDA PHARMAC', 'number_transactions': 4},
#  {'other_franchisename': 'ARTHUR BALES', 'number_transactions': 1},
#  {'other_franchisename': 'EQUIFOX VET SUPPLIES', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY LE', 'number_transactions': 3},
#  {'other_franchisename': 'PnP MM Fourway', 'number_transactions': 2},
#  {'other_franchisename': 'ALCON CELLARS', 'number_transactions': 1},
#  {'other_franchisename': 'CAT BOX FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'WELEDA PHARMACY PINESL', 'number_transactions': 15},
#  {'other_franchisename': 'Dainfern square', 'number_transactions': 20},
#  {'other_franchisename': "ANNICA'S DESIGNER PA", 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dairnfern', 'number_transactions': 62},
#  {'other_franchisename': 'PNP CLOTHING LONEHILL', 'number_transactions': 4},
#  {'other_franchisename': 'PnP Crp Lonehill', 'number_transactions': 12},
#  {'other_franchisename': 'PnP Clt Lonehill', 'number_transactions': 1},
#  {'other_franchisename': 'OLD FASHION FISH & CHI', 'number_transactions': 3},
#  {'other_franchisename': 'MATRIX WAREHOUSE FOU', 'number_transactions': 2},
#  {'other_franchisename': 'PLAYSTATIONNETWORK', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY BROADACR', 'number_transactions': 3},
#  {'other_franchisename': 'FACEBK *XMMCNRC', 'number_transactions': 1},
#  {'other_franchisename': 'TOY KINGDOM FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'FROZEN FOR YOU', 'number_transactions': 13},
#  {'other_franchisename': 'FACEBK *EUBGYQWC', 'number_transactions': 1},
#  {'other_franchisename': 'THE COMPOUNDING PHAR', 'number_transactions': 3},
#  {'other_franchisename': 'COTTON ON KIDS FOURWAY', 'number_transactions': 1},
#  {'other_franchisename': 'SPORTSMANS WAREHOUSE', 'number_transactions': 17},
#  {'other_franchisename': 'Clicks Cedar Road', 'number_transactions': 6},
#  {'other_franchisename': 'I AFRIHOST.COM', 'number_transactions': 9},
#  {'other_franchisename': 'GOOGLE *SERVICES', 'number_transactions': 3},
#  {'other_franchisename': "JONNY'S", 'number_transactions': 12},
#  {'other_franchisename': 'PURE WOODLANDS SPA', 'number_transactions': 1},
#  {'other_franchisename': 'PNA CRADLESTONE', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *MAPMQWC', 'number_transactions': 1},
#  {'other_franchisename': 'FISHAWAYS DAINFERN', 'number_transactions': 3},
#  {'other_franchisename': 'HOME STUFF HILLFOX', 'number_transactions': 1},
#  {'other_franchisename': 'OSTERIA  (PTY) LTD', 'number_transactions': 1},
#  {'other_franchisename': 'BLAIR ATHOL VILLAGE', 'number_transactions': 1},
#  {'other_franchisename': 'YUPPIECHEF ONLINE', 'number_transactions': 2},
#  {'other_franchisename': 'ST ALBANS COLLEGE', 'number_transactions': 1},
#  {'other_franchisename': 'KAUAI WHOLEFOODS FRA', 'number_transactions': 1},
#  {'other_franchisename': 'INTERPARK MENLYN', 'number_transactions': 1},
#  {'other_franchisename': 'BLAIR ATHOL CLUB HOU', 'number_transactions': 1},
#  {'other_franchisename': 'SpotifyZA', 'number_transactions': 6},
#  {'other_franchisename': 'KINGS MEAT DELI LYNW', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN Mktp USSYYR', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *GQWRCRSC', 'number_transactions': 1},
#  {'other_franchisename': 'SORBET DAINFERN DRYB', 'number_transactions': 3},
#  {'other_franchisename': 'MCD Menlyn RC ()', 'number_transactions': 1},
#  {'other_franchisename': 'CNA FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'HE CROSS TRAINER FOU', 'number_transactions': 1},
#  {'other_franchisename': 'GEMINI OCTOPUS', 'number_transactions': 1},
#  {'other_franchisename': 'EDGARS  FOURWAYS', 'number_transactions': 9},
#  {'other_franchisename': 'TOTALSPORTS FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL FERNGATE', 'number_transactions': 21},
#  {'other_franchisename': "ALFIE'S RESTAURANT", 'number_transactions': 1},
#  {'other_franchisename': 'CULINARY TABLE', 'number_transactions': 4},
#  {'other_franchisename': 'FACEBK *CKFRSC', 'number_transactions': 1},
#  {'other_franchisename': 'SHOPIFY*', 'number_transactions': 1},
#  {'other_franchisename': 'AIRBNB * HMHRHD', 'number_transactions': 1},
#  {'other_franchisename': 'THE PANTRY COLLECTIO', 'number_transactions': 12},
#  {'other_franchisename': 'AIRBNB * HMFNZJX', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *ANHFRC', 'number_transactions': 1},
#  {'other_franchisename': 'Tops Lanseria', 'number_transactions': 1},
#  {'other_franchisename': 'MY PARTY SUPPLIES', 'number_transactions': 2},
#  {'other_franchisename': 'LONEHILL BOULEVARD C', 'number_transactions': 11},
#  {'other_franchisename': 'HILLSIDE TAVERN', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *ZAGZQEC', 'number_transactions': 1},
#  {'other_franchisename': 'Hilton Hotel Windhoek', 'number_transactions': 1},
#  {'other_franchisename': 'I MTN SERVICE PROVIDER', 'number_transactions': 1},
#  {'other_franchisename': 'NEWS CAFE WOOD', 'number_transactions': 1},
#  {'other_franchisename': 'MVG COOPERAT', 'number_transactions': 1},
#  {'other_franchisename': 'Mall of Africa', 'number_transactions': 6},
#  {'other_franchisename': 'FACTORIE FOURWAYS CROS', 'number_transactions': 1},
#  {'other_franchisename': 'TOPS PINESLOPES', 'number_transactions': 3},
#  {'other_franchisename': 'CHICKEN LICKEN FOURW', 'number_transactions': 1},
#  {'other_franchisename': 'FEDERAL PARKING SERVIC', 'number_transactions': 20},
#  {'other_franchisename': 'BURGER KING - FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Intellepark', 'number_transactions': 1},
#  {'other_franchisename': 'I PROTEA MET SAGE', 'number_transactions': 1},
#  {'other_franchisename': 'NANDOS LEAPI', 'number_transactions': 4},
#  {'other_franchisename': 'MUGG & BEAN', 'number_transactions': 3},
#  {'other_franchisename': 'TS AFRIKA NE', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEA', 'number_transactions': 4},
#  {'other_franchisename': 'MCD Fourways', 'number_transactions': 5},
#  {'other_franchisename': 'TSAFRIKA *', 'number_transactions': 1},
#  {'other_franchisename': 'KFC FOURWAYS', 'number_transactions': 11},
#  {'other_franchisename': 'TS AFRIKA NESTLE', 'number_transactions': 1},
#  {'other_franchisename': 'MICROSOFT#G', 'number_transactions': 1},
#  {'other_franchisename': 'TSAFRIKA   *', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM NICOLWAY', 'number_transactions': 8},
#  {'other_franchisename': 'EXCLUSIVE BOOKS AIRP', 'number_transactions': 2},
#  {'other_franchisename': 'KULULA VITALITY', 'number_transactions': 5},
#  {'other_franchisename': 'TSAFRIKA HEADOFFICE', 'number_transactions': 2},
#  {'other_franchisename': 'VETSMART DAINF', 'number_transactions': 1},
#  {'other_franchisename': 'DURBAN SEAFOOD', 'number_transactions': 1},
#  {'other_franchisename': "ANNICA'S DES", 'number_transactions': 2},
#  {'other_franchisename': 'INK-LINK BRA', 'number_transactions': 1},
#  {'other_franchisename': 'PNP EXPRESS BR', 'number_transactions': 3},
#  {'other_franchisename': 'STATEMENT BEAU', 'number_transactions': 1},
#  {'other_franchisename': 'VIDA E CAFFE', 'number_transactions': 1},
#  {'other_franchisename': 'Perx Agency -', 'number_transactions': 1},
#  {'other_franchisename': 'MR PRICE SPORT', 'number_transactions': 5},
#  {'other_franchisename': 'EDGARS', 'number_transactions': 2},
#  {'other_franchisename': 'FOREVER NEW CU', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH FO', 'number_transactions': 6},
#  {'other_franchisename': 'FOSCHINI FOURW', 'number_transactions': 1},
#  {'other_franchisename': 'DAVID BENN CC.', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP ON NIC', 'number_transactions': 2},
#  {'other_franchisename': 'Brandons Pool Care', 'number_transactions': 3},
#  {'other_franchisename': 'MEDELLIN BARBERS', 'number_transactions': 1},
#  {'other_franchisename': 'GLOBAL GOLF GLOVES C', 'number_transactions': 3},
#  {'other_franchisename': 'TOP VENDING  PTY LTD', 'number_transactions': 2},
#  {'other_franchisename': 'TIGER OF SWEDEN SAND', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR SUNNINGHILL', 'number_transactions': 2},
#  {'other_franchisename': 'POSTNET SUNNINGHILL', 'number_transactions': 1},
#  {'other_franchisename': 'EXCLUSIVE BOOKS NICO', 'number_transactions': 2},
#  {'other_franchisename': 'NORTH STAR S/S', 'number_transactions': 5},
#  {'other_franchisename': 'CATTLE BARON SKUKUZA', 'number_transactions': 1},
#  {'other_franchisename': 'TINDLOVU CAFE', 'number_transactions': 1},
#  {'other_franchisename': 'CHATZ CONNEC', 'number_transactions': 1},
#  {'other_franchisename': 'LONEHILL ANIMAL HOSP', 'number_transactions': 6},
#  {'other_franchisename': 'SABC TV Licences', 'number_transactions': 2},
#  {'other_franchisename': 'BARGAIN BOOKS FOURWA', 'number_transactions': 6},
#  {'other_franchisename': 'SUPA QUICK FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'CHAMDOR FAKTRY SALES', 'number_transactions': 6},
#  {'other_franchisename': 'WOOLWORTHS DOUGLASDA', 'number_transactions': 7},
#  {'other_franchisename': 'A VAN DER MERWE INC', 'number_transactions': 1},
#  {'other_franchisename': 'MOZAMBIK SUNNINGHILL', 'number_transactions': 3},
#  {'other_franchisename': 'ENGEN PALM STOP SERV', 'number_transactions': 3},
#  {'other_franchisename': 'BERLINER BUTCHERY', 'number_transactions': 9},
#  {'other_franchisename': 'FAMILY PET CENTRE FO', 'number_transactions': 3},
#  {'other_franchisename': 'DIS-CHEM NORTHGATE', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CLOTHING FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'HUMBLE HARRYS', 'number_transactions': 5},
#  {'other_franchisename': 'SASOL THE RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'JNS GALAL', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *UBER BV', 'number_transactions': 2},
#  {'other_franchisename': 'PAYPAL *LINKEDIN', 'number_transactions': 1},
#  {'other_franchisename': 'NUTRITIONAL SOLUTIONS', 'number_transactions': 1},
#  {'other_franchisename': 'THE FACE AND BODY PLAC', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *SUCCESSFULM', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *INTERRDATIN', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MORNINGSI', 'number_transactions': 2},
#  {'other_franchisename': 'KIRBY DYNAMIC PROMOTIO', 'number_transactions': 1},
#  {'other_franchisename': 'ACSA JIA', 'number_transactions': 7},
#  {'other_franchisename': 'PALAZZO HOTEL REST', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS CEDAR SQUAR', 'number_transactions': 3},
#  {'other_franchisename': 'BLOOMBERG.COM', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *TRAINLINE', 'number_transactions': 1},
#  {'other_franchisename': 'ADAMS DISCOUNT CNT', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BENMORE GARS', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS DESIGN QU', 'number_transactions': 5},
#  {'other_franchisename': 'PAYPAL *KHATHUTSHEL', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *FUNKYSALES', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS RIVONIA JHB', 'number_transactions': 1},
#  {'other_franchisename': 'DRL HEALTH SOLUTIONS', 'number_transactions': 1},
#  {'other_franchisename': 'D J*WALL-ST-JOURNAL', 'number_transactions': 2},
#  {'other_franchisename': 'DRS VAN RENSBURG AND', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *SPOTIFY', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *ROYAL MAIL', 'number_transactions': 1},
#  {'other_franchisename': 'I SAGE SA SAGE', 'number_transactions': 1},
#  {'other_franchisename': 'VALUECO THE GL', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FAMILY WIN', 'number_transactions': 1},
#  {'other_franchisename': 'SERVEST PARKIN', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Columbi', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL SWARTGOU', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Dain', 'number_transactions': 5},
#  {'other_franchisename': 'BP MONTE', 'number_transactions': 19},
#  {'other_franchisename': 'EXCLUSIVE VIRG', 'number_transactions': 1},
#  {'other_franchisename': '@ PARKS RESTAU', 'number_transactions': 1},
#  {'other_franchisename': 'MCD Kyalami (', 'number_transactions': 2},
#  {'other_franchisename': 'CHECKERS COLUM', 'number_transactions': 1},
#  {'other_franchisename': 'HARD ROCK JOHA', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN LONEHILL', 'number_transactions': 5},
#  {'other_franchisename': 'THE ROCK CARNE', 'number_transactions': 1},
#  {'other_franchisename': 'CHECKERS LEAPI', 'number_transactions': 2},
#  {'other_franchisename': '@ PARKS RESTAURANT A', 'number_transactions': 2},
#  {'other_franchisename': 'BOLT.EU /O/', 'number_transactions': 2},
#  {'other_franchisename': 'CHAMDOR FAKTRY', 'number_transactions': 1},
#  {'other_franchisename': 'HJM Hair and B', 'number_transactions': 1},
#  {'other_franchisename': 'Que', 'number_transactions': 1},
#  {'other_franchisename': 'FACE LOGIC S', 'number_transactions': 3},
#  {'other_franchisename': 'MAKRO RIVERSANDS', 'number_transactions': 14},
#  {'other_franchisename': 'GARDENSHOP BROADACRE', 'number_transactions': 14},
#  {'other_franchisename': 'MR PRICE APPAREL- FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH RIVONIA   ONI',
#   'number_transactions': 1},
#  {'other_franchisename': 'ADOBE PHOTOGPHY PLAN', 'number_transactions': 3},
#  {'other_franchisename': 'COTTON ON FOURWAYS CROSSI',
#   'number_transactions': 2},
#  {'other_franchisename': 'NP-MER', 'number_transactions': 1},
#  {'other_franchisename': 'FOOD LOVERS AT LIFESTY', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY LONEHILL', 'number_transactions': 10},
#  {'other_franchisename': 'DIS-CHEM SUNNINGHILL', 'number_transactions': 2},
#  {'other_franchisename': 'CLicks SunningHill', 'number_transactions': 1},
#  {'other_franchisename': 'Bryanston Market at Mi', 'number_transactions': 1},
#  {'other_franchisename': 'C E Becker Transport S', 'number_transactions': 1},
#  {'other_franchisename': 'GROW WILD', 'number_transactions': 1},
#  {'other_franchisename': 'COFFEE AND CRUNCH', 'number_transactions': 1},
#  {'other_franchisename': 'LUDWIG S ROSES EGOLI', 'number_transactions': 1},
#  {'other_franchisename': 'DOONHOLM NURSERY', 'number_transactions': 1},
#  {'other_franchisename': 'AMAZING CRYSTALS CC', 'number_transactions': 1},
#  {'other_franchisename': 'FARMERS MARKET PINES', 'number_transactions': 6},
#  {'other_franchisename': 'THE MEAT BOSS', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR CITY LEAPING', 'number_transactions': 4},
#  {'other_franchisename': 'VETSMART DAINFERN', 'number_transactions': 7},
#  {'other_franchisename': 'DULCE CAFE FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'Bidvest', 'number_transactions': 2},
#  {'other_franchisename': 'FRANCOS PIZZERIA & T', 'number_transactions': 1},
#  {'other_franchisename': 'TOP HAT BAKERY AND T', 'number_transactions': 1},
#  {'other_franchisename': 'CENTURION GATE TOTAL S', 'number_transactions': 2},
#  {'other_franchisename': 'OH MY CAKE', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Leaping Frog', 'number_transactions': 26},
#  {'other_franchisename': 'TOTAL SANDTON DRIVE', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM THE CLUB PHAR', 'number_transactions': 1},
#  {'other_franchisename': 'PIZZA PERFECT', 'number_transactions': 1},
#  {'other_franchisename': 'M AND B LONEHILL', 'number_transactions': 3},
#  {'other_franchisename': 'NSRI', 'number_transactions': 1},
#  {'other_franchisename': 'TravelStart', 'number_transactions': 3},
#  {'other_franchisename': 'EN ROUTE LUGGAGE', 'number_transactions': 1},
#  {'other_franchisename': 'DR ALLEM INC ILLOVO', 'number_transactions': 1},
#  {'other_franchisename': 'I Chrome SA', 'number_transactions': 2},
#  {'other_franchisename': 'OLIVES & PLATES WBS', 'number_transactions': 1},
#  {'other_franchisename': 'TOPS PINESLO', 'number_transactions': 2},
#  {'other_franchisename': 'SPAR PINESLO', 'number_transactions': 8},
#  {'other_franchisename': 'YUME', 'number_transactions': 6},
#  {'other_franchisename': 'SHELL VILLAGE', 'number_transactions': 1},
#  {'other_franchisename': 'Wishy Washy Ca', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*CANDY DELI', 'number_transactions': 1},
#  {'other_franchisename': 'TIME SQUARE', 'number_transactions': 1},
#  {'other_franchisename': 'SBG (PTY) LT', 'number_transactions': 1},
#  {'other_franchisename': 'Internat', 'number_transactions': 1},
#  {'other_franchisename': 'Dough An', 'number_transactions': 1},
#  {'other_franchisename': 'Choppies Phaka', 'number_transactions': 1},
#  {'other_franchisename': 'BP BEYERS NA', 'number_transactions': 1},
#  {'other_franchisename': 'BARBER LOU FOU', 'number_transactions': 1},
#  {'other_franchisename': 'MARKHAM FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'BLING FONES', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX WITKOPPEN CON', 'number_transactions': 5},
#  {'other_franchisename': 'Gautrain CTLS Local', 'number_transactions': 2},
#  {'other_franchisename': 'Cltx Witkoppen Motors', 'number_transactions': 20},
#  {'other_franchisename': 'MR PRICE HOME- ROSEBAN', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM SANDTON CITY', 'number_transactions': 4},
#  {'other_franchisename': 'HOUSE OF ISIS ROSEBA', 'number_transactions': 1},
#  {'other_franchisename': 'PATA PATA AFRICAN RE', 'number_transactions': 1},
#  {'other_franchisename': 'REMAX ROSENBANK', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR GABS VILLAGE SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'MUG AND BEAN RIVERWALK', 'number_transactions': 1},
#  {'other_franchisename': 'EXCLUSIVE BOOKS FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'BARAZZA RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL RA VILLAGE', 'number_transactions': 2},
#  {'other_franchisename': 'BEM BOM BEDFORDVIEW', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL DOUGLASDALE_NE', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*M HAIR STUDIO', 'number_transactions': 1},
#  {'other_franchisename': 'THE LOFT NAIL SALON', 'number_transactions': 4},
#  {'other_franchisename': 'CARWASH DESIGN Q', 'number_transactions': 1},
#  {'other_franchisename': 'Dropbox RDHSSPTK', 'number_transactions': 1},
#  {'other_franchisename': 'GAS SA RETAIL FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'Cltx Cedar Road', 'number_transactions': 3},
#  {'other_franchisename': 'SIMPLY FRENCH', 'number_transactions': 1},
#  {'other_franchisename': 'PAINT EMPORIUM FOURWAY', 'number_transactions': 17},
#  {'other_franchisename': 'CHARTWELL VET', 'number_transactions': 9},
#  {'other_franchisename': 'LIQUOR CITY BROADARC', 'number_transactions': 11},
#  {'other_franchisename': 'PNP EXPRESS BROAD', 'number_transactions': 7},
#  {'other_franchisename': 'ENGEN GEORGE STORRAR', 'number_transactions': 1},
#  {'other_franchisename': 'VAN HEERDEN APTEEK N  END',
#   'number_transactions': 1},
#  {'other_franchisename': 'DAINFERN COUNTRY CL', 'number_transactions': 7},
#  {'other_franchisename': 'THE GOLFERS CLUB (PT  WD', 'number_transactions': 1},
#  {'other_franchisename': 'FEVER TREE BAR', 'number_transactions': 1},
#  {'other_franchisename': 'BISTRO BISTRO', 'number_transactions': 1},
#  {'other_franchisename': 'GOOGLE *Google Music', 'number_transactions': 4},
#  {'other_franchisename': 'WOOLWORTHS CROWTHORN', 'number_transactions': 2},
#  {'other_franchisename': 'Nandos Kyalami', 'number_transactions': 3},
#  {'other_franchisename': 'TWO IN ONE CHINESE AND', 'number_transactions': 2},
#  {'other_franchisename': 'PAYFAST*Creed Nutritio', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS EXP CEDARSQ', 'number_transactions': 12},
#  {'other_franchisename': 'DOPPIO ZERO PINESLOPES', 'number_transactions': 4},
#  {'other_franchisename': 'DR IGH JONES', 'number_transactions': 2},
#  {'other_franchisename': 'NATURAL EFFECTS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MORNING G', 'number_transactions': 2},
#  {'other_franchisename': 'TRAFALGAR PROPERTY M', 'number_transactions': 1},
#  {'other_franchisename': 'HI FI FOURWAYS', 'number_transactions': 6},
#  {'other_franchisename': 'POSTNET DAINFERN', 'number_transactions': 6},
#  {'other_franchisename': 'WIMPY KSIA', 'number_transactions': 2},
#  {'other_franchisename': 'WINSTON PARK CSTORE', 'number_transactions': 1},
#  {'other_franchisename': 'POINT WATER SPORTS CLU', 'number_transactions': 1},
#  {'other_franchisename': 'THE DAILY BAGEL', 'number_transactions': 1},
#  {'other_franchisename': 'SEATTLE COFFEE MT EDGE', 'number_transactions': 1},
#  {'other_franchisename': "READER'S WAR", 'number_transactions': 1},
#  {'other_franchisename': 'TOPS ROSEHILL', 'number_transactions': 1},
#  {'other_franchisename': 'OLD KHAKI FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'POETRY FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'HAMLEYS FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'CHECKERS FERND', 'number_transactions': 1},
#  {'other_franchisename': 'LOVISA F', 'number_transactions': 1},
#  {'other_franchisename': 'UBER SA HELP.U', 'number_transactions': 14},
#  {'other_franchisename': 'MR PRICE HOME- THE DES', 'number_transactions': 3},
#  {'other_franchisename': 'OCEAN BASKET KILLARNEY', 'number_transactions': 1},
#  {'other_franchisename': 'MRP HOME FOURWAYS', 'number_transactions': 5},
#  {'other_franchisename': 'FOSCHINI FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'XNEELO', 'number_transactions': 1},
#  {'other_franchisename': 'PIZA E VINO ROSEBANK', 'number_transactions': 2},
#  {'other_franchisename': 'CALTEX CAMBRIDGE', 'number_transactions': 2},
#  {'other_franchisename': 'FISHMONGER BRYANSTON', 'number_transactions': 1},
#  {'other_franchisename': 'MSFT * EAJWT', 'number_transactions': 1},
#  {'other_franchisename': 'ANDICCIO .', 'number_transactions': 4},
#  {'other_franchisename': 'GRAZIA S FINE FOOD A', 'number_transactions': 1},
#  {'other_franchisename': 'WIMPY ESPLANADE', 'number_transactions': 1},
#  {'other_franchisename': 'EXPRESSVPN', 'number_transactions': 1},
#  {'other_franchisename': 'MYTHOS MONTE CASINO', 'number_transactions': 1},
#  {'other_franchisename': 'GOOGLE *GSUITE_constoc', 'number_transactions': 1},
#  {'other_franchisename': 'THE FARM NURSE', 'number_transactions': 1},
#  {'other_franchisename': 'Audible*PU', 'number_transactions': 1},
#  {'other_franchisename': 'FROZEN FOR Y', 'number_transactions': 2},
#  {'other_franchisename': 'SUNNINGHILL RA', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL RA POT', 'number_transactions': 1},
#  {'other_franchisename': 'Kindle Unltd*G', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN MAIN R', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MORNI', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL SANDTON', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS FLO', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAL', 'number_transactions': 1},
#  {'other_franchisename': 'Just Love Stit', 'number_transactions': 1},
#  {'other_franchisename': 'NESPRESSO MA', 'number_transactions': 1},
#  {'other_franchisename': 'EVENT FOODS', 'number_transactions': 2},
#  {'other_franchisename': 'EXPO TRENDS CC', 'number_transactions': 1},
#  {'other_franchisename': 'BASECUT STUDIO', 'number_transactions': 7},
#  {'other_franchisename': 'MZP ENTERPRI', 'number_transactions': 1},
#  {'other_franchisename': 'THE LOFT NAIL', 'number_transactions': 2},
#  {'other_franchisename': 'EDGARS RSQ D', 'number_transactions': 3},
#  {'other_franchisename': 'Audible*WNKY', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BROOK', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PTY', 'number_transactions': 1},
#  {'other_franchisename': 'BERLINER BUT', 'number_transactions': 3},
#  {'other_franchisename': 'BLACK HORSE RE', 'number_transactions': 1},
#  {'other_franchisename': 'I SnapScan Alexs Car W', 'number_transactions': 4},
#  {'other_franchisename': 'DR BARROW', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BROOKLYN', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BROOKLYN', 'number_transactions': 1},
#  {'other_franchisename': 'TBS Brooklyn', 'number_transactions': 1},
#  {'other_franchisename': 'PAYFAST*Froggie', 'number_transactions': 1},
#  {'other_franchisename': 'POS CHARTW   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'MTN FOURWAYS L', 'number_transactions': 1},
#  {'other_franchisename': 'DR L STOCKRIGT & ASS', 'number_transactions': 1},
#  {'other_franchisename': 'CORNERSTONE PHARMACY B', 'number_transactions': 1},
#  {'other_franchisename': 'COTTON ON FOURWAYS CRO', 'number_transactions': 6},
#  {'other_franchisename': 'BELIFORE ITALIAN DELI', 'number_transactions': 2},
#  {'other_franchisename': 'ENGEN MAIN ROAD CONV', 'number_transactions': 5},
#  {'other_franchisename': 'BILTONG AT ZA PINESL', 'number_transactions': 2},
#  {'other_franchisename': 'Spar King Fisher Spar', 'number_transactions': 4},
#  {'other_franchisename': 'OLD KHAKHI NICOLWAY', 'number_transactions': 1},
#  {'other_franchisename': 'Z TWO', 'number_transactions': 2},
#  {'other_franchisename': 'PNP CRP ON NICOL', 'number_transactions': 5},
#  {'other_franchisename': 'FLM FERNDALE', 'number_transactions': 2},
#  {'other_franchisename': 'CRAZY PETS FERNDALE', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Bryan Park', 'number_transactions': 3},
#  {'other_franchisename': "JACK'S PAINT AND HAR", 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BRYAN PA', 'number_transactions': 4},
#  {'other_franchisename': 'PINESLOPES TYRES', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dougasdale', 'number_transactions': 1},
#  {'other_franchisename': 'EUROPA DOUGLASDALE', 'number_transactions': 2},
#  {'other_franchisename': 'THE VILLAGE CRAFT MARK', 'number_transactions': 1},
#  {'other_franchisename': 'TYPO FOURWAYS MALL', 'number_transactions': 1},
#  {'other_franchisename': 'MTN FOURWAYS LTALK', 'number_transactions': 1},
#  {'other_franchisename': 'Superga Fourways', 'number_transactions': 1},
#  {'other_franchisename': 'COFFEE EXCHANGE PARK', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN DOUGLASDALE', 'number_transactions': 5},
#  {'other_franchisename': 'Clicks Benmore Gardens', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CLOTHING BENMORE G', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BENMORE G', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Nicolway', 'number_transactions': 5},
#  {'other_franchisename': 'PNP CLOTHING NICOLWAY', 'number_transactions': 3},
#  {'other_franchisename': 'Cltx Kingfisher S S    Fo',
#   'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS DOU', 'number_transactions': 4},
#  {'other_franchisename': 'Spar Olivedale', 'number_transactions': 2},
#  {'other_franchisename': 'GAME BEL-AIR', 'number_transactions': 2},
#  {'other_franchisename': 'Tops Fourways', 'number_transactions': 3},
#  {'other_franchisename': 'POS Clicks   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'LONEHILL ANIMA', 'number_transactions': 1},
#  {'other_franchisename': 'STARBUCKS FO', 'number_transactions': 2},
#  {'other_franchisename': 'PLANKTON CAS', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*KATHY THOM', 'number_transactions': 1},
#  {'other_franchisename': 'I SnapScan SAJ', 'number_transactions': 1},
#  {'other_franchisename': 'Dr R B Lomba', 'number_transactions': 1},
#  {'other_franchisename': 'BP WILLIAM N', 'number_transactions': 3},
#  {'other_franchisename': 'SPAR PINESLOPE', 'number_transactions': 2},
#  {'other_franchisename': 'COTTON ON FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'CASH CONVERTER', 'number_transactions': 1},
#  {'other_franchisename': 'BARGAIN BOOKS', 'number_transactions': 1},
#  {'other_franchisename': 'Glasfit Four', 'number_transactions': 1},
#  {'other_franchisename': 'LESLEYS', 'number_transactions': 1},
#  {'other_franchisename': 'DIKHOLOLO', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *FRANKRO', 'number_transactions': 1},
#  {'other_franchisename': 'Amazon Prime*GKLKJ', 'number_transactions': 1},
#  {'other_franchisename': 'JEAN COUTU #', 'number_transactions': 1},
#  {'other_franchisename': 'LANCET MORNINGSIDE SIT', 'number_transactions': 1},
#  {'other_franchisename': 'ACDC FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Mr D Food', 'number_transactions': 2},
#  {'other_franchisename': 'PAYPAL *RICARDOSENE', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *CANCOOPER', 'number_transactions': 1},
#  {'other_franchisename': 'Mr D Food ZA', 'number_transactions': 5},
#  {'other_franchisename': 'PHARMAPRIX #', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *M', 'number_transactions': 1},
#  {'other_franchisename': 'ENTR OUELLET ET RAYMON', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BBQ DOWNS', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN VAN BUUREN', 'number_transactions': 1},
#  {'other_franchisename': 'SLOANE MEAT MARKET', 'number_transactions': 5},
#  {'other_franchisename': 'LIQUOR CITY G/NR', 'number_transactions': 3},
#  {'other_franchisename': 'JOSES RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'LANSERIA AIRPORT PARKI', 'number_transactions': 5},
#  {'other_franchisename': 'DUNES', 'number_transactions': 2},
#  {'other_franchisename': "PAPINO'S", 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM CANAL WALK', 'number_transactions': 2},
#  {'other_franchisename': 'INFLUENCE CC', 'number_transactions': 1},
#  {'other_franchisename': 'EYE Q SOMERSET WEST', 'number_transactions': 1},
#  {'other_franchisename': 'gotinder.com/help', 'number_transactions': 2},
#  {'other_franchisename': 'CONFAIT HAIRDRESSING', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Fourways Pharm', 'number_transactions': 7},
#  {'other_franchisename': 'MCD Boskruin (', 'number_transactions': 1},
#  {'other_franchisename': 'F H CHAMBERL', 'number_transactions': 1},
#  {'other_franchisename': 'LEROY MERLIN L', 'number_transactions': 1},
#  {'other_franchisename': 'HOUSE OF PAI', 'number_transactions': 1},
#  {'other_franchisename': 'TIMBERCITY BLA', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS EXP N', 'number_transactions': 1},
#  {'other_franchisename': 'DA MALTA (PTY)', 'number_transactions': 1},
#  {'other_franchisename': 'ROCK COTTAGE P', 'number_transactions': 1},
#  {'other_franchisename': 'MEDICARE BOSKR', 'number_transactions': 1},
#  {'other_franchisename': 'Universal Pa', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM RANDR', 'number_transactions': 1},
#  {'other_franchisename': 'GELMAR (PTY)LT', 'number_transactions': 1},
#  {'other_franchisename': 'BP BRYANSTON', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX WITKOPPEN C STO', 'number_transactions': 5},
#  {'other_franchisename': 'SEATTLE GROSVENOR CROS', 'number_transactions': 3},
#  {'other_franchisename': 'ENGEN BRYANSTON CONV', 'number_transactions': 2},
#  {'other_franchisename': 'WESTERN SHOPPE (PTY)', 'number_transactions': 1},
#  {'other_franchisename': 'DRIFTERS ADVENTURE', 'number_transactions': 2},
#  {'other_franchisename': 'SPAR EXPRESS GOLDEN', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL GOLDEN MEADOWS F', 'number_transactions': 1},
#  {'other_franchisename': 'ARAMEX INTERNATIONAL Z', 'number_transactions': 1},
#  {'other_franchisename': 'LAURENTINA HARTEES', 'number_transactions': 1},
# ...
#  {'other_franchisename': 'CALTEX CAMBRID', 'number_transactions': 2},
#  {'other_franchisename': 'TOPS PARKMORE', 'number_transactions': 1},
#  {'other_franchisename': 'MAXWELLS', 'number_transactions': 1},
#  {'other_franchisename': 'MICROSOFT*CONSOLE -MONTH', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MORNINGSIDE', 'number_transactions': 2},
#  {'other_franchisename': 'AMZN DIGITAIVNZ', 'number_transactions': 1},
#  {'other_franchisename': 'KINDLE SVCUVSWS', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAABHLA', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITADAW', 'number_transactions': 1},
#  {'other_franchisename': 'MCDONALDS RIVONIA', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR WEDGE', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN RIVONIA', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS SUNNINGHI', 'number_transactions': 2},
#  {'other_franchisename': 'GOOGLE *GSUITE_KUZWAYO', 'number_transactions': 1},
#  {'other_franchisename': 'PERFECT HEALTH', 'number_transactions': 2},
#  {'other_franchisename': 'ABSOLUTE PETS KYALAM', 'number_transactions': 1},
#  {'other_franchisename': 'CRAZY STORE LONEHIL   EHI',
#   'number_transactions': 1},
#  {'other_franchisename': 'IC INTERNET', 'number_transactions': 1},
#  {'other_franchisename': 'WELLNESS WAREHOUSE K  LAM',
#   'number_transactions': 1},
#  {'other_franchisename': 'Checkers Kyalami', 'number_transactions': 7},
#  {'other_franchisename': 'ENGEN ERASSMUND', 'number_transactions': 1},
#  {'other_franchisename': 'JALA SUPERETTE EN SL', 'number_transactions': 1},
#  {'other_franchisename': 'CROWTHORNE HARDWARE', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Crowthorne', 'number_transactions': 1},
#  {'other_franchisename': 'PIATTO RESTAURANT', 'number_transactions': 3},
#  {'other_franchisename': 'NANDOS BRYANSTON DT', 'number_transactions': 1},
#  {'other_franchisename': 'LA PARADA CONSTANTIA', 'number_transactions': 1},
#  {'other_franchisename': 'BRAND COLLECTIVE HOU', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL CANAL WALK', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Midrand', 'number_transactions': 1},
#  {'other_franchisename': 'COMAIR LIMITED', 'number_transactions': 6},
#  {'other_franchisename': 'FAITHFUL TO NATURE', 'number_transactions': 3},
#  {'other_franchisename': 'HENLEY CROWTHRONE SE', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN DAINFE', 'number_transactions': 11},
#  {'other_franchisename': 'UCook', 'number_transactions': 1},
#  {'other_franchisename': 'Nandos Waterfall Drive', 'number_transactions': 2},
#  {'other_franchisename': 'PIZZA HUT DAINFERN', 'number_transactions': 3},
#  {'other_franchisename': 'Clicks Windsor Way NCC', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Blue Hi', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR CARL', 'number_transactions': 1},
#  {'other_franchisename': 'COMPASS GROU', 'number_transactions': 2},
#  {'other_franchisename': 'LIQUOR CITY CL', 'number_transactions': 1},
#  {'other_franchisename': 'PEP  MIDRA', 'number_transactions': 2},
#  {'other_franchisename': 'BA BATTERY', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP BLUE H', 'number_transactions': 1},
#  {'other_franchisename': 'OLIFANTSFONTEI', 'number_transactions': 1},
#  {'other_franchisename': 'Kids Milestone', 'number_transactions': 1},
#  {'other_franchisename': 'PHOSA S TAVERN', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL BLUE HIL', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Crowthorn', 'number_transactions': 3},
#  {'other_franchisename': 'CheckersHyper', 'number_transactions': 4},
#  {'other_franchisename': 'CROWTHORNE S', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- FO', 'number_transactions': 2},
#  {'other_franchisename': 'ROOTS OLIEVENH', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL PIETERSBURG', 'number_transactions': 1},
#  {'other_franchisename': 'FISHAWAYS MASINGITA  C', 'number_transactions': 1},
#  {'other_franchisename': 'BIDVEST WALTONS', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM DAINFERN PH', 'number_transactions': 1},
#  {'other_franchisename': 'CHICKEN LICKEN TEMBI', 'number_transactions': 1},
#  {'other_franchisename': 'COMPASS GROUP SA PTY', 'number_transactions': 2},
#  {'other_franchisename': 'SASOL BLUE HILLS', 'number_transactions': 1},
#  {'other_franchisename': "LET'S EAT CANTEEN (PTY", 'number_transactions': 2},
#  {'other_franchisename': 'SOAPY RIDES CAR WASH', 'number_transactions': 1},
#  {'other_franchisename': 'KFC BLUE HILLS', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR MALL', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Mall', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR CITY TO', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN TOWER', 'number_transactions': 1},
#  {'other_franchisename': 'DIE WINDPOMP L', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Mnandi Sp', 'number_transactions': 1},
#  {'other_franchisename': 'HEALTH MED PHA', 'number_transactions': 1},
#  {'other_franchisename': 'TOP VENDING P', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL CIRCLE C', 'number_transactions': 1},
#  {'other_franchisename': 'COPPER LEAF GO', 'number_transactions': 1},
#  {'other_franchisename': 'COPPERLEAF GOL', 'number_transactions': 1},
#  {'other_franchisename': 'Tops Mnandi', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BLUE HILL', 'number_transactions': 1},
#  {'other_franchisename': 'WEST PACK LIFESTYLE MA', 'number_transactions': 2},
#  {'other_franchisename': 'SUPERSPAR MALL AT', 'number_transactions': 3},
#  {'other_franchisename': 'MR PRICE- FOREST HILL', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Forest Hill', 'number_transactions': 2},
#  {'other_franchisename': 'TOTAL KNOPJESLAAGTE', 'number_transactions': 4},
#  {'other_franchisename': 'WOOLWORTHS- FOREST H', 'number_transactions': 2},
#  {'other_franchisename': 'ENGEN FLAMINGO', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN TOWERS EAST R', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Mnandi Spar', 'number_transactions': 1},
#  {'other_franchisename': 'COPPER LEAF GOLF EST', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM BOKSBURG', 'number_transactions': 1},
#  {'other_franchisename': 'COTTON ON MEGA', 'number_transactions': 1},
#  {'other_franchisename': 'POS MEGA F   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'POS COTTON   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'REEBOK ATTERBU', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS MALL OF', 'number_transactions': 1},
#  {'other_franchisename': 'KUNG FU KITC', 'number_transactions': 1},
#  {'other_franchisename': 'KROONVAAL  ST', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN KROONV', 'number_transactions': 1},
#  {'other_franchisename': 'MEI HUA SUSH', 'number_transactions': 1},
#  {'other_franchisename': 'PAPACHINOS BRO', 'number_transactions': 3},
#  {'other_franchisename': 'Movies AT Mont', 'number_transactions': 3},
#  {'other_franchisename': 'Clicks Broad A', 'number_transactions': 5},
#  {'other_franchisename': 'Checkers Pines', 'number_transactions': 4},
#  {'other_franchisename': 'SKYSTOP CONVIENCE CNT NTR',
#   'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Cedar Road', 'number_transactions': 4},
#  {'other_franchisename': 'SMOKE DADDYS', 'number_transactions': 1},
#  {'other_franchisename': 'CheckersHyper FourwaysS', 'number_transactions': 6},
#  {'other_franchisename': 'BP BEYERS NAUDE DRIV', 'number_transactions': 2},
#  {'other_franchisename': 'Movies AT Monte', 'number_transactions': 6},
#  {'other_franchisename': 'PAPACHINOS BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'PINESLOPES PTY LT', 'number_transactions': 1},
#  {'other_franchisename': 'BURGER KING - KYALAMI', 'number_transactions': 2},
#  {'other_franchisename': 'ORIENTAL STYLE', 'number_transactions': 1},
#  {'other_franchisename': 'CHEVALETE', 'number_transactions': 2},
#  {'other_franchisename': 'LONEHILL ANIMAL HOSP  AL', 'number_transactions': 1},
#  {'other_franchisename': 'Waltons Fourways', 'number_transactions': 4},
#  {'other_franchisename': 'COUNTRY MEAT BUTCHERIE', 'number_transactions': 2},
#  {'other_franchisename': 'PETERVALE PHARMACY', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PAULSHOF JH', 'number_transactions': 1},
#  {'other_franchisename': 'Sunninghill Medical Ce', 'number_transactions': 1},
#  {'other_franchisename': 'PAPA PRONTO', 'number_transactions': 4},
#  {'other_franchisename': 'FOURWAYS VETERINARY HO', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR LINDEN KWIK SPA', 'number_transactions': 1},
#  {'other_franchisename': 'GoWild Accessories pty', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR PINESLOPES', 'number_transactions': 9},
#  {'other_franchisename': 'FIORE GARDEN CENTRE SO', 'number_transactions': 1},
#  {'other_franchisename': 'KNICK KNACK KIOSK', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS CAPE TOWN A', 'number_transactions': 2},
#  {'other_franchisename': 'Trends t/a Lad', 'number_transactions': 1},
#  {'other_franchisename': 'COMPUTER MAN', 'number_transactions': 1},
#  {'other_franchisename': 'SIMPLY SKIN', 'number_transactions': 1},
#  {'other_franchisename': 'SONSTRAAL PHAR', 'number_transactions': 1},
#  {'other_franchisename': 'CHATEAU GATEAU', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR SONSTRAAL', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX COBBLE WALK', 'number_transactions': 1},
#  {'other_franchisename': 'CAFE DE LA MONTE', 'number_transactions': 1},
#  {'other_franchisename': 'Cltx CobbleWalk', 'number_transactions': 1},
#  {'other_franchisename': 'OASIS WATER DURBANVILL', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP PINEHURST', 'number_transactions': 1},
#  {'other_franchisename': 'Quicksilver Car Wash -', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR SONSTRAAL SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'BP BEYERS NAUDE SOUT', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BLOEMFONTEIN', 'number_transactions': 2},
#  {'other_franchisename': 'SANRAL/TCH IVR', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN LAINGSBURG  S', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN SWARTBERG  ST', 'number_transactions': 1},
#  {'other_franchisename': 'MUG & BEAN FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR LAND FICHARDT', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH CAPE GAT', 'number_transactions': 1},
#  {'other_franchisename': 'DAILYOM.COM', 'number_transactions': 1},
#  {'other_franchisename': 'SORBET BROADACRES', 'number_transactions': 2},
#  {'other_franchisename': 'THE SPORT INJURY CLI', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*Lizelle Steinberg', 'number_transactions': 1},
#  {'other_franchisename': 'EMMAS SECRET ROOM', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*The Fresh', 'number_transactions': 1},
#  {'other_franchisename': 'SCHOOL AND LEISURE MID', 'number_transactions': 2},
#  {'other_franchisename': 'THE WORLD OF GOLF', 'number_transactions': 2},
#  {'other_franchisename': 'KFC BROADACRES', 'number_transactions': 4},
#  {'other_franchisename': 'SEATTLE BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'FOURWAYS VETERINARY', 'number_transactions': 7},
#  {'other_franchisename': "READER'S WAREHOUSE B", 'number_transactions': 11},
#  {'other_franchisename': 'DRI AVG TECHNO', 'number_transactions': 2},
#  {'other_franchisename': 'Audible*KXLU', 'number_transactions': 1},
#  {'other_franchisename': 'VIDA E DESIG', 'number_transactions': 1},
#  {'other_franchisename': 'SEATTLE BROADA', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BAS', 'number_transactions': 1},
#  {'other_franchisename': 'CORICRAFT GR', 'number_transactions': 1},
#  {'other_franchisename': 'Mindful Eating', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MALL', 'number_transactions': 2},
#  {'other_franchisename': 'SASOL MEYERS', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers South', 'number_transactions': 1},
#  {'other_franchisename': 'VODACOM BROADA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BRACK', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Meyersd', 'number_transactions': 1},
#  {'other_franchisename': 'PAUL JAMES HAI', 'number_transactions': 1},
#  {'other_franchisename': 'ROCOMAMAS MEYE', 'number_transactions': 1},
#  {'other_franchisename': 'DEBONAIRS PI', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Brack', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH GL', 'number_transactions': 1},
#  {'other_franchisename': 'BP BROADACRE', 'number_transactions': 4},
#  {'other_franchisename': 'LOCO LIQ BRACK', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BRACKE', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MEYERSD', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MEY', 'number_transactions': 1},
#  {'other_franchisename': 'DEBONAIRS FO', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS MELRO', 'number_transactions': 1},
#  {'other_franchisename': 'CITY FISH AND', 'number_transactions': 1},
#  {'other_franchisename': "ANNICA'S DESIG", 'number_transactions': 1},
#  {'other_franchisename': 'PnP Exp Monte', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp On Nicol', 'number_transactions': 2},
#  {'other_franchisename': 'ALL FIX', 'number_transactions': 2},
#  {'other_franchisename': 'THE VALLEY GRILL', 'number_transactions': 9},
#  {'other_franchisename': 'AIRBNB * HMHXDDPY', 'number_transactions': 1},
#  {'other_franchisename': 'McDONALDS KYALAMI', 'number_transactions': 1},
#  {'other_franchisename': 'THE ROCK DINER FOURWAYTER',
#   'number_transactions': 1},
#  {'other_franchisename': 'VEROS CAKES', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN FOURWAYS', 'number_transactions': 7},
#  {'other_franchisename': 'MV CAFE', 'number_transactions': 1},
#  {'other_franchisename': 'PANDORA', 'number_transactions': 1},
#  {'other_franchisename': 'FESO HAIR CLINIC', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS GARDENS BP', 'number_transactions': 15},
#  {'other_franchisename': 'SPAR FOURWAYS GARDENS', 'number_transactions': 4},
#  {'other_franchisename': 'MANGO AIRLI', 'number_transactions': 1},
#  {'other_franchisename': 'SS MONTECASINO BAR', 'number_transactions': 1},
#  {'other_franchisename': 'FEDERAL PARKING SERVICES', 'number_transactions': 1},
#  {'other_franchisename': 'CHICKEN LICKEN FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'STER KINEKOR FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'ALTITUDE BEACH CLUB', 'number_transactions': 1},
#  {'other_franchisename': 'TBS Dainfern           SQ',
#   'number_transactions': 2},
#  {'other_franchisename': 'THE OLDE CHARITY S', 'number_transactions': 1},
#  {'other_franchisename': "PICOLINO'S ROLL ALWAYS", 'number_transactions': 1},
#  {'other_franchisename': 'Hotel on Booking.com', 'number_transactions': 2},
#  {'other_franchisename': 'RIVERSIDE LODGE', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BLOEM  STOP S', 'number_transactions': 1},
#  {'other_franchisename': 'AIRBNB * HMMRESQZXC', 'number_transactions': 1},
#  {'other_franchisename': 'MOUNTAIN VIEW MANOR', 'number_transactions': 1},
#  {'other_franchisename': 'Truworths', 'number_transactions': 8},
#  {'other_franchisename': 'VODASHOP EAST LONDON A', 'number_transactions': 1},
#  {'other_franchisename': 'THE COCKHOUSE CC', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN AIRPORT MOTORS', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN EL AIRPO', 'number_transactions': 1},
#  {'other_franchisename': 'THE BARISTA SISA', 'number_transactions': 1},
#  ...]

# %%
my_node = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c:Client)-
[othertransaction:TRANSACTED_AT]-(other:Merchant)
WHERE other.franchisename<>dischem.franchisename 
WITH other.franchisename AS other_franchisename, count(othertransaction) AS number_transactions 
RETURN DISTINCT(other_franchisename), number_transactions""").data()
my_node
# Out:
# [{'other_franchisename': 'Spar Broad A', 'number_transactions': 2},
#  {'other_franchisename': 'FOURWAYS GAR', 'number_transactions': 9},
#  {'other_franchisename': 'WOOLWORTHS- BR', 'number_transactions': 13},
#  {'other_franchisename': 'Clicks Fourway', 'number_transactions': 4},
#  {'other_franchisename': 'BUILDERS EXP C', 'number_transactions': 5},
#  {'other_franchisename': 'Spar Broadacre', 'number_transactions': 19},
#  {'other_franchisename': 'FOURNOS FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'HERBERT EVAN', 'number_transactions': 4},
#  {'other_franchisename': 'PNA DAINFERN', 'number_transactions': 34},
#  {'other_franchisename': 'Dainfern squar', 'number_transactions': 5},
#  {'other_franchisename': 'THE PANTRY C', 'number_transactions': 1},
#  {'other_franchisename': 'Microsoft*Offi', 'number_transactions': 2},
#  {'other_franchisename': 'PALM GARDENS V', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS CED', 'number_transactions': 3},
#  {'other_franchisename': 'Hair@Kim -', 'number_transactions': 1},
#  {'other_franchisename': 'DR KRIEL', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS GARDE', 'number_transactions': 1},
#  {'other_franchisename': 'SHOWMAX', 'number_transactions': 3},
#  {'other_franchisename': 'THE COMPOUND', 'number_transactions': 1},
#  {'other_franchisename': 'NETFLIX.COM', 'number_transactions': 50},
#  {'other_franchisename': 'Spar Fourways', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS MAR', 'number_transactions': 33},
#  {'other_franchisename': 'GOOGLE *Google', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM DAINF', 'number_transactions': 22},
#  {'other_franchisename': 'WOOLWORTHS FOU', 'number_transactions': 7},
#  {'other_franchisename': 'FEDERAL PARKIN', 'number_transactions': 8},
#  {'other_franchisename': 'TAKEALOT ONLINE', 'number_transactions': 22},
#  {'other_franchisename': 'WOOLWORTHS ONLINE', 'number_transactions': 4},
#  {'other_franchisename': 'Takealot', 'number_transactions': 2},
#  {'other_franchisename': 'PNP CRP DEINFERN SQUAR', 'number_transactions': 116},
#  {'other_franchisename': 'DEBONAIRS DAINFERN', 'number_transactions': 8},
#  {'other_franchisename': 'FACE LOGIC SKIN SPA', 'number_transactions': 6},
#  {'other_franchisename': 'APPLE.COM/BILL', 'number_transactions': 72},
#  {'other_franchisename': 'OCEAN BASKET', 'number_transactions': 4},
#  {'other_franchisename': 'VovoTeloLonehill', 'number_transactions': 1},
#  {'other_franchisename': "CARMELLA'S ON THE SQ", 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQUARE',
#   'number_transactions': 34},
#  {'other_franchisename': "HUMBLE HARRY'S THE BUZ", 'number_transactions': 2},
#  {'other_franchisename': 'LUSH SOUTH AFRICA', 'number_transactions': 2},
#  {'other_franchisename': 'PnP Crp Deinfern SquarRE',
#   'number_transactions': 26},
#  {'other_franchisename': 'CRUISEABOUT DAINFERN', 'number_transactions': 1},
#  {'other_franchisename': 'THE SHAVE UNION', 'number_transactions': 1},
#  {'other_franchisename': 'FLM FOURWAYS', 'number_transactions': 19},
#  {'other_franchisename': 'DIS-CHEM THE M', 'number_transactions': 4},
#  {'other_franchisename': 'RED SQUARE', 'number_transactions': 1},
#  {'other_franchisename': 'ROMANS PIZZA', 'number_transactions': 1},
#  {'other_franchisename': 'Viva gym', 'number_transactions': 1},
#  {'other_franchisename': 'STEERS DAINF', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PAU', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Leapi', 'number_transactions': 6},
#  {'other_franchisename': 'Cltx Witkoppen', 'number_transactions': 11},
#  {'other_franchisename': 'Fournos Roseba', 'number_transactions': 1},
#  {'other_franchisename': 'JACKSONS REA', 'number_transactions': 1},
#  {'other_franchisename': 'WELLNESS WAR', 'number_transactions': 2},
#  {'other_franchisename': 'TBS Dainfern', 'number_transactions': 6},
#  {'other_franchisename': 'WOOLWORTHS KYA', 'number_transactions': 3},
#  {'other_franchisename': 'LOTUS POOJA SH', 'number_transactions': 1},
#  {'other_franchisename': 'MRP HOME-NICOL', 'number_transactions': 1},
#  {'other_franchisename': 'UBER EATS', 'number_transactions': 8},
#  {'other_franchisename': 'ENGEN MAIN ROA', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dairnfe', 'number_transactions': 14},
#  {'other_franchisename': 'UBER TRIP', 'number_transactions': 8},
#  {'other_franchisename': 'CALTEX WITKO', 'number_transactions': 7},
#  {'other_franchisename': 'FLM WILLIAM NI', 'number_transactions': 3},
#  {'other_franchisename': 'CALTEX WITKOPP', 'number_transactions': 7},
#  {'other_franchisename': 'PNP CRP DEINFE', 'number_transactions': 27},
#  {'other_franchisename': "JACKSON'S REAL", 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Deinfe', 'number_transactions': 6},
#  {'other_franchisename': 'DIS-CHEM NICOL', 'number_transactions': 3},
#  {'other_franchisename': 'OPTIMUM HEAL', 'number_transactions': 1},
#  {'other_franchisename': 'UBER SA HELP.UBER.CO', 'number_transactions': 39},
#  {'other_franchisename': 'AMZN DIGITAVIFTZ', 'number_transactions': 1},
#  {'other_franchisename': 'STEERS DAINFERN', 'number_transactions': 8},
#  {'other_franchisename': 'AMZN DIGITAPPHT', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAMX', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAJ', 'number_transactions': 1},
#  {'other_franchisename': 'LOTUS POOJA SHOP CC', 'number_transactions': 1},
#  {'other_franchisename': 'SAFARI AND OUTDOOR', 'number_transactions': 2},
#  {'other_franchisename': 'SPORTSMANS WAREHOUSE FS', 'number_transactions': 4},
#  {'other_franchisename': 'WELLNESS WAREHOUSE D', 'number_transactions': 4},
#  {'other_franchisename': 'TECHEXPRESS (PTY)LTD', 'number_transactions': 1},
#  {'other_franchisename': 'AZAURA JEWELLERY NIC', 'number_transactions': 1},
#  {'other_franchisename': 'ALFIES PIZZERIA', 'number_transactions': 1},
#  {'other_franchisename': 'CheckersHyper Fourways', 'number_transactions': 16},
#  {'other_franchisename': 'SIX RESTAURANT', 'number_transactions': 13},
#  {'other_franchisename': 'I PAYU: Van Schaik Boo', 'number_transactions': 1},
#  {'other_franchisename': 'ISTORE FOURWAYS', 'number_transactions': 5},
#  {'other_franchisename': 'SPAR PINESLOPES SPAR', 'number_transactions': 21},
#  {'other_franchisename': 'Pizza Perfect Lonehill', 'number_transactions': 2},
#  {'other_franchisename': 'WEST PACK LIFESTYLE FORWA',
#   'number_transactions': 2},
#  {'other_franchisename': 'DR R M WEISS', 'number_transactions': 1},
#  {'other_franchisename': 'POSTNET BROADACRES', 'number_transactions': 5},
#  {'other_franchisename': 'I DHL INTERNATIONAL PT', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Broadacres Spar', 'number_transactions': 72},
#  {'other_franchisename': 'TOTAL RA LANSERIA', 'number_transactions': 2},
#  {'other_franchisename': 'SHAW ACADEMY SUBSCRIPT', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Fourways', 'number_transactions': 13},
#  {'other_franchisename': 'STARBUCKS FOURWAYS M', 'number_transactions': 7},
#  {'other_franchisename': 'YOYOSO FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM THE MALL FOUR', 'number_transactions': 21},
#  {'other_franchisename': 'PNP CLT FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'THE VENUE MELROSE AR', 'number_transactions': 1},
#  {'other_franchisename': 'ADOBE CREATIVE CLOUD', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQ', 'number_transactions': 111},
#  {'other_franchisename': 'MCD Fourways ()', 'number_transactions': 7},
#  {'other_franchisename': 'SHUTTERSTOCK*--', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BROADACR', 'number_transactions': 42},
#  {'other_franchisename': 'ENGEN LONEHILL BOULE', 'number_transactions': 20},
#  {'other_franchisename': 'LA LAMPARA RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MENLYNMAINE SPA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM DAINFERN PHARMCY',
#   'number_transactions': 29},
#  {'other_franchisename': 'LASERDERM DUNKELD PT', 'number_transactions': 1},
#  {'other_franchisename': 'SKIN RENEWAL', 'number_transactions': 1},
#  {'other_franchisename': 'LuluCOM', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Pineslopes', 'number_transactions': 16},
#  {'other_franchisename': 'PAYPAL *JOSHUABRAND', 'number_transactions': 1},
#  {'other_franchisename': 'FLM WILLIAM NICOL', 'number_transactions': 8},
#  {'other_franchisename': 'WOOLWORTHS CEDAR SQU', 'number_transactions': 14},
#  {'other_franchisename': 'WEST PACK LIFESTYLE FO', 'number_transactions': 19},
#  {'other_franchisename': 'LA CREMOSA', 'number_transactions': 9},
#  {'other_franchisename': 'PNP CRP FOURWAYS', 'number_transactions': 31},
#  {'other_franchisename': 'Clicks Broad Acres', 'number_transactions': 32},
#  {'other_franchisename': 'Dischem Strubens Valley', 'number_transactions': 1},
#  {'other_franchisename': 'DRS VAN RENSBURG AND  ART',
#   'number_transactions': 1},
#  {'other_franchisename': 'MOGALE CITY LOCAL MUNIC', 'number_transactions': 1},
#  {'other_franchisename': "DULCE'S WILGEHEUWEL", 'number_transactions': 1},
#  {'other_franchisename': 'WILGEHEUWEL HOSPITAL', 'number_transactions': 1},
#  {'other_franchisename': 'MATRIX WAREHOUSE FOU  AYS',
#   'number_transactions': 2},
#  {'other_franchisename': 'THE MARKET', 'number_transactions': 15},
#  {'other_franchisename': 'ENGEN MAIN ROAD', 'number_transactions': 3},
#  {'other_franchisename': 'FOURWAYS DRY CLEANERS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS DESIGN QUART', 'number_transactions': 1},
#  {'other_franchisename': 'CHOP IT BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'GARDENSHOP BROADACRES', 'number_transactions': 1},
#  {'other_franchisename': 'NORTHWORLD PHARMACY    S', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BROADACRES', 'number_transactions': 18},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS JHB', 'number_transactions': 2},
#  {'other_franchisename': 'GAME FOURWAYS', 'number_transactions': 8},
#  {'other_franchisename': 'BP BROADACRES', 'number_transactions': 14},
#  {'other_franchisename': 'WOOLWORTHS MAROUN SQUAR', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS OLIVEDALE JH', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Dainfern Square', 'number_transactions': 3},
#  {'other_franchisename': 'BP FOURWAYS', 'number_transactions': 11},
#  {'other_franchisename': 'NANDOS BROADACRES', 'number_transactions': 2},
#  {'other_franchisename': 'DR PA BETTS', 'number_transactions': 1},
#  {'other_franchisename': 'Makro Riversands', 'number_transactions': 25},
#  {'other_franchisename': 'MUGG & BEAN RIVERSANDS', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN CREST', 'number_transactions': 1},
#  {'other_franchisename': 'CRAZY STORE OV FOURWAY', 'number_transactions': 4},
#  {'other_franchisename': 'SHEET STREET- FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Fourways Mall', 'number_transactions': 1},
#  {'other_franchisename': 'MUG & BEAN FOURWAYS MALL', 'number_transactions': 1},
#  {'other_franchisename': 'SLOANE STAR MEA', 'number_transactions': 1},
#  {'other_franchisename': 'The valley grill', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR NORTHWOLD SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Olivedale Spar   TOR',
#   'number_transactions': 1},
#  {'other_franchisename': 'GERALD FRANCIS JEWELLE', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Morningside', 'number_transactions': 1},
#  {'other_franchisename': 'WALMART.COM', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- CRADLEST', 'number_transactions': 1},
#  {'other_franchisename': 'DEALZ  KRUGERSDORP', 'number_transactions': 1},
#  {'other_franchisename': 'NUTRI GEN', 'number_transactions': 1},
#  {'other_franchisename': 'Nail society  -', 'number_transactions': 1},
#  {'other_franchisename': 'ROYAL JOHANNESBURG G', 'number_transactions': 2},
#  {'other_franchisename': "READER'S WAREHOUSE N", 'number_transactions': 2},
#  {'other_franchisename': 'HOTELSCOM', 'number_transactions': 1},
#  {'other_franchisename': 'MR PRICE- CRADLE STONE', 'number_transactions': 1},
#  {'other_franchisename': 'DUNKELD FRUIT WHOLESAL', 'number_transactions': 2},
#  {'other_franchisename': 'Fresh Earth Food Store', 'number_transactions': 1},
#  {'other_franchisename': "FISHERMAN'S DELI DUN", 'number_transactions': 1},
#  {'other_franchisename': 'FRUITS AND ROOTS', 'number_transactions': 4},
#  {'other_franchisename': 'BP LINDEN PARK', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH FOURWAYS', 'number_transactions': 34},
#  {'other_franchisename': 'PNP CRP LONEHILL', 'number_transactions': 33},
#  {'other_franchisename': 'Clicks Lonehill', 'number_transactions': 19},
#  {'other_franchisename': 'Treasure', 'number_transactions': 4},
#  {'other_franchisename': 'VET TO PET LONEHILL', 'number_transactions': 4},
#  {'other_franchisename': 'DR D L LILLEY', 'number_transactions': 1},
#  {'other_franchisename': 'LIFESTYLE GARDEN CENTR', 'number_transactions': 2},
#  {'other_franchisename': "READER'S WAREHOUSE R", 'number_transactions': 2},
#  {'other_franchisename': 'COTTON ON MEGA FOURWAY', 'number_transactions': 7},
#  {'other_franchisename': 'takealot.com', 'number_transactions': 2},
#  {'other_franchisename': 'RANDBURG WHOLESALE M', 'number_transactions': 5},
#  {'other_franchisename': 'APEX DISTRIBUTORS SA', 'number_transactions': 1},
#  {'other_franchisename': 'JACKSONS REAL FOOD M', 'number_transactions': 5},
#  {'other_franchisename': 'WOOLWORTHS LONEHILL', 'number_transactions': 34},
#  {'other_franchisename': 'IMPALA FRUITERS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS', 'number_transactions': 26},
#  {'other_franchisename': 'SUPERBALIST', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS NICOLWAY BRYA', 'number_transactions': 4},
#  {'other_franchisename': 'TYPO NICOLWAY   _RE', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS NICHOL WA', 'number_transactions': 13},
#  {'other_franchisename': 'SEATTLE ERNEST & YOUNG', 'number_transactions': 1},
#  {'other_franchisename': 'CUTE DAINFERN', 'number_transactions': 7},
#  {'other_franchisename': 'EASY ON WEST', 'number_transactions': 1},
#  {'other_franchisename': 'Fedics Ernst & Young', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM FOURWAYS MALL', 'number_transactions': 8},
#  {'other_franchisename': 'FOREVER NEW FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': '@HOME FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS FOURWAYS JH', 'number_transactions': 8},
#  {'other_franchisename': 'WOOLWORTHS PAR', 'number_transactions': 1},
#  {'other_franchisename': 'SuperSpar Mall', 'number_transactions': 1},
#  {'other_franchisename': 'MAGNOLIA KWEKERY', 'number_transactions': 1},
#  {'other_franchisename': 'VODASHOP-THE GROVE', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP LYNNWOOD', 'number_transactions': 1},
#  {'other_franchisename': 'MONTEXO SPUR', 'number_transactions': 3},
#  {'other_franchisename': 'HONDA EAST RAND MALL', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN HIGHVELD  STO', 'number_transactions': 1},
#  {'other_franchisename': 'BP NORTHRAND', 'number_transactions': 1},
#  {'other_franchisename': 'GEORGES SUPERMARKET', 'number_transactions': 3},
#  {'other_franchisename': 'Checkers Bonaero Park', 'number_transactions': 1},
#  {'other_franchisename': 'TILETORIA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MALL@ - C', 'number_transactions': 3},
#  {'other_franchisename': 'TOTAL SUMMIT', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP BLUE HILLS', 'number_transactions': 5},
#  {'other_franchisename': 'SLOANE STAR ME', 'number_transactions': 3},
#  {'other_franchisename': 'WOOLWORTHS NOR', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Fourwa', 'number_transactions': 2},
#  {'other_franchisename': 'ADOBE PHOTOGPH', 'number_transactions': 1},
#  {'other_franchisename': 'JOUBERT EN SEU', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Riverside', 'number_transactions': 1},
#  {'other_franchisename': 'PAYFAST*RapidI', 'number_transactions': 1},
#  {'other_franchisename': 'Short Cuts Cra', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Lonehi', 'number_transactions': 5},
#  {'other_franchisename': 'LONEHILL PLAST', 'number_transactions': 4},
#  {'other_franchisename': 'WELEDA PHARMAC', 'number_transactions': 4},
#  {'other_franchisename': 'ARTHUR BALES', 'number_transactions': 1},
#  {'other_franchisename': 'EQUIFOX VET SUPPLIES', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY LE', 'number_transactions': 3},
#  {'other_franchisename': 'PnP MM Fourway', 'number_transactions': 2},
#  {'other_franchisename': 'ALCON CELLARS', 'number_transactions': 1},
#  {'other_franchisename': 'CAT BOX FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'WELEDA PHARMACY PINESL', 'number_transactions': 15},
#  {'other_franchisename': 'Dainfern square', 'number_transactions': 20},
#  {'other_franchisename': "ANNICA'S DESIGNER PA", 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dairnfern', 'number_transactions': 62},
#  {'other_franchisename': 'PNP CLOTHING LONEHILL', 'number_transactions': 4},
#  {'other_franchisename': 'PnP Crp Lonehill', 'number_transactions': 12},
#  {'other_franchisename': 'PnP Clt Lonehill', 'number_transactions': 1},
#  {'other_franchisename': 'OLD FASHION FISH & CHI', 'number_transactions': 3},
#  {'other_franchisename': 'MATRIX WAREHOUSE FOU', 'number_transactions': 2},
#  {'other_franchisename': 'PLAYSTATIONNETWORK', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY BROADACR', 'number_transactions': 3},
#  {'other_franchisename': 'FACEBK *XMMCNRC', 'number_transactions': 1},
#  {'other_franchisename': 'TOY KINGDOM FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'FROZEN FOR YOU', 'number_transactions': 13},
#  {'other_franchisename': 'FACEBK *EUBGYQWC', 'number_transactions': 1},
#  {'other_franchisename': 'THE COMPOUNDING PHAR', 'number_transactions': 3},
#  {'other_franchisename': 'COTTON ON KIDS FOURWAY', 'number_transactions': 1},
#  {'other_franchisename': 'SPORTSMANS WAREHOUSE', 'number_transactions': 17},
#  {'other_franchisename': 'Clicks Cedar Road', 'number_transactions': 6},
#  {'other_franchisename': 'I AFRIHOST.COM', 'number_transactions': 9},
#  {'other_franchisename': 'GOOGLE *SERVICES', 'number_transactions': 3},
#  {'other_franchisename': "JONNY'S", 'number_transactions': 12},
#  {'other_franchisename': 'PURE WOODLANDS SPA', 'number_transactions': 1},
#  {'other_franchisename': 'PNA CRADLESTONE', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *MAPMQWC', 'number_transactions': 1},
#  {'other_franchisename': 'FISHAWAYS DAINFERN', 'number_transactions': 3},
#  {'other_franchisename': 'HOME STUFF HILLFOX', 'number_transactions': 1},
#  {'other_franchisename': 'OSTERIA  (PTY) LTD', 'number_transactions': 1},
#  {'other_franchisename': 'BLAIR ATHOL VILLAGE', 'number_transactions': 1},
#  {'other_franchisename': 'YUPPIECHEF ONLINE', 'number_transactions': 2},
#  {'other_franchisename': 'ST ALBANS COLLEGE', 'number_transactions': 1},
#  {'other_franchisename': 'KAUAI WHOLEFOODS FRA', 'number_transactions': 1},
#  {'other_franchisename': 'INTERPARK MENLYN', 'number_transactions': 1},
#  {'other_franchisename': 'BLAIR ATHOL CLUB HOU', 'number_transactions': 1},
#  {'other_franchisename': 'SpotifyZA', 'number_transactions': 6},
#  {'other_franchisename': 'KINGS MEAT DELI LYNW', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN Mktp USSYYR', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *GQWRCRSC', 'number_transactions': 1},
#  {'other_franchisename': 'SORBET DAINFERN DRYB', 'number_transactions': 3},
#  {'other_franchisename': 'MCD Menlyn RC ()', 'number_transactions': 1},
#  {'other_franchisename': 'CNA FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'HE CROSS TRAINER FOU', 'number_transactions': 1},
#  {'other_franchisename': 'GEMINI OCTOPUS', 'number_transactions': 1},
#  {'other_franchisename': 'EDGARS  FOURWAYS', 'number_transactions': 9},
#  {'other_franchisename': 'TOTALSPORTS FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL FERNGATE', 'number_transactions': 21},
#  {'other_franchisename': "ALFIE'S RESTAURANT", 'number_transactions': 1},
#  {'other_franchisename': 'CULINARY TABLE', 'number_transactions': 4},
#  {'other_franchisename': 'FACEBK *CKFRSC', 'number_transactions': 1},
#  {'other_franchisename': 'SHOPIFY*', 'number_transactions': 1},
#  {'other_franchisename': 'AIRBNB * HMHRHD', 'number_transactions': 1},
#  {'other_franchisename': 'THE PANTRY COLLECTIO', 'number_transactions': 12},
#  {'other_franchisename': 'AIRBNB * HMFNZJX', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *ANHFRC', 'number_transactions': 1},
#  {'other_franchisename': 'Tops Lanseria', 'number_transactions': 1},
#  {'other_franchisename': 'MY PARTY SUPPLIES', 'number_transactions': 2},
#  {'other_franchisename': 'LONEHILL BOULEVARD C', 'number_transactions': 11},
#  {'other_franchisename': 'HILLSIDE TAVERN', 'number_transactions': 1},
#  {'other_franchisename': 'FACEBK *ZAGZQEC', 'number_transactions': 1},
#  {'other_franchisename': 'Hilton Hotel Windhoek', 'number_transactions': 1},
#  {'other_franchisename': 'I MTN SERVICE PROVIDER', 'number_transactions': 1},
#  {'other_franchisename': 'NEWS CAFE WOOD', 'number_transactions': 1},
#  {'other_franchisename': 'MVG COOPERAT', 'number_transactions': 1},
#  {'other_franchisename': 'Mall of Africa', 'number_transactions': 6},
#  {'other_franchisename': 'FACTORIE FOURWAYS CROS', 'number_transactions': 1},
#  {'other_franchisename': 'TOPS PINESLOPES', 'number_transactions': 3},
#  {'other_franchisename': 'CHICKEN LICKEN FOURW', 'number_transactions': 1},
#  {'other_franchisename': 'FEDERAL PARKING SERVIC', 'number_transactions': 20},
#  {'other_franchisename': 'BURGER KING - FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Intellepark', 'number_transactions': 1},
#  {'other_franchisename': 'I PROTEA MET SAGE', 'number_transactions': 1},
#  {'other_franchisename': 'NANDOS LEAPI', 'number_transactions': 4},
#  {'other_franchisename': 'MUGG & BEAN', 'number_transactions': 3},
#  {'other_franchisename': 'TS AFRIKA NE', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEA', 'number_transactions': 4},
#  {'other_franchisename': 'MCD Fourways', 'number_transactions': 5},
#  {'other_franchisename': 'TSAFRIKA *', 'number_transactions': 1},
#  {'other_franchisename': 'KFC FOURWAYS', 'number_transactions': 11},
#  {'other_franchisename': 'TS AFRIKA NESTLE', 'number_transactions': 1},
#  {'other_franchisename': 'MICROSOFT#G', 'number_transactions': 1},
#  {'other_franchisename': 'TSAFRIKA   *', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM NICOLWAY', 'number_transactions': 8},
#  {'other_franchisename': 'EXCLUSIVE BOOKS AIRP', 'number_transactions': 2},
#  {'other_franchisename': 'KULULA VITALITY', 'number_transactions': 5},
#  {'other_franchisename': 'TSAFRIKA HEADOFFICE', 'number_transactions': 2},
#  {'other_franchisename': 'VETSMART DAINF', 'number_transactions': 1},
#  {'other_franchisename': 'DURBAN SEAFOOD', 'number_transactions': 1},
#  {'other_franchisename': "ANNICA'S DES", 'number_transactions': 2},
#  {'other_franchisename': 'INK-LINK BRA', 'number_transactions': 1},
#  {'other_franchisename': 'PNP EXPRESS BR', 'number_transactions': 3},
#  {'other_franchisename': 'STATEMENT BEAU', 'number_transactions': 1},
#  {'other_franchisename': 'VIDA E CAFFE', 'number_transactions': 1},
#  {'other_franchisename': 'Perx Agency -', 'number_transactions': 1},
#  {'other_franchisename': 'MR PRICE SPORT', 'number_transactions': 5},
#  {'other_franchisename': 'EDGARS', 'number_transactions': 2},
#  {'other_franchisename': 'FOREVER NEW CU', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH FO', 'number_transactions': 6},
#  {'other_franchisename': 'FOSCHINI FOURW', 'number_transactions': 1},
#  {'other_franchisename': 'DAVID BENN CC.', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP ON NIC', 'number_transactions': 2},
#  {'other_franchisename': 'Brandons Pool Care', 'number_transactions': 3},
#  {'other_franchisename': 'MEDELLIN BARBERS', 'number_transactions': 1},
#  {'other_franchisename': 'GLOBAL GOLF GLOVES C', 'number_transactions': 3},
#  {'other_franchisename': 'TOP VENDING  PTY LTD', 'number_transactions': 2},
#  {'other_franchisename': 'TIGER OF SWEDEN SAND', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR SUNNINGHILL', 'number_transactions': 2},
#  {'other_franchisename': 'POSTNET SUNNINGHILL', 'number_transactions': 1},
#  {'other_franchisename': 'EXCLUSIVE BOOKS NICO', 'number_transactions': 2},
#  {'other_franchisename': 'NORTH STAR S/S', 'number_transactions': 5},
#  {'other_franchisename': 'CATTLE BARON SKUKUZA', 'number_transactions': 1},
#  {'other_franchisename': 'TINDLOVU CAFE', 'number_transactions': 1},
#  {'other_franchisename': 'CHATZ CONNEC', 'number_transactions': 1},
#  {'other_franchisename': 'LONEHILL ANIMAL HOSP', 'number_transactions': 6},
#  {'other_franchisename': 'SABC TV Licences', 'number_transactions': 2},
#  {'other_franchisename': 'BARGAIN BOOKS FOURWA', 'number_transactions': 6},
#  {'other_franchisename': 'SUPA QUICK FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'CHAMDOR FAKTRY SALES', 'number_transactions': 6},
#  {'other_franchisename': 'WOOLWORTHS DOUGLASDA', 'number_transactions': 7},
#  {'other_franchisename': 'A VAN DER MERWE INC', 'number_transactions': 1},
#  {'other_franchisename': 'MOZAMBIK SUNNINGHILL', 'number_transactions': 3},
#  {'other_franchisename': 'ENGEN PALM STOP SERV', 'number_transactions': 3},
#  {'other_franchisename': 'BERLINER BUTCHERY', 'number_transactions': 9},
#  {'other_franchisename': 'FAMILY PET CENTRE FO', 'number_transactions': 3},
#  {'other_franchisename': 'DIS-CHEM NORTHGATE', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CLOTHING FOURWAYS', 'number_transactions': 4},
#  {'other_franchisename': 'HUMBLE HARRYS', 'number_transactions': 5},
#  {'other_franchisename': 'SASOL THE RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'JNS GALAL', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *UBER BV', 'number_transactions': 2},
#  {'other_franchisename': 'PAYPAL *LINKEDIN', 'number_transactions': 1},
#  {'other_franchisename': 'NUTRITIONAL SOLUTIONS', 'number_transactions': 1},
#  {'other_franchisename': 'THE FACE AND BODY PLAC', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *SUCCESSFULM', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *INTERRDATIN', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MORNINGSI', 'number_transactions': 2},
#  {'other_franchisename': 'KIRBY DYNAMIC PROMOTIO', 'number_transactions': 1},
#  {'other_franchisename': 'ACSA JIA', 'number_transactions': 7},
#  {'other_franchisename': 'PALAZZO HOTEL REST', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS CEDAR SQUAR', 'number_transactions': 3},
#  {'other_franchisename': 'BLOOMBERG.COM', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *TRAINLINE', 'number_transactions': 1},
#  {'other_franchisename': 'ADAMS DISCOUNT CNT', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BENMORE GARS', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS DESIGN QU', 'number_transactions': 5},
#  {'other_franchisename': 'PAYPAL *KHATHUTSHEL', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *FUNKYSALES', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS RIVONIA JHB', 'number_transactions': 1},
#  {'other_franchisename': 'DRL HEALTH SOLUTIONS', 'number_transactions': 1},
#  {'other_franchisename': 'D J*WALL-ST-JOURNAL', 'number_transactions': 2},
#  {'other_franchisename': 'DRS VAN RENSBURG AND', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *SPOTIFY', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *ROYAL MAIL', 'number_transactions': 1},
#  {'other_franchisename': 'I SAGE SA SAGE', 'number_transactions': 1},
#  {'other_franchisename': 'VALUECO THE GL', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FAMILY WIN', 'number_transactions': 1},
#  {'other_franchisename': 'SERVEST PARKIN', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Columbi', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL SWARTGOU', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Dain', 'number_transactions': 5},
#  {'other_franchisename': 'BP MONTE', 'number_transactions': 19},
#  {'other_franchisename': 'EXCLUSIVE VIRG', 'number_transactions': 1},
#  {'other_franchisename': '@ PARKS RESTAU', 'number_transactions': 1},
#  {'other_franchisename': 'MCD Kyalami (', 'number_transactions': 2},
#  {'other_franchisename': 'CHECKERS COLUM', 'number_transactions': 1},
#  {'other_franchisename': 'HARD ROCK JOHA', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN LONEHILL', 'number_transactions': 5},
#  {'other_franchisename': 'THE ROCK CARNE', 'number_transactions': 1},
#  {'other_franchisename': 'CHECKERS LEAPI', 'number_transactions': 2},
#  {'other_franchisename': '@ PARKS RESTAURANT A', 'number_transactions': 2},
#  {'other_franchisename': 'BOLT.EU /O/', 'number_transactions': 2},
#  {'other_franchisename': 'CHAMDOR FAKTRY', 'number_transactions': 1},
#  {'other_franchisename': 'HJM Hair and B', 'number_transactions': 1},
#  {'other_franchisename': 'Que', 'number_transactions': 1},
#  {'other_franchisename': 'FACE LOGIC S', 'number_transactions': 3},
#  {'other_franchisename': 'MAKRO RIVERSANDS', 'number_transactions': 14},
#  {'other_franchisename': 'GARDENSHOP BROADACRE', 'number_transactions': 14},
#  {'other_franchisename': 'MR PRICE APPAREL- FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH RIVONIA   ONI',
#   'number_transactions': 1},
#  {'other_franchisename': 'ADOBE PHOTOGPHY PLAN', 'number_transactions': 3},
#  {'other_franchisename': 'COTTON ON FOURWAYS CROSSI',
#   'number_transactions': 2},
#  {'other_franchisename': 'NP-MER', 'number_transactions': 1},
#  {'other_franchisename': 'FOOD LOVERS AT LIFESTY', 'number_transactions': 3},
#  {'other_franchisename': 'LIQUOR CITY LONEHILL', 'number_transactions': 10},
#  {'other_franchisename': 'DIS-CHEM SUNNINGHILL', 'number_transactions': 2},
#  {'other_franchisename': 'CLicks SunningHill', 'number_transactions': 1},
#  {'other_franchisename': 'Bryanston Market at Mi', 'number_transactions': 1},
#  {'other_franchisename': 'C E Becker Transport S', 'number_transactions': 1},
#  {'other_franchisename': 'GROW WILD', 'number_transactions': 1},
#  {'other_franchisename': 'COFFEE AND CRUNCH', 'number_transactions': 1},
#  {'other_franchisename': 'LUDWIG S ROSES EGOLI', 'number_transactions': 1},
#  {'other_franchisename': 'DOONHOLM NURSERY', 'number_transactions': 1},
#  {'other_franchisename': 'AMAZING CRYSTALS CC', 'number_transactions': 1},
#  {'other_franchisename': 'FARMERS MARKET PINES', 'number_transactions': 6},
#  {'other_franchisename': 'THE MEAT BOSS', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR CITY LEAPING', 'number_transactions': 4},
#  {'other_franchisename': 'VETSMART DAINFERN', 'number_transactions': 7},
#  {'other_franchisename': 'DULCE CAFE FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'Bidvest', 'number_transactions': 2},
#  {'other_franchisename': 'FRANCOS PIZZERIA & T', 'number_transactions': 1},
#  {'other_franchisename': 'TOP HAT BAKERY AND T', 'number_transactions': 1},
#  {'other_franchisename': 'CENTURION GATE TOTAL S', 'number_transactions': 2},
#  {'other_franchisename': 'OH MY CAKE', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Leaping Frog', 'number_transactions': 26},
#  {'other_franchisename': 'TOTAL SANDTON DRIVE', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM THE CLUB PHAR', 'number_transactions': 1},
#  {'other_franchisename': 'PIZZA PERFECT', 'number_transactions': 1},
#  {'other_franchisename': 'M AND B LONEHILL', 'number_transactions': 3},
#  {'other_franchisename': 'NSRI', 'number_transactions': 1},
#  {'other_franchisename': 'TravelStart', 'number_transactions': 3},
#  {'other_franchisename': 'EN ROUTE LUGGAGE', 'number_transactions': 1},
#  {'other_franchisename': 'DR ALLEM INC ILLOVO', 'number_transactions': 1},
#  {'other_franchisename': 'I Chrome SA', 'number_transactions': 2},
#  {'other_franchisename': 'OLIVES & PLATES WBS', 'number_transactions': 1},
#  {'other_franchisename': 'TOPS PINESLO', 'number_transactions': 2},
#  {'other_franchisename': 'SPAR PINESLO', 'number_transactions': 8},
#  {'other_franchisename': 'YUME', 'number_transactions': 6},
#  {'other_franchisename': 'SHELL VILLAGE', 'number_transactions': 1},
#  {'other_franchisename': 'Wishy Washy Ca', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*CANDY DELI', 'number_transactions': 1},
#  {'other_franchisename': 'TIME SQUARE', 'number_transactions': 1},
#  {'other_franchisename': 'SBG (PTY) LT', 'number_transactions': 1},
#  {'other_franchisename': 'Internat', 'number_transactions': 1},
#  {'other_franchisename': 'Dough An', 'number_transactions': 1},
#  {'other_franchisename': 'Choppies Phaka', 'number_transactions': 1},
#  {'other_franchisename': 'BP BEYERS NA', 'number_transactions': 1},
#  {'other_franchisename': 'BARBER LOU FOU', 'number_transactions': 1},
#  {'other_franchisename': 'MARKHAM FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'BLING FONES', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX WITKOPPEN CON', 'number_transactions': 5},
#  {'other_franchisename': 'Gautrain CTLS Local', 'number_transactions': 2},
#  {'other_franchisename': 'Cltx Witkoppen Motors', 'number_transactions': 20},
#  {'other_franchisename': 'MR PRICE HOME- ROSEBAN', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM SANDTON CITY', 'number_transactions': 4},
#  {'other_franchisename': 'HOUSE OF ISIS ROSEBA', 'number_transactions': 1},
#  {'other_franchisename': 'PATA PATA AFRICAN RE', 'number_transactions': 1},
#  {'other_franchisename': 'REMAX ROSENBANK', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR GABS VILLAGE SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'MUG AND BEAN RIVERWALK', 'number_transactions': 1},
#  {'other_franchisename': 'EXCLUSIVE BOOKS FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'BARAZZA RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL RA VILLAGE', 'number_transactions': 2},
#  {'other_franchisename': 'BEM BOM BEDFORDVIEW', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL DOUGLASDALE_NE', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*M HAIR STUDIO', 'number_transactions': 1},
#  {'other_franchisename': 'THE LOFT NAIL SALON', 'number_transactions': 4},
#  {'other_franchisename': 'CARWASH DESIGN Q', 'number_transactions': 1},
#  {'other_franchisename': 'Dropbox RDHSSPTK', 'number_transactions': 1},
#  {'other_franchisename': 'GAS SA RETAIL FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'Cltx Cedar Road', 'number_transactions': 3},
#  {'other_franchisename': 'SIMPLY FRENCH', 'number_transactions': 1},
#  {'other_franchisename': 'PAINT EMPORIUM FOURWAY', 'number_transactions': 17},
#  {'other_franchisename': 'CHARTWELL VET', 'number_transactions': 9},
#  {'other_franchisename': 'LIQUOR CITY BROADARC', 'number_transactions': 11},
#  {'other_franchisename': 'PNP EXPRESS BROAD', 'number_transactions': 7},
#  {'other_franchisename': 'ENGEN GEORGE STORRAR', 'number_transactions': 1},
#  {'other_franchisename': 'VAN HEERDEN APTEEK N  END',
#   'number_transactions': 1},
#  {'other_franchisename': 'DAINFERN COUNTRY CL', 'number_transactions': 7},
#  {'other_franchisename': 'THE GOLFERS CLUB (PT  WD', 'number_transactions': 1},
#  {'other_franchisename': 'FEVER TREE BAR', 'number_transactions': 1},
#  {'other_franchisename': 'BISTRO BISTRO', 'number_transactions': 1},
#  {'other_franchisename': 'GOOGLE *Google Music', 'number_transactions': 4},
#  {'other_franchisename': 'WOOLWORTHS CROWTHORN', 'number_transactions': 2},
#  {'other_franchisename': 'Nandos Kyalami', 'number_transactions': 3},
#  {'other_franchisename': 'TWO IN ONE CHINESE AND', 'number_transactions': 2},
#  {'other_franchisename': 'PAYFAST*Creed Nutritio', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS EXP CEDARSQ', 'number_transactions': 12},
#  {'other_franchisename': 'DOPPIO ZERO PINESLOPES', 'number_transactions': 4},
#  {'other_franchisename': 'DR IGH JONES', 'number_transactions': 2},
#  {'other_franchisename': 'NATURAL EFFECTS', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MORNING G', 'number_transactions': 2},
#  {'other_franchisename': 'TRAFALGAR PROPERTY M', 'number_transactions': 1},
#  {'other_franchisename': 'HI FI FOURWAYS', 'number_transactions': 6},
#  {'other_franchisename': 'POSTNET DAINFERN', 'number_transactions': 6},
#  {'other_franchisename': 'WIMPY KSIA', 'number_transactions': 2},
#  {'other_franchisename': 'WINSTON PARK CSTORE', 'number_transactions': 1},
#  {'other_franchisename': 'POINT WATER SPORTS CLU', 'number_transactions': 1},
#  {'other_franchisename': 'THE DAILY BAGEL', 'number_transactions': 1},
#  {'other_franchisename': 'SEATTLE COFFEE MT EDGE', 'number_transactions': 1},
#  {'other_franchisename': "READER'S WAR", 'number_transactions': 1},
#  {'other_franchisename': 'TOPS ROSEHILL', 'number_transactions': 1},
#  {'other_franchisename': 'OLD KHAKI FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'POETRY FOURWAYS', 'number_transactions': 3},
#  {'other_franchisename': 'HAMLEYS FOURWA', 'number_transactions': 1},
#  {'other_franchisename': 'CHECKERS FERND', 'number_transactions': 1},
#  {'other_franchisename': 'LOVISA F', 'number_transactions': 1},
#  {'other_franchisename': 'UBER SA HELP.U', 'number_transactions': 14},
#  {'other_franchisename': 'MR PRICE HOME- THE DES', 'number_transactions': 3},
#  {'other_franchisename': 'OCEAN BASKET KILLARNEY', 'number_transactions': 1},
#  {'other_franchisename': 'MRP HOME FOURWAYS', 'number_transactions': 5},
#  {'other_franchisename': 'FOSCHINI FOURWAYS', 'number_transactions': 2},
#  {'other_franchisename': 'XNEELO', 'number_transactions': 1},
#  {'other_franchisename': 'PIZA E VINO ROSEBANK', 'number_transactions': 2},
#  {'other_franchisename': 'CALTEX CAMBRIDGE', 'number_transactions': 2},
#  {'other_franchisename': 'FISHMONGER BRYANSTON', 'number_transactions': 1},
#  {'other_franchisename': 'MSFT * EAJWT', 'number_transactions': 1},
#  {'other_franchisename': 'ANDICCIO .', 'number_transactions': 4},
#  {'other_franchisename': 'GRAZIA S FINE FOOD A', 'number_transactions': 1},
#  {'other_franchisename': 'WIMPY ESPLANADE', 'number_transactions': 1},
#  {'other_franchisename': 'EXPRESSVPN', 'number_transactions': 1},
#  {'other_franchisename': 'MYTHOS MONTE CASINO', 'number_transactions': 1},
#  {'other_franchisename': 'GOOGLE *GSUITE_constoc', 'number_transactions': 1},
#  {'other_franchisename': 'THE FARM NURSE', 'number_transactions': 1},
#  {'other_franchisename': 'Audible*PU', 'number_transactions': 1},
#  {'other_franchisename': 'FROZEN FOR Y', 'number_transactions': 2},
#  {'other_franchisename': 'SUNNINGHILL RA', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL RA POT', 'number_transactions': 1},
#  {'other_franchisename': 'Kindle Unltd*G', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN MAIN R', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MORNI', 'number_transactions': 1},
#  {'other_franchisename': 'TOTAL SANDTON', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS FLO', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MAL', 'number_transactions': 1},
#  {'other_franchisename': 'Just Love Stit', 'number_transactions': 1},
#  {'other_franchisename': 'NESPRESSO MA', 'number_transactions': 1},
#  {'other_franchisename': 'EVENT FOODS', 'number_transactions': 2},
#  {'other_franchisename': 'EXPO TRENDS CC', 'number_transactions': 1},
#  {'other_franchisename': 'BASECUT STUDIO', 'number_transactions': 7},
#  {'other_franchisename': 'MZP ENTERPRI', 'number_transactions': 1},
#  {'other_franchisename': 'THE LOFT NAIL', 'number_transactions': 2},
#  {'other_franchisename': 'EDGARS RSQ D', 'number_transactions': 3},
#  {'other_franchisename': 'Audible*WNKY', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BROOK', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PTY', 'number_transactions': 1},
#  {'other_franchisename': 'BERLINER BUT', 'number_transactions': 3},
#  {'other_franchisename': 'BLACK HORSE RE', 'number_transactions': 1},
#  {'other_franchisename': 'I SnapScan Alexs Car W', 'number_transactions': 4},
#  {'other_franchisename': 'DR BARROW', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BROOKLYN', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BROOKLYN', 'number_transactions': 1},
#  {'other_franchisename': 'TBS Brooklyn', 'number_transactions': 1},
#  {'other_franchisename': 'PAYFAST*Froggie', 'number_transactions': 1},
#  {'other_franchisename': 'POS CHARTW   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'MTN FOURWAYS L', 'number_transactions': 1},
#  {'other_franchisename': 'DR L STOCKRIGT & ASS', 'number_transactions': 1},
#  {'other_franchisename': 'CORNERSTONE PHARMACY B', 'number_transactions': 1},
#  {'other_franchisename': 'COTTON ON FOURWAYS CRO', 'number_transactions': 6},
#  {'other_franchisename': 'BELIFORE ITALIAN DELI', 'number_transactions': 2},
#  {'other_franchisename': 'ENGEN MAIN ROAD CONV', 'number_transactions': 5},
#  {'other_franchisename': 'BILTONG AT ZA PINESL', 'number_transactions': 2},
#  {'other_franchisename': 'Spar King Fisher Spar', 'number_transactions': 4},
#  {'other_franchisename': 'OLD KHAKHI NICOLWAY', 'number_transactions': 1},
#  {'other_franchisename': 'Z TWO', 'number_transactions': 2},
#  {'other_franchisename': 'PNP CRP ON NICOL', 'number_transactions': 5},
#  {'other_franchisename': 'FLM FERNDALE', 'number_transactions': 2},
#  {'other_franchisename': 'CRAZY PETS FERNDALE', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Bryan Park', 'number_transactions': 3},
#  {'other_franchisename': "JACK'S PAINT AND HAR", 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- BRYAN PA', 'number_transactions': 4},
#  {'other_franchisename': 'PINESLOPES TYRES', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Dougasdale', 'number_transactions': 1},
#  {'other_franchisename': 'EUROPA DOUGLASDALE', 'number_transactions': 2},
#  {'other_franchisename': 'THE VILLAGE CRAFT MARK', 'number_transactions': 1},
#  {'other_franchisename': 'TYPO FOURWAYS MALL', 'number_transactions': 1},
#  {'other_franchisename': 'MTN FOURWAYS LTALK', 'number_transactions': 1},
#  {'other_franchisename': 'Superga Fourways', 'number_transactions': 1},
#  {'other_franchisename': 'COFFEE EXCHANGE PARK', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN DOUGLASDALE', 'number_transactions': 5},
#  {'other_franchisename': 'Clicks Benmore Gardens', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CLOTHING BENMORE G', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BENMORE G', 'number_transactions': 2},
#  {'other_franchisename': 'Checkers Nicolway', 'number_transactions': 5},
#  {'other_franchisename': 'PNP CLOTHING NICOLWAY', 'number_transactions': 3},
#  {'other_franchisename': 'Cltx Kingfisher S S    Fo',
#   'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS DOU', 'number_transactions': 4},
#  {'other_franchisename': 'Spar Olivedale', 'number_transactions': 2},
#  {'other_franchisename': 'GAME BEL-AIR', 'number_transactions': 2},
#  {'other_franchisename': 'Tops Fourways', 'number_transactions': 3},
#  {'other_franchisename': 'POS Clicks   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'LONEHILL ANIMA', 'number_transactions': 1},
#  {'other_franchisename': 'STARBUCKS FO', 'number_transactions': 2},
#  {'other_franchisename': 'PLANKTON CAS', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*KATHY THOM', 'number_transactions': 1},
#  {'other_franchisename': 'I SnapScan SAJ', 'number_transactions': 1},
#  {'other_franchisename': 'Dr R B Lomba', 'number_transactions': 1},
#  {'other_franchisename': 'BP WILLIAM N', 'number_transactions': 3},
#  {'other_franchisename': 'SPAR PINESLOPE', 'number_transactions': 2},
#  {'other_franchisename': 'COTTON ON FOUR', 'number_transactions': 1},
#  {'other_franchisename': 'CASH CONVERTER', 'number_transactions': 1},
#  {'other_franchisename': 'BARGAIN BOOKS', 'number_transactions': 1},
#  {'other_franchisename': 'Glasfit Four', 'number_transactions': 1},
#  {'other_franchisename': 'LESLEYS', 'number_transactions': 1},
#  {'other_franchisename': 'DIKHOLOLO', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *FRANKRO', 'number_transactions': 1},
#  {'other_franchisename': 'Amazon Prime*GKLKJ', 'number_transactions': 1},
#  {'other_franchisename': 'JEAN COUTU #', 'number_transactions': 1},
#  {'other_franchisename': 'LANCET MORNINGSIDE SIT', 'number_transactions': 1},
#  {'other_franchisename': 'ACDC FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'Mr D Food', 'number_transactions': 2},
#  {'other_franchisename': 'PAYPAL *RICARDOSENE', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *CANCOOPER', 'number_transactions': 1},
#  {'other_franchisename': 'Mr D Food ZA', 'number_transactions': 5},
#  {'other_franchisename': 'PHARMAPRIX #', 'number_transactions': 1},
#  {'other_franchisename': 'PAYPAL *M', 'number_transactions': 1},
#  {'other_franchisename': 'ENTR OUELLET ET RAYMON', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BBQ DOWNS', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN VAN BUUREN', 'number_transactions': 1},
#  {'other_franchisename': 'SLOANE MEAT MARKET', 'number_transactions': 5},
#  {'other_franchisename': 'LIQUOR CITY G/NR', 'number_transactions': 3},
#  {'other_franchisename': 'JOSES RESTAURANT', 'number_transactions': 1},
#  {'other_franchisename': 'LANSERIA AIRPORT PARKI', 'number_transactions': 5},
#  {'other_franchisename': 'DUNES', 'number_transactions': 2},
#  {'other_franchisename': "PAPINO'S", 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM CANAL WALK', 'number_transactions': 2},
#  {'other_franchisename': 'INFLUENCE CC', 'number_transactions': 1},
#  {'other_franchisename': 'EYE Q SOMERSET WEST', 'number_transactions': 1},
#  {'other_franchisename': 'gotinder.com/help', 'number_transactions': 2},
#  {'other_franchisename': 'CONFAIT HAIRDRESSING', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Fourways Pharm', 'number_transactions': 7},
#  {'other_franchisename': 'MCD Boskruin (', 'number_transactions': 1},
#  {'other_franchisename': 'F H CHAMBERL', 'number_transactions': 1},
#  {'other_franchisename': 'LEROY MERLIN L', 'number_transactions': 1},
#  {'other_franchisename': 'HOUSE OF PAI', 'number_transactions': 1},
#  {'other_franchisename': 'TIMBERCITY BLA', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS EXP N', 'number_transactions': 1},
#  {'other_franchisename': 'DA MALTA (PTY)', 'number_transactions': 1},
#  {'other_franchisename': 'ROCK COTTAGE P', 'number_transactions': 1},
#  {'other_franchisename': 'MEDICARE BOSKR', 'number_transactions': 1},
#  {'other_franchisename': 'Universal Pa', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM RANDR', 'number_transactions': 1},
#  {'other_franchisename': 'GELMAR (PTY)LT', 'number_transactions': 1},
#  {'other_franchisename': 'BP BRYANSTON', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX WITKOPPEN C STO', 'number_transactions': 5},
#  {'other_franchisename': 'SEATTLE GROSVENOR CROS', 'number_transactions': 3},
#  {'other_franchisename': 'ENGEN BRYANSTON CONV', 'number_transactions': 2},
#  {'other_franchisename': 'WESTERN SHOPPE (PTY)', 'number_transactions': 1},
#  {'other_franchisename': 'DRIFTERS ADVENTURE', 'number_transactions': 2},
#  {'other_franchisename': 'SPAR EXPRESS GOLDEN', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL GOLDEN MEADOWS F', 'number_transactions': 1},
#  {'other_franchisename': 'ARAMEX INTERNATIONAL Z', 'number_transactions': 1},
#  {'other_franchisename': 'LAURENTINA HARTEES', 'number_transactions': 1},
# ...
#  {'other_franchisename': 'CALTEX CAMBRID', 'number_transactions': 2},
#  {'other_franchisename': 'TOPS PARKMORE', 'number_transactions': 1},
#  {'other_franchisename': 'MAXWELLS', 'number_transactions': 1},
#  {'other_franchisename': 'MICROSOFT*CONSOLE -MONTH', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MORNINGSIDE', 'number_transactions': 2},
#  {'other_franchisename': 'AMZN DIGITAIVNZ', 'number_transactions': 1},
#  {'other_franchisename': 'KINDLE SVCUVSWS', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITAABHLA', 'number_transactions': 1},
#  {'other_franchisename': 'AMZN DIGITADAW', 'number_transactions': 1},
#  {'other_franchisename': 'MCDONALDS RIVONIA', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR WEDGE', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN RIVONIA', 'number_transactions': 2},
#  {'other_franchisename': 'WOOLWORTHS SUNNINGHI', 'number_transactions': 2},
#  {'other_franchisename': 'GOOGLE *GSUITE_KUZWAYO', 'number_transactions': 1},
#  {'other_franchisename': 'PERFECT HEALTH', 'number_transactions': 2},
#  {'other_franchisename': 'ABSOLUTE PETS KYALAM', 'number_transactions': 1},
#  {'other_franchisename': 'CRAZY STORE LONEHIL   EHI',
#   'number_transactions': 1},
#  {'other_franchisename': 'IC INTERNET', 'number_transactions': 1},
#  {'other_franchisename': 'WELLNESS WAREHOUSE K  LAM',
#   'number_transactions': 1},
#  {'other_franchisename': 'Checkers Kyalami', 'number_transactions': 7},
#  {'other_franchisename': 'ENGEN ERASSMUND', 'number_transactions': 1},
#  {'other_franchisename': 'JALA SUPERETTE EN SL', 'number_transactions': 1},
#  {'other_franchisename': 'CROWTHORNE HARDWARE', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Crowthorne', 'number_transactions': 1},
#  {'other_franchisename': 'PIATTO RESTAURANT', 'number_transactions': 3},
#  {'other_franchisename': 'NANDOS BRYANSTON DT', 'number_transactions': 1},
#  {'other_franchisename': 'LA PARADA CONSTANTIA', 'number_transactions': 1},
#  {'other_franchisename': 'BRAND COLLECTIVE HOU', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL CANAL WALK', 'number_transactions': 2},
#  {'other_franchisename': 'Clicks Midrand', 'number_transactions': 1},
#  {'other_franchisename': 'COMAIR LIMITED', 'number_transactions': 6},
#  {'other_franchisename': 'FAITHFUL TO NATURE', 'number_transactions': 3},
#  {'other_franchisename': 'HENLEY CROWTHRONE SE', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN DAINFE', 'number_transactions': 11},
#  {'other_franchisename': 'UCook', 'number_transactions': 1},
#  {'other_franchisename': 'Nandos Waterfall Drive', 'number_transactions': 2},
#  {'other_franchisename': 'PIZZA HUT DAINFERN', 'number_transactions': 3},
#  {'other_franchisename': 'Clicks Windsor Way NCC', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Blue Hi', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR CARL', 'number_transactions': 1},
#  {'other_franchisename': 'COMPASS GROU', 'number_transactions': 2},
#  {'other_franchisename': 'LIQUOR CITY CL', 'number_transactions': 1},
#  {'other_franchisename': 'PEP  MIDRA', 'number_transactions': 2},
#  {'other_franchisename': 'BA BATTERY', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP BLUE H', 'number_transactions': 1},
#  {'other_franchisename': 'OLIFANTSFONTEI', 'number_transactions': 1},
#  {'other_franchisename': 'Kids Milestone', 'number_transactions': 1},
#  {'other_franchisename': 'PHOSA S TAVERN', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL BLUE HIL', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Crowthorn', 'number_transactions': 3},
#  {'other_franchisename': 'CheckersHyper', 'number_transactions': 4},
#  {'other_franchisename': 'CROWTHORNE S', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS- FO', 'number_transactions': 2},
#  {'other_franchisename': 'ROOTS OLIEVENH', 'number_transactions': 1},
#  {'other_franchisename': 'SHELL PIETERSBURG', 'number_transactions': 1},
#  {'other_franchisename': 'FISHAWAYS MASINGITA  C', 'number_transactions': 1},
#  {'other_franchisename': 'BIDVEST WALTONS', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM DAINFERN PH', 'number_transactions': 1},
#  {'other_franchisename': 'CHICKEN LICKEN TEMBI', 'number_transactions': 1},
#  {'other_franchisename': 'COMPASS GROUP SA PTY', 'number_transactions': 2},
#  {'other_franchisename': 'SASOL BLUE HILLS', 'number_transactions': 1},
#  {'other_franchisename': "LET'S EAT CANTEEN (PTY", 'number_transactions': 2},
#  {'other_franchisename': 'SOAPY RIDES CAR WASH', 'number_transactions': 1},
#  {'other_franchisename': 'KFC BLUE HILLS', 'number_transactions': 1},
#  {'other_franchisename': 'SUPERSPAR MALL', 'number_transactions': 1},
#  {'other_franchisename': 'Dischem Mall', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR CITY TO', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN TOWER', 'number_transactions': 1},
#  {'other_franchisename': 'DIE WINDPOMP L', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Mnandi Sp', 'number_transactions': 1},
#  {'other_franchisename': 'HEALTH MED PHA', 'number_transactions': 1},
#  {'other_franchisename': 'TOP VENDING P', 'number_transactions': 1},
#  {'other_franchisename': 'SASOL CIRCLE C', 'number_transactions': 1},
#  {'other_franchisename': 'COPPER LEAF GO', 'number_transactions': 1},
#  {'other_franchisename': 'COPPERLEAF GOL', 'number_transactions': 1},
#  {'other_franchisename': 'Tops Mnandi', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BLUE HILL', 'number_transactions': 1},
#  {'other_franchisename': 'WEST PACK LIFESTYLE MA', 'number_transactions': 2},
#  {'other_franchisename': 'SUPERSPAR MALL AT', 'number_transactions': 3},
#  {'other_franchisename': 'MR PRICE- FOREST HILL', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Forest Hill', 'number_transactions': 2},
#  {'other_franchisename': 'TOTAL KNOPJESLAAGTE', 'number_transactions': 4},
#  {'other_franchisename': 'WOOLWORTHS- FOREST H', 'number_transactions': 2},
#  {'other_franchisename': 'ENGEN FLAMINGO', 'number_transactions': 1},
#  {'other_franchisename': 'PNP FRAN TOWERS EAST R', 'number_transactions': 1},
#  {'other_franchisename': 'Spar Mnandi Spar', 'number_transactions': 1},
#  {'other_franchisename': 'COPPER LEAF GOLF EST', 'number_transactions': 2},
#  {'other_franchisename': 'DIS-CHEM BOKSBURG', 'number_transactions': 1},
#  {'other_franchisename': 'COTTON ON MEGA', 'number_transactions': 1},
#  {'other_franchisename': 'POS MEGA F   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'POS COTTON   INS FUNDS', 'number_transactions': 1},
#  {'other_franchisename': 'REEBOK ATTERBU', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS MALL OF', 'number_transactions': 1},
#  {'other_franchisename': 'KUNG FU KITC', 'number_transactions': 1},
#  {'other_franchisename': 'KROONVAAL  ST', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN KROONV', 'number_transactions': 1},
#  {'other_franchisename': 'MEI HUA SUSH', 'number_transactions': 1},
#  {'other_franchisename': 'PAPACHINOS BRO', 'number_transactions': 3},
#  {'other_franchisename': 'Movies AT Mont', 'number_transactions': 3},
#  {'other_franchisename': 'Clicks Broad A', 'number_transactions': 5},
#  {'other_franchisename': 'Checkers Pines', 'number_transactions': 4},
#  {'other_franchisename': 'SKYSTOP CONVIENCE CNT NTR',
#   'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp Cedar Road', 'number_transactions': 4},
#  {'other_franchisename': 'SMOKE DADDYS', 'number_transactions': 1},
#  {'other_franchisename': 'CheckersHyper FourwaysS', 'number_transactions': 6},
#  {'other_franchisename': 'BP BEYERS NAUDE DRIV', 'number_transactions': 2},
#  {'other_franchisename': 'Movies AT Monte', 'number_transactions': 6},
#  {'other_franchisename': 'PAPACHINOS BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'PINESLOPES PTY LT', 'number_transactions': 1},
#  {'other_franchisename': 'BURGER KING - KYALAMI', 'number_transactions': 2},
#  {'other_franchisename': 'ORIENTAL STYLE', 'number_transactions': 1},
#  {'other_franchisename': 'CHEVALETE', 'number_transactions': 2},
#  {'other_franchisename': 'LONEHILL ANIMAL HOSP  AL', 'number_transactions': 1},
#  {'other_franchisename': 'Waltons Fourways', 'number_transactions': 4},
#  {'other_franchisename': 'COUNTRY MEAT BUTCHERIE', 'number_transactions': 2},
#  {'other_franchisename': 'PETERVALE PHARMACY', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS PAULSHOF JH', 'number_transactions': 1},
#  {'other_franchisename': 'Sunninghill Medical Ce', 'number_transactions': 1},
#  {'other_franchisename': 'PAPA PRONTO', 'number_transactions': 4},
#  {'other_franchisename': 'FOURWAYS VETERINARY HO', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR LINDEN KWIK SPA', 'number_transactions': 1},
#  {'other_franchisename': 'GoWild Accessories pty', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR PINESLOPES', 'number_transactions': 9},
#  {'other_franchisename': 'FIORE GARDEN CENTRE SO', 'number_transactions': 1},
#  {'other_franchisename': 'KNICK KNACK KIOSK', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS CAPE TOWN A', 'number_transactions': 2},
#  {'other_franchisename': 'Trends t/a Lad', 'number_transactions': 1},
#  {'other_franchisename': 'COMPUTER MAN', 'number_transactions': 1},
#  {'other_franchisename': 'SIMPLY SKIN', 'number_transactions': 1},
#  {'other_franchisename': 'SONSTRAAL PHAR', 'number_transactions': 1},
#  {'other_franchisename': 'CHATEAU GATEAU', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR SONSTRAAL', 'number_transactions': 1},
#  {'other_franchisename': 'CALTEX COBBLE WALK', 'number_transactions': 1},
#  {'other_franchisename': 'CAFE DE LA MONTE', 'number_transactions': 1},
#  {'other_franchisename': 'Cltx CobbleWalk', 'number_transactions': 1},
#  {'other_franchisename': 'OASIS WATER DURBANVILL', 'number_transactions': 1},
#  {'other_franchisename': 'PNP CRP PINEHURST', 'number_transactions': 1},
#  {'other_franchisename': 'Quicksilver Car Wash -', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR SONSTRAAL SPAR', 'number_transactions': 1},
#  {'other_franchisename': 'BP BEYERS NAUDE SOUT', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BLOEMFONTEIN', 'number_transactions': 2},
#  {'other_franchisename': 'SANRAL/TCH IVR', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN LAINGSBURG  S', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN SWARTBERG  ST', 'number_transactions': 1},
#  {'other_franchisename': 'MUG & BEAN FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'LIQUOR LAND FICHARDT', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH CAPE GAT', 'number_transactions': 1},
#  {'other_franchisename': 'DAILYOM.COM', 'number_transactions': 1},
#  {'other_franchisename': 'SORBET BROADACRES', 'number_transactions': 2},
#  {'other_franchisename': 'THE SPORT INJURY CLI', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*Lizelle Steinberg', 'number_transactions': 1},
#  {'other_franchisename': 'EMMAS SECRET ROOM', 'number_transactions': 1},
#  {'other_franchisename': 'IKH*The Fresh', 'number_transactions': 1},
#  {'other_franchisename': 'SCHOOL AND LEISURE MID', 'number_transactions': 2},
#  {'other_franchisename': 'THE WORLD OF GOLF', 'number_transactions': 2},
#  {'other_franchisename': 'KFC BROADACRES', 'number_transactions': 4},
#  {'other_franchisename': 'SEATTLE BROADACRES', 'number_transactions': 3},
#  {'other_franchisename': 'FOURWAYS VETERINARY', 'number_transactions': 7},
#  {'other_franchisename': "READER'S WAREHOUSE B", 'number_transactions': 11},
#  {'other_franchisename': 'DRI AVG TECHNO', 'number_transactions': 2},
#  {'other_franchisename': 'Audible*KXLU', 'number_transactions': 1},
#  {'other_franchisename': 'VIDA E DESIG', 'number_transactions': 1},
#  {'other_franchisename': 'SEATTLE BROADA', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS BAS', 'number_transactions': 1},
#  {'other_franchisename': 'CORICRAFT GR', 'number_transactions': 1},
#  {'other_franchisename': 'Mindful Eating', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM MALL', 'number_transactions': 2},
#  {'other_franchisename': 'SASOL MEYERS', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers South', 'number_transactions': 1},
#  {'other_franchisename': 'VODACOM BROADA', 'number_transactions': 1},
#  {'other_franchisename': 'DIS-CHEM BRACK', 'number_transactions': 1},
#  {'other_franchisename': 'Clicks Meyersd', 'number_transactions': 1},
#  {'other_franchisename': 'PAUL JAMES HAI', 'number_transactions': 1},
#  {'other_franchisename': 'ROCOMAMAS MEYE', 'number_transactions': 1},
#  {'other_franchisename': 'DEBONAIRS PI', 'number_transactions': 1},
#  {'other_franchisename': 'Checkers Brack', 'number_transactions': 1},
#  {'other_franchisename': 'BUILDERS WH GL', 'number_transactions': 1},
#  {'other_franchisename': 'BP BROADACRE', 'number_transactions': 4},
#  {'other_franchisename': 'LOCO LIQ BRACK', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BRACKE', 'number_transactions': 1},
#  {'other_franchisename': 'SPAR MEYERSD', 'number_transactions': 1},
#  {'other_franchisename': 'WOOLWORTHS MEY', 'number_transactions': 1},
#  {'other_franchisename': 'DEBONAIRS FO', 'number_transactions': 1},
#  {'other_franchisename': 'TASHAS MELRO', 'number_transactions': 1},
#  {'other_franchisename': 'CITY FISH AND', 'number_transactions': 1},
#  {'other_franchisename': "ANNICA'S DESIG", 'number_transactions': 1},
#  {'other_franchisename': 'PnP Exp Monte', 'number_transactions': 1},
#  {'other_franchisename': 'PnP Crp On Nicol', 'number_transactions': 2},
#  {'other_franchisename': 'ALL FIX', 'number_transactions': 2},
#  {'other_franchisename': 'THE VALLEY GRILL', 'number_transactions': 9},
#  {'other_franchisename': 'AIRBNB * HMHXDDPY', 'number_transactions': 1},
#  {'other_franchisename': 'McDONALDS KYALAMI', 'number_transactions': 1},
#  {'other_franchisename': 'THE ROCK DINER FOURWAYTER',
#   'number_transactions': 1},
#  {'other_franchisename': 'VEROS CAKES', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN FOURWAYS', 'number_transactions': 7},
#  {'other_franchisename': 'MV CAFE', 'number_transactions': 1},
#  {'other_franchisename': 'PANDORA', 'number_transactions': 1},
#  {'other_franchisename': 'FESO HAIR CLINIC', 'number_transactions': 1},
#  {'other_franchisename': 'FOURWAYS GARDENS BP', 'number_transactions': 15},
#  {'other_franchisename': 'SPAR FOURWAYS GARDENS', 'number_transactions': 4},
#  {'other_franchisename': 'MANGO AIRLI', 'number_transactions': 1},
#  {'other_franchisename': 'SS MONTECASINO BAR', 'number_transactions': 1},
#  {'other_franchisename': 'FEDERAL PARKING SERVICES', 'number_transactions': 1},
#  {'other_franchisename': 'CHICKEN LICKEN FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'STER KINEKOR FOURWAYS', 'number_transactions': 1},
#  {'other_franchisename': 'ALTITUDE BEACH CLUB', 'number_transactions': 1},
#  {'other_franchisename': 'TBS Dainfern           SQ',
#   'number_transactions': 2},
#  {'other_franchisename': 'THE OLDE CHARITY S', 'number_transactions': 1},
#  {'other_franchisename': "PICOLINO'S ROLL ALWAYS", 'number_transactions': 1},
#  {'other_franchisename': 'Hotel on Booking.com', 'number_transactions': 2},
#  {'other_franchisename': 'RIVERSIDE LODGE', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN BLOEM  STOP S', 'number_transactions': 1},
#  {'other_franchisename': 'AIRBNB * HMMRESQZXC', 'number_transactions': 1},
#  {'other_franchisename': 'MOUNTAIN VIEW MANOR', 'number_transactions': 1},
#  {'other_franchisename': 'Truworths', 'number_transactions': 8},
#  {'other_franchisename': 'VODASHOP EAST LONDON A', 'number_transactions': 1},
#  {'other_franchisename': 'THE COCKHOUSE CC', 'number_transactions': 1},
#  {'other_franchisename': 'ENGEN AIRPORT MOTORS', 'number_transactions': 1},
#  {'other_franchisename': 'MUGG AND BEAN EL AIRPO', 'number_transactions': 1},
#  {'other_franchisename': 'THE BARISTA SISA', 'number_transactions': 1},
#  ...]

# %% [markdown]
# ### Common Neighbours
#
# Common neighbors captures the idea that two strangers who have a friend in common are more likely to be introduced than those who don’t have any friends in common.
#
# In retail and a bank graph db, this notion may be extended to imply that merchants who share clients do so for a number of reasons.  The product offering may be supplementary.  They share cclients with the same value prefeerences.

# %% [markdown]
# Take one client, one previously identified as a DIS-CHEM DAINFERN shopper, and measure shared nodes or commonNeighbours:

# %%
commonNeighbors_df = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c0:Client)
MATCH (c1:Client {dedupestatic:'2.11279273006e+11'})  
WHERE c0.dedupestatic <> c1.dedupestatic  
RETURN c0.dedupestatic as client1,c1.dedupestatic as client2, gds.alpha.linkprediction.commonNeighbors(c0, c1) as commonNeighbors
ORDER BY commonNeighbors DESC""").to_data_frame()
commonNeighbors_df
# Out:
#                client1            client2  commonNeighbors
# 0      2.110886841e+11  2.11279273006e+11             11.0
# 1    1.91188171709e+11  2.11279273006e+11             10.0
# 2    1.91831161106e+11  2.11279273006e+11              9.0
# 3    1.10231270801e+11  2.11279273006e+11              8.0
# 4    1.10183522702e+11  2.11279273006e+11              8.0
# ..                 ...                ...              ...
# 246  1.91087949007e+11  2.11279273006e+11              1.0
# 247  1.10090793803e+11  2.11279273006e+11              1.0
# 248  1.10029036305e+11  2.11279273006e+11              1.0
# 249  1.91100151227e+11  2.11279273006e+11              1.0
# 250  1.10096863404e+11  2.11279273006e+11              1.0
#
# [251 rows x 3 columns]

# %% [markdown]
# Below all clients, taken from the DainfernSquare complex is taken and compared via common neighbours.  This procedure takes LONGER to run, and it needss to be speeded up still.  There are apporximately 63000 ombinations.

# %%
commonNeighbors_df = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c0:Client) 
MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c1:Client) 
WHERE c0.dedupestatic <> c1.dedupestatic
RETURN c0.dedupestatic as client1,c1.dedupestatic as client2, gds.alpha.linkprediction.commonNeighbors(c0, c1) as commonNeighbors
ORDER BY commonNeighbors DESC """).to_data_frame()
commonNeighbors_df
# Out:
#                  client1            client2  commonNeighbors
# 0      1.91061835402e+11  1.91084371003e+11             16.0
# 1      1.91084371003e+11  1.91061835402e+11             16.0
# 2        1.918431743e+11  1.91030354806e+11             14.0
# 3        1.918431743e+11    1.100845365e+11             14.0
# 4      1.91061835402e+11  1.10265834708e+11             14.0
# ...                  ...                ...              ...
# 63247  1.30000322651e+11  6.00000357947e+11              1.0
# 63248  1.10206451601e+11  6.00000357947e+11              1.0
# 63249  1.10152180508e+11  6.00000357947e+11              1.0
# 63250  1.91032174406e+11  6.00000357947e+11              1.0
# 63251  1.10005126509e+11  6.00000357947e+11              1.0
#
# [63252 rows x 3 columns]

# %%
my_node = graph.run("""MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c0:Client)
WITH collect(distinct c0) as clients 
MATCH (dischem:Merchant {franchisename:'DIS-CHEM DAINFERN'})-[:TRANSACTED_AT]-(c1:Client) 
WHERE c1 NOT in clients AND gds.alpha.linkprediction.commonNeighbors(c0, c1)>5 
RETURN c0.dedupestatic, c1.dedupestatic""").data()
my_node

# %%
gds_graph_create="""CALL gds.graph.create(
    'myGraph',
    'Page',
    'LINKS',
)"""
