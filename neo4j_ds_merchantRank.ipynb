# %% [markdown]
# https://neo4j.com/developer/guide-build-a-recommendation-engine/
#
# https://www.r-bloggers.com/from-random-walks-to-personalized-pagerank/
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3964346/

# %%
import pandas as pd
from py2neo import Graph
graph = Graph("bolt://localhost:7687", user='neo4j', password='newPassword')
# graph = Graph()

# %%
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# ## merchantRank  (pageRank)

# %% [markdown]
# PageRank is an algorithm that measures connectivity of nodes, so they can be compared and ranked(connectivity: the transitive influence) It can be computed by either
#
# 1. iteratively distributing one node’s rank (originally based on degree) over its neighbors or
# 2. by randomly traversing the graph and counting the frequency of hitting each node during these walks.
#
# The following PageRank code is run over the whole graph to find out the most influential Merchant in terms of transactions:

# %% [markdown]
# https://www.cs.princeton.edu/~chazelle/courses/BIB/pagerank.htm

# %% [markdown]
# Check that our database is running:

# %%
graph.run("CALL db.schema.visualization()").data()
# Out:
# [{'nodes': [(_-2:Merchant {constraints: ['CONSTRAINT ON ( merchant:Merchant ) ASSERT (merchant.franchisename) IS UNIQUE'], indexes: [], name: 'Merchant'}),
#    (_-1:Client {constraints: ['CONSTRAINT ON ( client:Client ) ASSERT (client.dedupestatic) IS UNIQUE'], indexes: [], name: 'Client'}),
#    (_-3:Segment {constraints: ['CONSTRAINT ON ( segment:Segment ) ASSERT (segment.seg_l3_num) IS UNIQUE'], indexes: [], name: 'Segment'})],
#   'relationships': [(Client)-[:TRANSACTED_AT {}]->(Merchant),
#    (Merchant)-[:MERCHANT_VALUE_LINK {}]->(Merchant),
#    (Merchant)-[:MERCHANT_LINK {}]->(Merchant),
#    (Merchant)-[:MERCHANT_FEET_LINK {}]->(Merchant)]}]

# %% [markdown]
# ### MERCHANT_FEET_LINK

# %% [markdown]
# The feet link is an edge between Merchants.
# 1. It is created when one or more clients shopped at any time at each of the two merchants during the same month.
# 2. The feet link is DIRECTED by the transaction count at each of the two merchants by clients who transacted at both.
# 3. If client c transacted 'a' times at A and 'b' times at B and a>b AND c is the ONLY client who transacted at both A and B, then the MERCHANT_FEET_LINK edge points from B to A.
# 4. The COUNT property of the MERCHANT_FEET_LINK is equal to the number of clients who completed the edge.

# %%
MERCHANT_FEET_LINK_query="""MATCH (m0:Merchant)-[rel:MERCHANT_FEET_LINK]-(m1:Merchant)
WHERE ID(m0)=rel.ID0 AND ID(m1)=rel.ID1
WITH m0,m1,rel, rel.transactioncount0<=rel.transactioncount1 AS mustpointright, 
rel.transactioncount0>rel.transactioncount1 AS mustpointleft,
NOT (startNode(rel) = m0) as pointsleft,
(startNode(rel) = m0) as pointsright
RETURN ID(m0) as IDm0, ID(m1) as IDm1, m0.franchisename as franchisename0,
m1.franchisename as franchisename1, rel.transactioncount0 as transactioncount0,
rel.transactioncount1 as transactioncount1,
mustpointright, pointsright, mustpointleft, pointsleft;
"""
df=graph.run(MERCHANT_FEET_LINK_query).to_data_frame()

# %%
df
# Out:
#            IDm0     IDm1             franchisename0  \
# 0       4655367  4655368          Clicks Canal Walk
# 1       4655368  4655417        DIS-CHEM CANAL WALK
# 2       4655387  4655450  DIS-CHEM KILLARNEY PHAMAC
# 3       4655368  4655450        DIS-CHEM CANAL WALK
# 4       4655387  4655484  DIS-CHEM KILLARNEY PHAMAC
# ...         ...      ...                        ...
# 258055  4966020  5226623             DIS-CHEM CENTU
# 258056  5193978  5226623             CLICKS CLEARWA
# 258057  5186253  5229416             Dischem Sunnin
# 258058  4971648  5229846             DIS-CHEM THREE
# 258059  5193978  5230247             CLICKS CLEARWA
#
#                    franchisename1  transactioncount0  transactioncount1  \
# 0             DIS-CHEM CANAL WALK                 27                 31
# 1               DIS-CHEM DAINFERN                  2                  2
# 2       DIS-CHEM SANDTON CITY PHA                 18                 12
# 3       DIS-CHEM SANDTON CITY PHA                  1                  1
# 4               Clicks Rand Steam                  8                  7
# ...                           ...                ...                ...
# 258055             CLICKS VILLAGE                  1                  1
# 258056             CLICKS VILLAGE                  1                  1
# 258057             CLICKS WATERFA                  2                  1
# 258058               DIS-CHEM THR                  1                  1
# 258059             Dischem Clearw                  1                  1
#
#         mustpointright  pointsright  mustpointleft  pointsleft
# 0                 True         True          False       False
# 1                 True         True          False       False
# 2                False        False           True        True
# 3                 True         True          False       False
# 4                False        False           True        True
# ...                ...          ...            ...         ...
# 258055            True         True          False       False
# 258056            True         True          False       False
# 258057           False        False           True        True
# 258058            True         True          False       False
# 258059            True         True          False       False
#
# [258060 rows x 10 columns]

# %% [markdown]
# ### Create a graph built on the Dischem Clicks Merchant nodes linked only by MERCHANT_FEET_LINK:

# %% [markdown]
# List all existing graphs on this databse:

# %%
graph_list_query="""CALL gds.graph.list()"""
graph.run(graph_list_query).to_data_frame()
# Out:
#                 graphName memoryUsage  sizeInBytes  \
# 0  DischemClicksFeetGraph      18 MiB     18983448
#
#                                       nodeProjection  \
# 0  {'Merchant': {'properties': {}, 'label': 'Merc...
#
#                               relationshipProjection nodeQuery  \
# 0  {'MERCHANT_FEET_LINK': {'orientation': 'NATURA...      None
#
#   relationshipQuery  nodeCount  relationshipCount  \
# 0              None      92388             258060
#
#                                   degreeDistribution  \
# 0  {'p99': 77, 'min': 0, 'max': 680, 'mean': 2.79...
#
#                           creationTime               modificationTime  \
# 0  2020-06-09T15:36:59.597548000+02:00  2020-06-09T15:37:01.524147999
#
#                                               schema
# 0  {'relationships': {'MERCHANT_FEET_LINK': {'cou...

# %% [markdown]
# If the query doesnt exist, create it as follows:

# %%
MERCHANT_FEET_LINK_query="""CALL gds.graph.create(
    'DischemClicksFeetGraph',
    'Merchant',
    'MERCHANT_FEET_LINK',
    {
        relationshipProperties: 'count'
    }
);
"""
graph.run(MERCHANT_FEET_LINK_query).to_data_frame()
# Out:
#                                       nodeProjection  \
# 0  {'Merchant': {'properties': {}, 'label': 'Merc...
#
#                               relationshipProjection               graphName  \
# 0  {'MERCHANT_FEET_LINK': {'orientation': 'NATURA...  DischemClicksFeetGraph
#
#    nodeCount  relationshipCount  createMillis
# 0      92388             258060           752

# %%
MERCHANT_RANK_query="""CALL gds.pageRank.stream('DischemClicksFeetGraph', { maxIterations: 50, dampingFactor: 0.85 })
YIELD nodeId, score
RETURN gds.util.asNode(nodeId).franchisename AS franchisename, gds.util.asNode(nodeId).companyname AS companyname,score
ORDER BY score DESC, franchisename ASC;"""
df=graph.run(MERCHANT_RANK_query).to_data_frame()
# Out:
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-11-0f13f1ae9ad5> in <module>
#       3 RETURN gds.util.asNode(nodeId).franchisename AS franchisename, gds.util.asNode(nodeId).companyname AS companyname,score
#       4 ORDER BY score DESC, franchisename ASC;"""
# ----> 5 df=graph.run(MERCHANT_RANK_query).to_data_frame()
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/py2neo/database.py in to_data_frame(self, index, columns, dtype)
#    1287             raise
#    1288         else:
# -> 1289             return DataFrame(list(map(dict, self)), index=index, columns=columns, dtype=dtype)
#    1290
#    1291     def to_matrix(self, mutable=False):
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/py2neo/database.py in __iter__(self)
#    1069
#    1070     def __iter__(self):
# -> 1071         while self.forward():
#    1072             yield self._current
#    1073
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/py2neo/database.py in forward(self, amount)
#    1131         fetch = self._result.fetch
#    1132         while moved != amount:
# -> 1133             new_current = fetch()
#    1134             if new_current is None:
#    1135                 break
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/py2neo/internal/hydration/__init__.py in fetch(self)
#     112             while not self._records and not self._done:
#     113                 if callable(self._on_more):
# --> 114                     self._on_more()
#     115             try:
#     116                 return Record(zip(self.keys(), self._records.popleft()))
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     417     def fetch(self):
#     418         try:
# --> 419             return self._fetch()
#     420         except self.error_handler.known_errors as error:
#     421             self.error_handler.handle(error, self.unresolved_address)
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     459         elif summary_signature == b"\x7F":
#     460             log_debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
# --> 461             response.on_failure(summary_metadata or {})
#     462         else:
#     463             raise ProtocolError("Unexpected response message with signature %02X" % summary_signature)
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in on_failure(self, metadata)
#     746         """ Called when a FAILURE message has been received.
#     747         """
# --> 748         self.connection.reset()
#     749         handler = self.handlers.get("on_failure")
#     750         if callable(handler):
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in reset(self)
#     382         log_debug("[#%04X]  C: RESET", self.local_port)
#     383         self._append(b"\x0F", response=Response(self, on_failure=fail))
# --> 384         self.sync()
#     385
#     386     def send(self):
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in sync(self)
#     525             response = self.responses[0]
#     526             while not response.complete:
# --> 527                 detail_delta, summary_delta = self.fetch()
#     528                 detail_count += detail_delta
#     529                 summary_count += summary_delta
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in fetch(self)
#     417     def fetch(self):
#     418         try:
# --> 419             return self._fetch()
#     420         except self.error_handler.known_errors as error:
#     421             self.error_handler.handle(error, self.unresolved_address)
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in _fetch(self)
#     438             return 0, 0
#     439
# --> 440         self._receive()
#     441
#     442         details, summary_signature, summary_metadata = self._unpack()
#
# ~/anaconda3/envs/graphing/lib/python3.7/site-packages/neobolt/direct.py in _receive(self)
#     485                 if isinstance(response, CommitResponse):
#     486                     raise IncompleteCommitError(message)
# --> 487             raise self.Error(message)
#     488         elif received == -1:
#     489             raise KeyboardInterrupt()
#
# ServiceUnavailable: Failed to read from defunct connection ('localhost', 7687) (Address(host='127.0.0.1', port=7687))

# %%
df
# Out:
#                 franchisename companyname      score
# 0      POS Clicks   INS FUNDS      CLICKS  21.133721
# 1              Clicks The Mar      CLICKS   7.508745
# 2               DIS-CHEM GLEN     DISCHEM   6.979960
# 3              DIS-CHEM SOUTH     DISCHEM   6.702191
# 4              DIS-CHEM WONDE     DISCHEM   5.898821
# ...                       ...         ...        ...
# 92383         www.game.com.tw        GAME   0.150000
# 92384  www.sparkhaus-shop.com        SPAR   0.150000
# 92385          xmglobal limit    XMGLOBAL   0.150000
# 92386        xmglobal limited    XMGLOBAL   0.150000
# 92387                zara.com        ZARA   0.150000
#
# [92388 rows x 3 columns]
